# %%
from datetime import datetime
import glob
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
BASE_DATA_PATH = os.path.join("out_tfg_v3")
OUTPUT_FOLDER = os.path.join(os.path.expanduser("~"), "tfg_info", "figuras", "benchmarks")
TIMES_IN_MS = False

def get_dataset_file(cloud_name, timestamp="latest", data_path=BASE_DATA_PATH):
    csv_folder = os.path.join(data_path, cloud_name)
    csv_files = glob.glob(os.path.join(csv_folder, "*.csv"))
    df = None

    if not csv_files:
        raise FileNotFoundError(f"No CSV files found in the folder: {csv_folder}")

    if timestamp == "latest":
        latest_file = None
        latest_time = None

        for file in csv_files:
            try:
                filename = os.path.basename(file)
                ts_str = '-'.join(filename.split('-')[1:]).replace('.csv', '')
                ts = datetime.strptime(ts_str, "%Y-%m-%d-%H:%M:%S")
                if latest_time is None or ts > latest_time:
                    latest_time = ts
                    latest_file = file
            except Exception as e:
                print(f"Skipping file with invalid timestamp format: {filename} ({e})")
                continue

        if latest_file:
            print(f"Loading latest file: {latest_file}")
            df = pd.read_csv(latest_file)
        else:
            raise FileNotFoundError(f"No valid timestamped files found in: {csv_folder}")

    else:
        for file in csv_files:
            try:
                filename = os.path.basename(file)
                ts_str = '-'.join(filename.split('-')[1:]).replace('.csv', '')
                if timestamp == ts_str:
                    print(f"Loading file: {file}")
                    df = pd.read_csv(file)
                    break
            except Exception as e:
                print(f"Skipping file with invalid format: {filename} ({e})")
                continue

        if df is None:
            raise FileNotFoundError(f"File with date '{timestamp}' not found in folder: {csv_folder}")

    # Convert times to milliseconds
    if TIMES_IN_MS:
        for col in ['mean', 'stdev', 'warmup_time']:
            if col in df.columns:
                df[col] = df[col] * 1000

    return df


def read_multiple_datasets(clouds_datasets, data_path = BASE_DATA_PATH):
    dfs = {}
    for cloud, dataset in clouds_datasets.items():
        dfs[cloud] = get_dataset_file(cloud, "latest", data_path)
    return dfs

def output_fig(fig, filename):
    fig.savefig(os.path.join(OUTPUT_FOLDER, filename + ".pdf"), dpi=300, bbox_inches='tight')
    plt.close(fig)

# %%
import scienceplots
plt.style.use(["science", "grid"])
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 14,
    #'axes.titlesize': 12,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'legend.title_fontsize': 16,  
    
    'axes.grid': True,
    'axes.grid.axis': 'y',  # Only horizontal grid lines
    'grid.linestyle': '-',  # Solid line
    'grid.linewidth': 0.4,  # Very thin grid lines
    'grid.color': '#CCCCCC',  # Light gray grid
    
    'axes.axisbelow': True,
    'figure.figsize': (6, 4),  # Standard publication-friendly figure size
    'figure.dpi': 100, 
    #'figure.dpi': 300, 
    
    'lines.linewidth': 1.0,  # Consistent line thickness
    'lines.markersize': 4,  # Consistent marker size

    'figure.facecolor': 'white',  # Background color of the figure
    'figure.edgecolor': 'white',   # Edge color of the figure
})

# %%
def add_octree_types_legend(legend_handles, legend_labels, legend_title, fig, pos = (0.9, 0.97)):
    legend = fig.legend(
        legend_handles,
        legend_labels,
        title=legend_title,
        loc="upper right",
        bbox_to_anchor=pos,
        ncol=len(legend_handles),
        columnspacing=0.8,     # Reduce horizontal space between columns
        handletextpad=0.4,     # Reduce space between handle and text
        borderpad=0.5,         # Padding inside the legend box
        labelspacing=0.3,       # Reduce vertical space between labels
    )

# %%
NEIGHBORS_PTR = "neighborsPtr"
NEIGHBORS = "neighbors"
NEIGHBORS_PRUNE = "neighborsPrune"
NEIGHBORS_STRUCT = "neighborsStruct"
NEIGHBORS_APPROX_LOWER = "neighborsApproxLower"
NEIGHBORS_APPROX_UPPER = "neighborsApproxUpper"
MORTON_ENCODER = "MortonEncoder3D"
HILBERT_ENCODER = "HilbertEncoder3D"
NO_ENCODER = "NoEncoding"
LINEAR_OCTREE = "LinearOctree"
POINTER_OCTREE = "Octree"
UNIBN_OCTREE = "unibnOctree"
PCL_KDTREE = "PCLKdTree"
PCL_OCTREE = "PCLOctree"
NEIGHBORS_PCLKD = "neighborsPCLKD"
NEIGHBORS_UNIBN = "neighborsUnibn"
NEIGHBORS_PCLOCT = "PCLOctree"

# %%
# This dicts store information about the type parameters and possible combinations used in each visualization, 
# along with the palette of colors
TYPES_INFO_OCTREE_ENCODER = {
    "type_parameters":  ['octree', 'encoder'],
    "available_types": pd.DataFrame({
        'octree': [LINEAR_OCTREE, LINEAR_OCTREE, POINTER_OCTREE, POINTER_OCTREE, POINTER_OCTREE],
        'encoder': [HILBERT_ENCODER, MORTON_ENCODER, HILBERT_ENCODER, MORTON_ENCODER, NO_ENCODER]
    }),

    "palette": {
        (LINEAR_OCTREE, HILBERT_ENCODER): '#1984c5',
        (LINEAR_OCTREE, MORTON_ENCODER): '#63bff0',
        (POINTER_OCTREE, HILBERT_ENCODER): '#c23728',
        (POINTER_OCTREE, MORTON_ENCODER): '#de6e56',
        (POINTER_OCTREE, NO_ENCODER): '#e1a692'
    },
    "display_name" : {
        (LINEAR_OCTREE, HILBERT_ENCODER): r'\texttt{loct\_hilb}',
        (LINEAR_OCTREE, MORTON_ENCODER): r'\texttt{loct\_mort}',
        (POINTER_OCTREE, HILBERT_ENCODER): r'\texttt{poct\_hilb}',
        (POINTER_OCTREE, MORTON_ENCODER): r'\texttt{poct\_mort}',
        (POINTER_OCTREE, NO_ENCODER): r'\texttt{poct\_unsorted}'
    }
}

palette_ops = sns.color_palette("viridis", n_colors=4)
palette_structs = sns.dark_palette(palette_ops[3], n_colors=8, input="rgb")
sns.hls_palette()
TYPES_INFO_OPERATIONS = {
    "type_parameters":  ['octree', 'operation'],
    "available_types": pd.DataFrame({
        'octree': [POINTER_OCTREE, LINEAR_OCTREE, LINEAR_OCTREE, LINEAR_OCTREE],
        'operation': [NEIGHBORS_PTR, NEIGHBORS, NEIGHBORS_PRUNE, NEIGHBORS_STRUCT]
    }),

    "palette": {
        (POINTER_OCTREE, NEIGHBORS_PTR): palette_ops[0],
        (LINEAR_OCTREE, NEIGHBORS): palette_ops[1],
        (LINEAR_OCTREE, NEIGHBORS_PRUNE): palette_ops[2],
        (LINEAR_OCTREE, NEIGHBORS_STRUCT): palette_ops[3],
    },
    "display_name" : {
        (POINTER_OCTREE, NEIGHBORS_PTR): r'\textit{neighborsPtr}',
        (LINEAR_OCTREE, NEIGHBORS): r'\textit{neighbors}',
        (LINEAR_OCTREE, NEIGHBORS_PRUNE): r'\textit{neighborsPrune}',
        (LINEAR_OCTREE, NEIGHBORS_STRUCT): r'\textit{neighborsStruct}',
    }
}

TYPES_INFO_STRUCTURES = {
    "type_parameters":  ['octree', 'operation'],
    "available_types": pd.DataFrame({
        'octree': [LINEAR_OCTREE, UNIBN_OCTREE, PCL_OCTREE, PCL_KDTREE],
        'operation': [NEIGHBORS_STRUCT, NEIGHBORS_UNIBN, NEIGHBORS_PCLOCT, NEIGHBORS_PCLKD]
    }),
    "markertype": {
        (LINEAR_OCTREE, NEIGHBORS_STRUCT): 'o',   # circle
        (UNIBN_OCTREE, NEIGHBORS_UNIBN): 'x',     # x marker
        (PCL_OCTREE, NEIGHBORS_PCLOCT): '*',       # star
        (PCL_KDTREE, NEIGHBORS_PCLKD): '^',       # triangle up
    },
    "palette": {
        (LINEAR_OCTREE, NEIGHBORS_STRUCT): palette_structs[7],
        (UNIBN_OCTREE, NEIGHBORS_UNIBN): palette_structs[5],
        (PCL_OCTREE, NEIGHBORS_PCLOCT): palette_structs[3],
        (PCL_KDTREE, NEIGHBORS_PCLKD): palette_structs[1],
    },
    "display_name" : {
        (LINEAR_OCTREE, NEIGHBORS_STRUCT): r'\textit{neighborsStruct}',
        (UNIBN_OCTREE, NEIGHBORS_UNIBN): r'\textit{unibnOctree}',
        (PCL_OCTREE, NEIGHBORS_PCLOCT): r'\textit{PCL Octree}',
        (PCL_KDTREE, NEIGHBORS_PCLKD): r'\textit{PCL KD-tree}'
    }
}

# %%
from matplotlib.colors import rgb2hex
palette_ops = sns.color_palette("viridis", n_colors=4)
hex_colors = [rgb2hex(color) for color in palette_ops]
print(hex_colors)
# Out:
# ['#414487', '#2a788e', '#22a884', '#7ad151']

# %%
DATA_SUBSET = os.path.join(BASE_DATA_PATH, "subset")
DATA_FULL = os.path.join(BASE_DATA_PATH, "full")
DATA_PARALLEL_SUBSET = os.path.join(BASE_DATA_PATH, "parallel_subset")
DATA_PARALLEL_FULL = os.path.join(BASE_DATA_PATH, "parallel_full")
DATA_APPROX_SUBSET = os.path.join(BASE_DATA_PATH, "approx_subset")
DATA_APPROX_FULL = os.path.join(BASE_DATA_PATH, "approx_full")

# %%
# Multiple datasets
CLOUDS_DATASETS = {
                    "Lille_0": "Paris_Lille", 
                    "Paris_Luxembourg_6": "Paris_Lille",
                    "5080_54400": "DALES"
                }
RADII = {0.5, 1.0, 2.0, 3.0}
CLOUDS_DATASETS_HIGH_DENSITY = {
                    "bildstein_station1_xyz_intensity_rgb": "Semantic3D",
                    "sg27_station8_intensity_rgb": "Semantic3D",
                    "Speulderbos_2017_TLS": "Speulderbos"
                }
RADII_HIGH_DENSITY = {0.01, 0.05, 0.1}
ALL_CLOUDS = CLOUDS_DATASETS.copy()
ALL_CLOUDS.update(CLOUDS_DATASETS_HIGH_DENSITY)

# %%
def octree_runtime_comparison(cloud, data_path, operations , legend_title = r"Combinación \textit{Octree} y SFC", 
                                show_warmup_time=False, types_info=TYPES_INFO_OCTREE_ENCODER, cols = 1, figsz = (7,10), legend_pos=(0.9, 1.0), encoder = "all", kernels="all", show_legend = True):
    df = get_dataset_file(cloud, "latest", data_path)
    # Filter the dataset for the specified operation
    df = df[df['operation'].isin(operations)]
    # Get unique radii and kernels
    radii = sorted(df['radius'].unique())
    if kernels != "all":
        if isinstance(kernels, str):
            kernels = [kernels]
        df = df[df["kernel"].isin(kernels)]
    
    kernels = df['kernel'].unique()
    if encoder != "all":
        df = df[df["encoder"] == encoder]

    print(df)
    # Create subplot grid with reduced vertical spacing
    fig, axes = plt.subplots(int(np.ceil(len(radii)/cols)), cols, figsize=figsz,
                              gridspec_kw={'hspace': 0.3}, squeeze = False)

    # Bar spacing parameters
    bar_width = 0.15
    group_width = bar_width * len(types_info["available_types"])
    group_gap = 0.2
    legend_handles, legend_labels = [], []
    curr_row, curr_col = 0, 0
    # First loop through each radius: 1.0, 2.5, 5.0, ...
    for radius_idx, radius in enumerate(radii):
        ax = axes[curr_row][curr_col]
        radius_data = df[df['radius'] == radius]
        # Now iterate through kernels: circle, sphere, square, cube, ...
        kernel_labels = []
        for i, kernel in enumerate(kernels):
            kernel_data = radius_data[radius_data['kernel'] == kernel]
            if kernel_data.empty:
                kernel_labels.append(f'Kernel {kernel}\nSin datos')
                continue
            avg_total = kernel_data['avg_result_size'].iloc[0]
            kernel_labels.append(f"$\\mathcal{{N}}_{{{kernel}}}$\n$\\mu = {avg_total:.0f}$")
            # Finally, iterate through each of the octree implementations identified by the (octree, encoder, point_type) tuple
            for j, (_, params) in enumerate(types_info["available_types"].iterrows()):
                # Extract parameters dynamically from the row
                key = tuple(params[col] for col in types_info["type_parameters"])
                octree_data = kernel_data[
                    (kernel_data[types_info["type_parameters"]] == pd.Series(key, index=types_info["type_parameters"])).all(axis=1)
                ]
                if octree_data.empty:
                    continue
                means = octree_data['mean'].values
                stdevs = octree_data['stdev'].values
                warmup_times = octree_data['warmup_time'].values
                x_pos = i * (group_width + group_gap) + j * bar_width
                
                # Main execution time bar
                bar = ax.bar(x_pos, means[0], bar_width,
                             color=types_info["palette"][key])
                
                # Warmup time bar (if enabled)
                if show_warmup_time:
                    ax.bar(x_pos, warmup_times[0], bar_width, 
                           color="none", 
                           edgecolor='black', alpha = 0.5,
                           zorder=-2)  # Ensure it's drawn on top
                
                ax.errorbar(x_pos, means[0], stdevs[0],
                            color='gray', capsize=3, capthick=1,
                            fmt='none', elinewidth=1)
                formatted_label = types_info["display_name"][key]
                if radius_idx == 0 and formatted_label not in legend_labels:
                    legend_handles.append(bar)
                    legend_labels.append(formatted_label)
        
        # Set kernel labels
        kernel_group_centers = [i * (group_width + group_gap) + group_width/2 for i in range(len(kernels))]
        ax.set_xticks(kernel_group_centers)
        ax.set_xticklabels(kernel_labels)
        alignment_x = 0 if curr_col == 0 else 0.85
        ax.text(alignment_x, 1.1, f'$r = {radius}~m$',
                transform=ax.transAxes,
                fontsize=16,
                va='top', ha='left')
       
        ax.set_ylabel(f"Tiempo total {'(ms)' if TIMES_IN_MS else '(s)'}")
        ax.tick_params(axis="x", which="both", length=0)
        curr_col += 1
        if curr_col == cols:
            curr_col = 0
            curr_row+=1
    if show_legend:
        add_octree_types_legend(legend_handles, legend_labels, legend_title, fig, pos = legend_pos)
    return fig

# %%
import scipy.stats as stats
def plot_avg_result_sizes_log(clouds_datasets, kernel, operations, data_path, types_info=TYPES_INFO_OCTREE_ENCODER, encoder = "all", 
                              legend_pos = (0.905, 0.98), show_legend = True, legend_title = r"Combinación \textit{Octree} y SFC", fsz=(8,7)):
    dfs = read_multiple_datasets(clouds_datasets, data_path)
    fig, ax = plt.subplots(figsize=fsz)
    legend_handles, legend_labels = [], []
    
    for j, (_, params) in enumerate(types_info["available_types"].iterrows()):
        key = tuple(params[col] for col in types_info["type_parameters"])
        avg_sizes, runtimes = [], []
        for df_name, df in dfs.items():
            if kernel == "all":
                df = df[(df['operation'].isin(operations))]
            else:
                df = df[(df['kernel'] == kernel) & (df['operation'].isin(operations))]
            if encoder != "all":
                df = df[df["encoder"] == encoder]
            if df.empty:
                continue
            octree_data = df[
                (df[types_info["type_parameters"]] == pd.Series(key, index=types_info["type_parameters"])).all(axis=1)
            ]
            print(octree_data)
            if octree_data.empty:
                continue
            avg_sizes.extend(octree_data['avg_result_size'].tolist())
            runtimes.extend(octree_data['mean'].tolist())

        if avg_sizes and runtimes:
            scatter_kwargs = {'s': 20}
            if "palette" in types_info:
                scatter_kwargs['color'] = types_info["palette"][key]
            if "markertype" in types_info:
                scatter_kwargs['s'] = 35
                print(key)
                scatter_kwargs['marker'] = types_info["markertype"][key]

            scatter = ax.scatter(avg_sizes, runtimes, **scatter_kwargs)
            legend_handles.append(scatter)
            legend_labels.append(types_info["display_name"][key])
            # linear regression line
            slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(avg_sizes), np.log(runtimes))
            regression_line = np.exp(intercept + slope * np.log(np.array(avg_sizes)))
            ax.plot(avg_sizes, regression_line, color=types_info["palette"][key], linestyle='dashed', linewidth=1)
    
    total_morton_runtimes = []
    total_hilbert_runtimes = []
    for df_name, df in dfs.items():
        if df.empty:
            continue
        morton_df = df[(df["encoder"] == MORTON_ENCODER)]
        hilbert_df = df[(df["encoder"] == HILBERT_ENCODER)]
        total_morton_runtimes.extend(morton_df["mean"].tolist())
        total_hilbert_runtimes.extend(hilbert_df["mean"].tolist())
    # Compute average reduction across all matched pairs
    avg_morton_runtime = np.mean(total_morton_runtimes)
    avg_hilbert_runtime = np.mean(total_hilbert_runtimes)

    print(f"Average Morton runtime:  {avg_morton_runtime:.4f}")
    print(f"Average Hilbert runtime: {avg_hilbert_runtime:.4f}")


    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)
    ax.set_xlabel(r"$\mu$", fontsize=16)
    ax.set_ylabel(f"Tiempo total {'(ms)' if TIMES_IN_MS else '(s)'}", fontsize=16)
        
    # Add legend and titles
    if show_legend:
        add_octree_types_legend(legend_handles, legend_labels, legend_title, fig, pos = legend_pos)
    return fig

# %%
# Paris_Luxembourg_6 SUBSETS
fig = octree_runtime_comparison("Paris_Luxembourg_6", DATA_SUBSET, [NEIGHBORS_PTR, NEIGHBORS_PRUNE], cols=2, figsz=(12,7), legend_pos= (0.85,1.03))
output_fig(fig, "paris_luxembourg_6_subsets")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/subset/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-06-01-10:38:28.csv
#                     date        octree point_type           encoder   npoints  \
# 0    2025-06-01-10:38:34        Octree      Point        NoEncoding  10000000
# 1    2025-06-01-10:38:35        Octree      Point        NoEncoding  10000000
# 2    2025-06-01-10:38:38        Octree      Point        NoEncoding  10000000
# 3    2025-06-01-10:38:39        Octree      Point        NoEncoding  10000000
# 4    2025-06-01-10:38:45        Octree      Point        NoEncoding  10000000
# ..                   ...           ...        ...               ...       ...
# 151  2025-06-01-10:53:07  LinearOctree      Point  HilbertEncoder3D  10000000
# 160  2025-06-01-10:54:06  LinearOctree      Point  HilbertEncoder3D  10000000
# 161  2025-06-01-10:54:08  LinearOctree      Point  HilbertEncoder3D  10000000
# 162  2025-06-01-10:54:13  LinearOctree      Point  HilbertEncoder3D  10000000
# 163  2025-06-01-10:54:17  LinearOctree      Point  HilbertEncoder3D  10000000
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 0      neighborsPtr  Circle     0.5         10000              random  ...
# 1      neighborsPtr  Sphere     0.5         10000              random  ...
# 2      neighborsPtr  Square     0.5         10000              random  ...
# 3      neighborsPtr    Cube     0.5         10000              random  ...
# 4      neighborsPtr  Circle     1.0         10000              random  ...
# ..              ...     ...     ...           ...                 ...  ...
# 151  neighborsPrune    Cube     2.0         10000              random  ...
# 160  neighborsPrune  Circle     3.0         10000              random  ...
# 161  neighborsPrune  Sphere     3.0         10000              random  ...
# 162  neighborsPrune  Square     3.0         10000              random  ...
# 163  neighborsPrune    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 0       2.274560  0.454912  0.447764  0.020720            1     0.531981
# 1       0.816164  0.163233  0.163578  0.003404            1     0.170857
# 2       2.102960  0.420591  0.422880  0.004190            1     0.429605
# 3       0.795293  0.159059  0.157683  0.003831            1     0.159071
# 4       5.091840  1.018370  1.022930  0.020297            1     1.058390
# ..           ...       ...       ...       ...          ...          ...
# 151     1.341380  0.268276  0.268776  0.000807            1     0.273632
# 160     3.643090  0.728618  0.728969  0.002826            1     0.727351
# 161     2.224320  0.444865  0.445232  0.001428            1     0.445514
# 162     4.200820  0.840165  0.839731  0.002851            1     0.843698
# 163     2.741030  0.548206  0.547873  0.002105            1     0.548118
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0              13555                     0              40          dynamic
# 1               4998                     0              40          dynamic
# 2              16598                     0              40          dynamic
# 3               6656                     0              40          dynamic
# 4              42141                     0              40          dynamic
# ..               ...                   ...             ...              ...
# 151           108831                     0              40          dynamic
# 160           268205                     0              40          dynamic
# 161           179797                     0              40          dynamic
# 162           331967                     0              40          dynamic
# 163           241699                     0              40          dynamic
#
# [80 rows x 21 columns]

# %%
# comparacion algoritmos subset
fig = octree_runtime_comparison("Paris_Luxembourg_6", DATA_SUBSET, [NEIGHBORS_PTR, NEIGHBORS, NEIGHBORS_PRUNE, NEIGHBORS_STRUCT], 
                                    legend_title=r"Algoritmo de búsqueda", cols=2, figsz=(12,7), legend_pos= (0.81,1), types_info=TYPES_INFO_OPERATIONS, encoder=HILBERT_ENCODER)
output_fig(fig, "paris_luxembourg_6_algo_comp_hilb_subsets")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/subset/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-06-01-10:38:28.csv
#                     date        octree point_type           encoder   npoints  \
# 104  2025-06-01-10:49:35        Octree      Point  HilbertEncoder3D  10000000
# 105  2025-06-01-10:49:36        Octree      Point  HilbertEncoder3D  10000000
# 106  2025-06-01-10:49:38        Octree      Point  HilbertEncoder3D  10000000
# 107  2025-06-01-10:49:39        Octree      Point  HilbertEncoder3D  10000000
# 108  2025-06-01-10:49:44        Octree      Point  HilbertEncoder3D  10000000
# ..                   ...           ...        ...               ...       ...
# 163  2025-06-01-10:54:17  LinearOctree      Point  HilbertEncoder3D  10000000
# 164  2025-06-01-10:54:19  LinearOctree      Point  HilbertEncoder3D  10000000
# 165  2025-06-01-10:54:20  LinearOctree      Point  HilbertEncoder3D  10000000
# 166  2025-06-01-10:54:22  LinearOctree      Point  HilbertEncoder3D  10000000
# 167  2025-06-01-10:54:23  LinearOctree      Point  HilbertEncoder3D  10000000
#
#            operation  kernel  radius  num_searches sequential_searches  ...  \
# 104     neighborsPtr  Circle     0.5         10000              random  ...
# 105     neighborsPtr  Sphere     0.5         10000              random  ...
# 106     neighborsPtr  Square     0.5         10000              random  ...
# 107     neighborsPtr    Cube     0.5         10000              random  ...
# 108     neighborsPtr  Circle     1.0         10000              random  ...
# ..               ...     ...     ...           ...                 ...  ...
# 163   neighborsPrune    Cube     3.0         10000              random  ...
# 164  neighborsStruct  Circle     3.0         10000              random  ...
# 165  neighborsStruct  Sphere     3.0         10000              random  ...
# 166  neighborsStruct  Square     3.0         10000              random  ...
# 167  neighborsStruct    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 104     1.868760  0.373753  0.374289  0.010503            1     0.403264
# 105     0.644801  0.128960  0.129057  0.001416            1     0.132935
# 106     1.721450  0.344290  0.344179  0.002890            1     0.353762
# 107     0.601318  0.120264  0.120072  0.000512            1     0.122294
# 108     4.393910  0.878783  0.880378  0.004247            1     0.890074
# ..           ...       ...       ...       ...          ...          ...
# 163     2.741030  0.548206  0.547873  0.002105            1     0.548118
# 164     1.587740  0.317548  0.317509  0.000583            1     0.319229
# 165     0.912213  0.182443  0.182312  0.000180            1     0.182330
# 166     1.582360  0.316472  0.316483  0.000468            1     0.318221
# 167     0.957258  0.191452  0.191572  0.000481            1     0.191847
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 104            13532                     0              40          dynamic
# 105             4999                     0              40          dynamic
# 106            16556                     0              40          dynamic
# 107             6660                     0              40          dynamic
# 108            42070                     0              40          dynamic
# ..               ...                   ...             ...              ...
# 163           241699                     0              40          dynamic
# 164           268205                     0              40          dynamic
# 165           179797                     0              40          dynamic
# 166           331967                     0              40          dynamic
# 167           241699                     0              40          dynamic
#
# [64 rows x 21 columns]

# %%
# log-log SUBSETS
fig = plot_avg_result_sizes_log(ALL_CLOUDS, "all", [NEIGHBORS_PTR, NEIGHBORS_PRUNE], DATA_SUBSET, legend_pos= (1.03,1), fsz=(8,8))
output_fig(fig, "loglog_subsets")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/subset/Lille_0/Lille_0-2025-06-01-10:30:28.csv
# Loading latest file: out_tfg_v3/subset/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-06-01-10:38:28.csv
# Loading latest file: out_tfg_v3/subset/5080_54400/5080_54400-2025-06-01-10:37:30.csv
# Loading latest file: out_tfg_v3/subset/bildstein_station1_xyz_intensity_rgb/bildstein_station1_xyz_intensity_rgb-2025-06-01-10:55:38.csv
# Loading latest file: out_tfg_v3/subset/sg27_station8_intensity_rgb/sg27_station8_intensity_rgb-2025-06-01-11:00:41.csv
# Skipping file with invalid timestamp format: extra.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/subset/Speulderbos_2017_TLS/Speulderbos_2017_TLS-2025-06-01-12:43:03.csv
#                     date        octree point_type           encoder   npoints  \
# 124  2025-06-01-10:36:10  LinearOctree      Point  HilbertEncoder3D  10000000
# 125  2025-06-01-10:36:10  LinearOctree      Point  HilbertEncoder3D  10000000
# 126  2025-06-01-10:36:10  LinearOctree      Point  HilbertEncoder3D  10000000
# 127  2025-06-01-10:36:10  LinearOctree      Point  HilbertEncoder3D  10000000
# 136  2025-06-01-10:36:15  LinearOctree      Point  HilbertEncoder3D  10000000
# 137  2025-06-01-10:36:15  LinearOctree      Point  HilbertEncoder3D  10000000
# 138  2025-06-01-10:36:15  LinearOctree      Point  HilbertEncoder3D  10000000
# 139  2025-06-01-10:36:16  LinearOctree      Point  HilbertEncoder3D  10000000
# 148  2025-06-01-10:36:27  LinearOctree      Point  HilbertEncoder3D  10000000
# 149  2025-06-01-10:36:28  LinearOctree      Point  HilbertEncoder3D  10000000
# 150  2025-06-01-10:36:28  LinearOctree      Point  HilbertEncoder3D  10000000
# 151  2025-06-01-10:36:29  LinearOctree      Point  HilbertEncoder3D  10000000
# 160  2025-06-01-10:36:53  LinearOctree      Point  HilbertEncoder3D  10000000
# 161  2025-06-01-10:36:54  LinearOctree      Point  HilbertEncoder3D  10000000
# 162  2025-06-01-10:36:56  LinearOctree      Point  HilbertEncoder3D  10000000
# 163  2025-06-01-10:36:57  LinearOctree      Point  HilbertEncoder3D  10000000
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 124  neighborsPrune  Circle     0.5         10000              random  ...
# 125  neighborsPrune  Sphere     0.5         10000              random  ...
# 126  neighborsPrune  Square     0.5         10000              random  ...
# 127  neighborsPrune    Cube     0.5         10000              random  ...
# 136  neighborsPrune  Circle     1.0         10000              random  ...
# 137  neighborsPrune  Sphere     1.0         10000              random  ...
# 138  neighborsPrune  Square     1.0         10000              random  ...
# 139  neighborsPrune    Cube     1.0         10000              random  ...
# 148  neighborsPrune  Circle     2.0         10000              random  ...
# 149  neighborsPrune  Sphere     2.0         10000              random  ...
# 150  neighborsPrune  Square     2.0         10000              random  ...
# 151  neighborsPrune    Cube     2.0         10000              random  ...
# 160  neighborsPrune  Circle     3.0         10000              random  ...
# 161  neighborsPrune  Sphere     3.0         10000              random  ...
# 162  neighborsPrune  Square     3.0         10000              random  ...
# 163  neighborsPrune    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 124     0.262896  0.052579  0.052730  0.000492            1     0.051956
# 125     0.091349  0.018270  0.018290  0.000067            1     0.018370
# 126     0.267859  0.053572  0.053674  0.000509            1     0.052777
# 127     0.098350  0.019670  0.019689  0.000111            1     0.019944
# 136     0.421526  0.084305  0.084412  0.000615            1     0.083598
# 137     0.205899  0.041180  0.041155  0.000139            1     0.041315
# 138     0.427514  0.085503  0.085848  0.000636            1     0.084896
# 139     0.222311  0.044462  0.044468  0.000155            1     0.044511
# 148     0.740761  0.148152  0.147843  0.000693            1     0.147058
# 149     0.485818  0.097163  0.097176  0.000331            1     0.097145
# 150     0.802694  0.160539  0.160870  0.000757            1     0.159759
# 151     0.556466  0.111293  0.111443  0.000417            1     0.111721
# 160     1.253700  0.250740  0.249680  0.001897            1     0.250044
# 161     0.914360  0.182872  0.183346  0.000899            1     0.184823
# 162     1.531820  0.306363  0.305686  0.001497            1     0.304670
# 163     1.171150  0.234230  0.234684  0.001059            1     0.233567
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 124             5148                     0              40          dynamic
# 125             2063                     0              40          dynamic
# 126             6241                     0              40          dynamic
# 127             2761                     0              40          dynamic
# 136            14817                     0              40          dynamic
# 137             8296                     0              40          dynamic
# 138            18151                     0              40          dynamic
# 139            11199                     0              40          dynamic
# 148            45183                     0              40          dynamic
# 149            32827                     0              40          dynamic
# 150            55765                     0              40          dynamic
# 151            43695                     0              40          dynamic
# 160            89398                     0              40          dynamic
# 161            71947                     0              40          dynamic
# 162           111210                     0              40          dynamic
# 163            95296                     0              40          dynamic
#
# [16 rows x 21 columns]
#                     date        octree point_type           encoder   npoints  \
# 124  2025-06-01-10:52:17  LinearOctree      Point  HilbertEncoder3D  10000000
# 125  2025-06-01-10:52:17  LinearOctree      Point  HilbertEncoder3D  10000000
# 126  2025-06-01-10:52:18  LinearOctree      Point  HilbertEncoder3D  10000000
# 127  2025-06-01-10:52:18  LinearOctree      Point  HilbertEncoder3D  10000000
# 136  2025-06-01-10:52:28  LinearOctree      Point  HilbertEncoder3D  10000000
# 137  2025-06-01-10:52:29  LinearOctree      Point  HilbertEncoder3D  10000000
# 138  2025-06-01-10:52:30  LinearOctree      Point  HilbertEncoder3D  10000000
# 139  2025-06-01-10:52:31  LinearOctree      Point  HilbertEncoder3D  10000000
# 148  2025-06-01-10:53:01  LinearOctree      Point  HilbertEncoder3D  10000000
# 149  2025-06-01-10:53:03  LinearOctree      Point  HilbertEncoder3D  10000000
# 150  2025-06-01-10:53:06  LinearOctree      Point  HilbertEncoder3D  10000000
# 151  2025-06-01-10:53:07  LinearOctree      Point  HilbertEncoder3D  10000000
# 160  2025-06-01-10:54:06  LinearOctree      Point  HilbertEncoder3D  10000000
# 161  2025-06-01-10:54:08  LinearOctree      Point  HilbertEncoder3D  10000000
# 162  2025-06-01-10:54:13  LinearOctree      Point  HilbertEncoder3D  10000000
# 163  2025-06-01-10:54:17  LinearOctree      Point  HilbertEncoder3D  10000000
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 124  neighborsPrune  Circle     0.5         10000              random  ...
# 125  neighborsPrune  Sphere     0.5         10000              random  ...
# 126  neighborsPrune  Square     0.5         10000              random  ...
# 127  neighborsPrune    Cube     0.5         10000              random  ...
# 136  neighborsPrune  Circle     1.0         10000              random  ...
# 137  neighborsPrune  Sphere     1.0         10000              random  ...
# 138  neighborsPrune  Square     1.0         10000              random  ...
# 139  neighborsPrune    Cube     1.0         10000              random  ...
# 148  neighborsPrune  Circle     2.0         10000              random  ...
# 149  neighborsPrune  Sphere     2.0         10000              random  ...
# 150  neighborsPrune  Square     2.0         10000              random  ...
# 151  neighborsPrune    Cube     2.0         10000              random  ...
# 160  neighborsPrune  Circle     3.0         10000              random  ...
# 161  neighborsPrune  Sphere     3.0         10000              random  ...
# 162  neighborsPrune  Square     3.0         10000              random  ...
# 163  neighborsPrune    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 124     0.531499  0.106300  0.105728  0.000815            1     0.108780
# 125     0.146380  0.029276  0.028410  0.001173            1     0.032278
# 126     0.559079  0.111816  0.111536  0.000826            1     0.113071
# 127     0.155784  0.031157  0.031235  0.000170            1     0.031387
# 136     1.046160  0.209231  0.209308  0.001283            1     0.210993
# 137     0.356745  0.071349  0.071189  0.000397            1     0.072243
# 138     1.125670  0.225133  0.225197  0.001482            1     0.226288
# 139     0.406659  0.081332  0.081575  0.000427            1     0.082484
# 148     2.317910  0.463582  0.461295  0.004129            1     0.472442
# 149     1.130450  0.226090  0.226532  0.001533            1     0.226640
# 150     2.540620  0.508125  0.507099  0.002204            1     0.509211
# 151     1.341380  0.268276  0.268776  0.000807            1     0.273632
# 160     3.643090  0.728618  0.728969  0.002826            1     0.727351
# 161     2.224320  0.444865  0.445232  0.001428            1     0.445514
# 162     4.200820  0.840165  0.839731  0.002851            1     0.843698
# 163     2.741030  0.548206  0.547873  0.002105            1     0.548118
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 124            13532                     0              40          dynamic
# 125             4999                     0              40          dynamic
# 126            16556                     0              40          dynamic
# 127             6660                     0              40          dynamic
# 136            42070                     0              40          dynamic
# 137            20202                     0              40          dynamic
# 138            51917                     0              40          dynamic
# 139            27092                     0              40          dynamic
# 148           134518                     0              40          dynamic
# 149            81042                     0              40          dynamic
# 150           166349                     0              40          dynamic
# 151           108831                     0              40          dynamic
# 160           268205                     0              40          dynamic
# 161           179797                     0              40          dynamic
# 162           331967                     0              40          dynamic
# 163           241699                     0              40          dynamic
#
# [16 rows x 21 columns]
#                     date        octree point_type           encoder   npoints  \
# 124  2025-06-01-10:38:17  LinearOctree      Point  HilbertEncoder3D  12219779
# 125  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 126  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 127  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 136  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 137  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 138  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 139  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 148  2025-06-01-10:38:19  LinearOctree      Point  HilbertEncoder3D  12219779
# 149  2025-06-01-10:38:19  LinearOctree      Point  HilbertEncoder3D  12219779
# 150  2025-06-01-10:38:20  LinearOctree      Point  HilbertEncoder3D  12219779
# 151  2025-06-01-10:38:20  LinearOctree      Point  HilbertEncoder3D  12219779
# 160  2025-06-01-10:38:21  LinearOctree      Point  HilbertEncoder3D  12219779
# 161  2025-06-01-10:38:21  LinearOctree      Point  HilbertEncoder3D  12219779
# 162  2025-06-01-10:38:22  LinearOctree      Point  HilbertEncoder3D  12219779
# 163  2025-06-01-10:38:22  LinearOctree      Point  HilbertEncoder3D  12219779
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 124  neighborsPrune  Circle     0.5         10000              random  ...
# 125  neighborsPrune  Sphere     0.5         10000              random  ...
# 126  neighborsPrune  Square     0.5         10000              random  ...
# 127  neighborsPrune    Cube     0.5         10000              random  ...
# 136  neighborsPrune  Circle     1.0         10000              random  ...
# 137  neighborsPrune  Sphere     1.0         10000              random  ...
# 138  neighborsPrune  Square     1.0         10000              random  ...
# 139  neighborsPrune    Cube     1.0         10000              random  ...
# 148  neighborsPrune  Circle     2.0         10000              random  ...
# 149  neighborsPrune  Sphere     2.0         10000              random  ...
# 150  neighborsPrune  Square     2.0         10000              random  ...
# 151  neighborsPrune    Cube     2.0         10000              random  ...
# 160  neighborsPrune  Circle     3.0         10000              random  ...
# 161  neighborsPrune  Sphere     3.0         10000              random  ...
# 162  neighborsPrune  Square     3.0         10000              random  ...
# 163  neighborsPrune    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 124     0.067161  0.013432  0.013399  0.000058            1     0.013726
# 125     0.016465  0.003293  0.003291  0.000018            1     0.003290
# 126     0.072510  0.014502  0.014533  0.000074            1     0.014686
# 127     0.018017  0.003603  0.003603  0.000024            1     0.003618
# 136     0.087388  0.017478  0.017427  0.000143            1     0.017651
# 137     0.027921  0.005584  0.005567  0.000042            1     0.005572
# 138     0.094496  0.018899  0.018849  0.000177            1     0.019059
# 139     0.032031  0.006406  0.006386  0.000062            1     0.006390
# 148     0.133575  0.026715  0.026695  0.000158            1     0.026875
# 149     0.056131  0.011226  0.011212  0.000057            1     0.011227
# 150     0.144010  0.028802  0.028843  0.000225            1     0.028898
# 151     0.065513  0.013103  0.013070  0.000107            1     0.013078
# 160     0.188609  0.037722  0.037706  0.000324            1     0.037849
# 161     0.091689  0.018338  0.018334  0.000121            1     0.018354
# 162     0.202166  0.040433  0.040419  0.000190            1     0.040389
# 163     0.109357  0.021871  0.021808  0.000163            1     0.021725
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 124               50                     0              40          dynamic
# 125               20                     0              40          dynamic
# 126               62                     0              40          dynamic
# 127               27                     0              40          dynamic
# 136              200                     0              40          dynamic
# 137               87                     0              40          dynamic
# 138              251                     0              40          dynamic
# 139              119                     0              40          dynamic
# 148              777                     0              40          dynamic
# 149              375                     0              40          dynamic
# 150              978                     0              40          dynamic
# 151              539                     0              40          dynamic
# 160             1706                     0              40          dynamic
# 161              907                     0              40          dynamic
# 162             2140                     0              40          dynamic
# 163             1339                     0              40          dynamic
#
# [16 rows x 21 columns]
#                     date        octree point_type           encoder   npoints  \
# 124  2025-06-01-10:59:39  LinearOctree      Point  HilbertEncoder3D  29697591
# 125  2025-06-01-10:59:39  LinearOctree      Point  HilbertEncoder3D  29697591
# 126  2025-06-01-10:59:39  LinearOctree      Point  HilbertEncoder3D  29697591
# 127  2025-06-01-10:59:39  LinearOctree      Point  HilbertEncoder3D  29697591
# 136  2025-06-01-10:59:42  LinearOctree      Point  HilbertEncoder3D  29697591
# 137  2025-06-01-10:59:42  LinearOctree      Point  HilbertEncoder3D  29697591
# 138  2025-06-01-10:59:43  LinearOctree      Point  HilbertEncoder3D  29697591
# 139  2025-06-01-10:59:43  LinearOctree      Point  HilbertEncoder3D  29697591
# 148  2025-06-01-10:59:50  LinearOctree      Point  HilbertEncoder3D  29697591
# 149  2025-06-01-10:59:50  LinearOctree      Point  HilbertEncoder3D  29697591
# 150  2025-06-01-10:59:51  LinearOctree      Point  HilbertEncoder3D  29697591
# 151  2025-06-01-10:59:51  LinearOctree      Point  HilbertEncoder3D  29697591
# 160  2025-06-01-11:00:09  LinearOctree      Point  HilbertEncoder3D  29697591
# 161  2025-06-01-11:00:10  LinearOctree      Point  HilbertEncoder3D  29697591
# 162  2025-06-01-11:00:12  LinearOctree      Point  HilbertEncoder3D  29697591
# 163  2025-06-01-11:00:12  LinearOctree      Point  HilbertEncoder3D  29697591
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 124  neighborsPrune  Circle    0.01         10000              random  ...
# 125  neighborsPrune  Sphere    0.01         10000              random  ...
# 126  neighborsPrune  Square    0.01         10000              random  ...
# 127  neighborsPrune    Cube    0.01         10000              random  ...
# 136  neighborsPrune  Circle    0.05         10000              random  ...
# 137  neighborsPrune  Sphere    0.05         10000              random  ...
# 138  neighborsPrune  Square    0.05         10000              random  ...
# 139  neighborsPrune    Cube    0.05         10000              random  ...
# 148  neighborsPrune  Circle    0.10         10000              random  ...
# 149  neighborsPrune  Sphere    0.10         10000              random  ...
# 150  neighborsPrune  Square    0.10         10000              random  ...
# 151  neighborsPrune    Cube    0.10         10000              random  ...
# 160  neighborsPrune  Circle    0.20         10000              random  ...
# 161  neighborsPrune  Sphere    0.20         10000              random  ...
# 162  neighborsPrune  Square    0.20         10000              random  ...
# 163  neighborsPrune    Cube    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 124     0.138419  0.027684  0.027570  0.000358            1     0.027553
# 125     0.019289  0.003858  0.003853  0.000030            1     0.003929
# 126     0.146666  0.029333  0.029274  0.000248            1     0.029251
# 127     0.023641  0.004728  0.004716  0.000043            1     0.004810
# 136     0.389349  0.077870  0.077477  0.000532            1     0.078058
# 137     0.111297  0.022259  0.022249  0.000103            1     0.022323
# 138     0.408245  0.081649  0.081373  0.000522            1     0.081812
# 139     0.134091  0.026818  0.026762  0.000189            1     0.026957
# 148     0.666210  0.133242  0.133252  0.001272            1     0.133637
# 149     0.243320  0.048664  0.048593  0.000426            1     0.049013
# 150     0.711035  0.142207  0.142496  0.001008            1     0.142636
# 151     0.288396  0.057679  0.057522  0.000436            1     0.057077
# 160     1.362320  0.272465  0.272654  0.002376            1     0.272508
# 161     0.585555  0.117111  0.117261  0.001269            1     0.117638
# 162     1.480600  0.296120  0.296368  0.001667            1     0.297042
# 163     0.717297  0.143459  0.142990  0.001595            1     0.144151
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 124              442                     0              40          dynamic
# 125               66                     0              40          dynamic
# 126              505                     0              40          dynamic
# 127               73                     0              40          dynamic
# 136             6248                     0              40          dynamic
# 137             2029                     0              40          dynamic
# 138             7783                     0              40          dynamic
# 139             3229                     0              40          dynamic
# 148            20124                     0              40          dynamic
# 149             8553                     0              40          dynamic
# 150            24689                     0              40          dynamic
# 151            12686                     0              40          dynamic
# 160            64044                     0              40          dynamic
# 161            33036                     0              40          dynamic
# 162            78462                     0              40          dynamic
# 163            46857                     0              40          dynamic
#
# [16 rows x 21 columns]
#                     date        octree point_type           encoder  \
# 124  2025-06-01-12:22:44  LinearOctree      Point  HilbertEncoder3D
# 125  2025-06-01-12:22:44  LinearOctree      Point  HilbertEncoder3D
# 126  2025-06-01-12:22:48  LinearOctree      Point  HilbertEncoder3D
# 127  2025-06-01-12:22:48  LinearOctree      Point  HilbertEncoder3D
# 136  2025-06-01-12:24:06  LinearOctree      Point  HilbertEncoder3D
# 137  2025-06-01-12:24:06  LinearOctree      Point  HilbertEncoder3D
# 138  2025-06-01-12:24:18  LinearOctree      Point  HilbertEncoder3D
# 139  2025-06-01-12:24:19  LinearOctree      Point  HilbertEncoder3D
# 148  2025-06-01-12:27:23  LinearOctree      Point  HilbertEncoder3D
# 149  2025-06-01-12:27:24  LinearOctree      Point  HilbertEncoder3D
# 150  2025-06-01-12:27:50  LinearOctree      Point  HilbertEncoder3D
# 151  2025-06-01-12:27:52  LinearOctree      Point  HilbertEncoder3D
# 160  2025-06-01-12:35:20  LinearOctree      Point  HilbertEncoder3D
# 161  2025-06-01-12:35:25  LinearOctree      Point  HilbertEncoder3D
# 162  2025-06-01-12:36:33  LinearOctree      Point  HilbertEncoder3D
# 163  2025-06-01-12:36:40  LinearOctree      Point  HilbertEncoder3D
#
#        npoints       operation  kernel  radius  num_searches  \
# 124  429615314  neighborsPrune  Circle    0.01         10000
# 125  429615314  neighborsPrune  Sphere    0.01         10000
# 126  429615314  neighborsPrune  Square    0.01         10000
# 127  429615314  neighborsPrune    Cube    0.01         10000
# 136  429615314  neighborsPrune  Circle    0.05         10000
# 137  429615314  neighborsPrune  Sphere    0.05         10000
# 138  429615314  neighborsPrune  Square    0.05         10000
# 139  429615314  neighborsPrune    Cube    0.05         10000
# 148  429615314  neighborsPrune  Circle    0.10         10000
# 149  429615314  neighborsPrune  Sphere    0.10         10000
# 150  429615314  neighborsPrune  Square    0.10         10000
# 151  429615314  neighborsPrune    Cube    0.10         10000
# 160  429615314  neighborsPrune  Circle    0.20         10000
# 161  429615314  neighborsPrune  Sphere    0.20         10000
# 162  429615314  neighborsPrune  Square    0.20         10000
# 163  429615314  neighborsPrune    Cube    0.20         10000
#
#     sequential_searches  ...  accumulated       mean     median     stdev  \
# 124              random  ...     2.943690   0.588738   0.585577  0.007841
# 125              random  ...     0.052353   0.010471   0.010481  0.000093
# 126              random  ...     3.029610   0.605923   0.602280  0.006680
# 127              random  ...     0.077695   0.015539   0.015465  0.000176
# 136              random  ...     9.842550   1.968510   1.957460  0.028273
# 137              random  ...     0.329927   0.065986   0.066082  0.000406
# 138              random  ...    10.091700   2.018330   2.013210  0.017745
# 139              random  ...     0.472825   0.094565   0.094518  0.001164
# 148              random  ...    20.556600   4.111320   4.088270  0.047650
# 149              random  ...     0.964642   0.192928   0.193110  0.002391
# 150              random  ...    21.710300   4.342050   4.354250  0.052836
# 151              random  ...     1.574010   0.314802   0.315614  0.004792
# 160              random  ...    50.228700  10.045700  10.047000  0.134036
# 161              random  ...     4.106650   0.821330   0.819513  0.014275
# 162              random  ...    56.841900  11.368400  11.447000  0.371938
# 163              random  ...     5.681120   1.136220   1.121040  0.030111
#
#      used_warmup  warmup_time  avg_result_size  tolerance_percentage  \
# 124            1     0.582163            25843                     0
# 125            1     0.010713              460                     0
# 126            1     0.603893            28669                     0
# 127            1     0.015822              506                     0
# 136            1     1.983760           296234                     0
# 137            1     0.066959            14663                     0
# 138            1     2.030790           336392                     0
# 139            1     0.096071            21670                     0
# 148            1     4.055380           765061                     0
# 149            1     0.192926            59321                     0
# 150            1     4.279290           860040                     0
# 151            1     0.314186            83693                     0
# 160            1    10.056000          1949215                     0
# 161            1     0.820682           234024                     0
# 162            1    10.967100          2189463                     0
# 163            1     1.202150           323295                     0
#
#      openmp_threads  openmp_schedule
# 124              40          dynamic
# 125              40          dynamic
# 126              40          dynamic
# 127              40          dynamic
# 136              40          dynamic
# 137              40          dynamic
# 138              40          dynamic
# 139              40          dynamic
# 148              40          dynamic
# 149              40          dynamic
# 150              40          dynamic
# 151              40          dynamic
# 160              40          dynamic
# 161              40          dynamic
# 162              40          dynamic
# 163              40          dynamic
#
# [16 rows x 21 columns]
#                     date        octree point_type           encoder  \
# 124  2025-06-01-13:16:33  LinearOctree      Point  HilbertEncoder3D
# 125  2025-06-01-13:16:33  LinearOctree      Point  HilbertEncoder3D
# 126  2025-06-01-13:16:33  LinearOctree      Point  HilbertEncoder3D
# 127  2025-06-01-13:16:33  LinearOctree      Point  HilbertEncoder3D
# 136  2025-06-01-13:16:38  LinearOctree      Point  HilbertEncoder3D
# 137  2025-06-01-13:16:38  LinearOctree      Point  HilbertEncoder3D
# 138  2025-06-01-13:16:39  LinearOctree      Point  HilbertEncoder3D
# 139  2025-06-01-13:16:39  LinearOctree      Point  HilbertEncoder3D
# 148  2025-06-01-13:16:46  LinearOctree      Point  HilbertEncoder3D
# 149  2025-06-01-13:16:46  LinearOctree      Point  HilbertEncoder3D
# 150  2025-06-01-13:16:47  LinearOctree      Point  HilbertEncoder3D
# 151  2025-06-01-13:16:47  LinearOctree      Point  HilbertEncoder3D
# 160  2025-06-01-13:17:00  LinearOctree      Point  HilbertEncoder3D
# 161  2025-06-01-13:17:00  LinearOctree      Point  HilbertEncoder3D
# 162  2025-06-01-13:17:03  LinearOctree      Point  HilbertEncoder3D
# 163  2025-06-01-13:17:03  LinearOctree      Point  HilbertEncoder3D
#
#        npoints       operation  kernel  radius  num_searches  \
# 124  721810646  neighborsPrune  Circle    0.01         10000
# 125  721810646  neighborsPrune  Sphere    0.01         10000
# 126  721810646  neighborsPrune  Square    0.01         10000
# 127  721810646  neighborsPrune    Cube    0.01         10000
# 136  721810646  neighborsPrune  Circle    0.05         10000
# 137  721810646  neighborsPrune  Sphere    0.05         10000
# 138  721810646  neighborsPrune  Square    0.05         10000
# 139  721810646  neighborsPrune    Cube    0.05         10000
# 148  721810646  neighborsPrune  Circle    0.10         10000
# 149  721810646  neighborsPrune  Sphere    0.10         10000
# 150  721810646  neighborsPrune  Square    0.10         10000
# 151  721810646  neighborsPrune    Cube    0.10         10000
# 160  721810646  neighborsPrune  Circle    0.20         10000
# 161  721810646  neighborsPrune  Sphere    0.20         10000
# 162  721810646  neighborsPrune  Square    0.20         10000
# 163  721810646  neighborsPrune    Cube    0.20         10000
#
#     sequential_searches  ...  accumulated      mean    median     stdev  \
# 124              random  ...     0.424855  0.084971  0.084636  0.000985
# 125              random  ...     0.011870  0.002374  0.002365  0.000035
# 126              random  ...     0.448324  0.089665  0.089862  0.001014
# 127              random  ...     0.012374  0.002475  0.002475  0.000005
# 136              random  ...     0.767728  0.153546  0.154404  0.002210
# 137              random  ...     0.034270  0.006854  0.006857  0.000062
# 138              random  ...     0.809090  0.161818  0.162881  0.002097
# 139              random  ...     0.037541  0.007508  0.007502  0.000038
# 148              random  ...     1.187930  0.237585  0.238521  0.002818
# 149              random  ...     0.070863  0.014173  0.014263  0.000152
# 150              random  ...     1.244440  0.248889  0.250024  0.003189
# 151              random  ...     0.077073  0.015414  0.015409  0.000069
# 160              random  ...     2.021040  0.404209  0.403632  0.004570
# 161              random  ...     0.153392  0.030679  0.030618  0.000174
# 162              random  ...     2.114500  0.422900  0.423161  0.005647
# 163              random  ...     0.165352  0.033070  0.033037  0.000294
#
#      used_warmup  warmup_time  avg_result_size  tolerance_percentage  \
# 124            1     0.086133              204                     0
# 125            1     0.002443                7                     0
# 126            1     0.089972              248                     0
# 127            1     0.002550               11                     0
# 136            1     0.152732             3174                     0
# 137            1     0.006899              190                     0
# 138            1     0.160935             3847                     0
# 139            1     0.009803              274                     0
# 148            1     0.242610             9389                     0
# 149            1     0.014324              757                     0
# 150            1     0.252956            11238                     0
# 151            1     0.015470             1066                     0
# 160            1     0.407850            26521                     0
# 161            1     0.030820             2933                     0
# 162            1     0.425298            31490                     0
# 163            1     0.033104             4010                     0
#
#      openmp_threads  openmp_schedule
# 124              40          dynamic
# 125              40          dynamic
# 126              40          dynamic
# 127              40          dynamic
# 136              40          dynamic
# 137              40          dynamic
# 138              40          dynamic
# 139              40          dynamic
# 148              40          dynamic
# 149              40          dynamic
# 150              40          dynamic
# 151              40          dynamic
# 160              40          dynamic
# 161              40          dynamic
# 162              40          dynamic
# 163              40          dynamic
#
# [16 rows x 21 columns]
#                    date        octree point_type          encoder   npoints  \
# 48  2025-06-01-10:33:30  LinearOctree      Point  MortonEncoder3D  10000000
# 49  2025-06-01-10:33:30  LinearOctree      Point  MortonEncoder3D  10000000
# 50  2025-06-01-10:33:31  LinearOctree      Point  MortonEncoder3D  10000000
# 51  2025-06-01-10:33:31  LinearOctree      Point  MortonEncoder3D  10000000
# 60  2025-06-01-10:33:37  LinearOctree      Point  MortonEncoder3D  10000000
# 61  2025-06-01-10:33:37  LinearOctree      Point  MortonEncoder3D  10000000
# 62  2025-06-01-10:33:38  LinearOctree      Point  MortonEncoder3D  10000000
# 63  2025-06-01-10:33:39  LinearOctree      Point  MortonEncoder3D  10000000
# 72  2025-06-01-10:33:54  LinearOctree      Point  MortonEncoder3D  10000000
# 73  2025-06-01-10:33:55  LinearOctree      Point  MortonEncoder3D  10000000
# 74  2025-06-01-10:33:56  LinearOctree      Point  MortonEncoder3D  10000000
# 75  2025-06-01-10:33:57  LinearOctree      Point  MortonEncoder3D  10000000
# 84  2025-06-01-10:34:28  LinearOctree      Point  MortonEncoder3D  10000000
# 85  2025-06-01-10:34:29  LinearOctree      Point  MortonEncoder3D  10000000
# 86  2025-06-01-10:34:32  LinearOctree      Point  MortonEncoder3D  10000000
# 87  2025-06-01-10:34:33  LinearOctree      Point  MortonEncoder3D  10000000
#
#          operation  kernel  radius  num_searches sequential_searches  ...  \
# 48  neighborsPrune  Circle     0.5         10000              random  ...
# 49  neighborsPrune  Sphere     0.5         10000              random  ...
# 50  neighborsPrune  Square     0.5         10000              random  ...
# 51  neighborsPrune    Cube     0.5         10000              random  ...
# 60  neighborsPrune  Circle     1.0         10000              random  ...
# 61  neighborsPrune  Sphere     1.0         10000              random  ...
# 62  neighborsPrune  Square     1.0         10000              random  ...
# 63  neighborsPrune    Cube     1.0         10000              random  ...
# 72  neighborsPrune  Circle     2.0         10000              random  ...
# 73  neighborsPrune  Sphere     2.0         10000              random  ...
# 74  neighborsPrune  Square     2.0         10000              random  ...
# 75  neighborsPrune    Cube     2.0         10000              random  ...
# 84  neighborsPrune  Circle     3.0         10000              random  ...
# 85  neighborsPrune  Sphere     3.0         10000              random  ...
# 86  neighborsPrune  Square     3.0         10000              random  ...
# 87  neighborsPrune    Cube     3.0         10000              random  ...
#
#     accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 48     0.395927  0.079186  0.079101  0.000502            1     0.078869
# 49     0.127111  0.025422  0.025431  0.000117            1     0.025587
# 50     0.413684  0.082737  0.082797  0.000369            1     0.083019
# 51     0.140601  0.028120  0.028151  0.000081            1     0.028238
# 60     0.628270  0.125654  0.125750  0.000539            1     0.125609
# 61     0.289355  0.057871  0.057896  0.000165            1     0.058034
# 62     0.649943  0.129989  0.129946  0.000401            1     0.130219
# 63     0.319438  0.063888  0.063953  0.000203            1     0.064149
# 72     1.067980  0.213595  0.213930  0.000706            1     0.214143
# 73     0.660633  0.132127  0.132085  0.000384            1     0.132857
# 74     1.164720  0.232944  0.232766  0.000685            1     0.234975
# 75     0.761007  0.152201  0.152110  0.000678            1     0.152939
# 84     1.699580  0.339915  0.340412  0.000713            1     0.341377
# 85     1.175860  0.235172  0.234415  0.001268            1     0.237830
# 86     1.968210  0.393642  0.393828  0.001536            1     0.396409
# 87     1.435620  0.287123  0.287752  0.001239            1     0.289456
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 48             5221                     0              40          dynamic
# 49             2057                     0              40          dynamic
# 50             6323                     0              40          dynamic
# 51             2756                     0              40          dynamic
# 60            14950                     0              40          dynamic
# 61             8276                     0              40          dynamic
# 62            18309                     0              40          dynamic
# 63            11184                     0              40          dynamic
# 72            45407                     0              40          dynamic
# 73            32768                     0              40          dynamic
# 74            56005                     0              40          dynamic
# 75            43668                     0              40          dynamic
# 84            89734                     0              40          dynamic
# 85            71896                     0              40          dynamic
# 86           111599                     0              40          dynamic
# 87            95360                     0              40          dynamic
#
# [16 rows x 21 columns]
#                    date        octree point_type          encoder   npoints  \
# 48  2025-06-01-10:45:53  LinearOctree      Point  MortonEncoder3D  10000000
# 49  2025-06-01-10:45:53  LinearOctree      Point  MortonEncoder3D  10000000
# 50  2025-06-01-10:45:54  LinearOctree      Point  MortonEncoder3D  10000000
# 51  2025-06-01-10:45:54  LinearOctree      Point  MortonEncoder3D  10000000
# 60  2025-06-01-10:46:05  LinearOctree      Point  MortonEncoder3D  10000000
# 61  2025-06-01-10:46:06  LinearOctree      Point  MortonEncoder3D  10000000
# 62  2025-06-01-10:46:07  LinearOctree      Point  MortonEncoder3D  10000000
# 63  2025-06-01-10:46:08  LinearOctree      Point  MortonEncoder3D  10000000
# 72  2025-06-01-10:46:42  LinearOctree      Point  MortonEncoder3D  10000000
# 73  2025-06-01-10:46:43  LinearOctree      Point  MortonEncoder3D  10000000
# 74  2025-06-01-10:46:46  LinearOctree      Point  MortonEncoder3D  10000000
# 75  2025-06-01-10:46:48  LinearOctree      Point  MortonEncoder3D  10000000
# 84  2025-06-01-10:47:54  LinearOctree      Point  MortonEncoder3D  10000000
# 85  2025-06-01-10:47:57  LinearOctree      Point  MortonEncoder3D  10000000
# 86  2025-06-01-10:48:03  LinearOctree      Point  MortonEncoder3D  10000000
# 87  2025-06-01-10:48:07  LinearOctree      Point  MortonEncoder3D  10000000
#
#          operation  kernel  radius  num_searches sequential_searches  ...  \
# 48  neighborsPrune  Circle     0.5         10000              random  ...
# 49  neighborsPrune  Sphere     0.5         10000              random  ...
# 50  neighborsPrune  Square     0.5         10000              random  ...
# 51  neighborsPrune    Cube     0.5         10000              random  ...
# 60  neighborsPrune  Circle     1.0         10000              random  ...
# 61  neighborsPrune  Sphere     1.0         10000              random  ...
# 62  neighborsPrune  Square     1.0         10000              random  ...
# 63  neighborsPrune    Cube     1.0         10000              random  ...
# 72  neighborsPrune  Circle     2.0         10000              random  ...
# 73  neighborsPrune  Sphere     2.0         10000              random  ...
# 74  neighborsPrune  Square     2.0         10000              random  ...
# 75  neighborsPrune    Cube     2.0         10000              random  ...
# 84  neighborsPrune  Circle     3.0         10000              random  ...
# 85  neighborsPrune  Sphere     3.0         10000              random  ...
# 86  neighborsPrune  Square     3.0         10000              random  ...
# 87  neighborsPrune    Cube     3.0         10000              random  ...
#
#     accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 48     0.593127  0.118625  0.118386  0.000471            1     0.119249
# 49     0.166762  0.033353  0.033361  0.000249            1     0.033528
# 50     0.636166  0.127233  0.127244  0.000938            1     0.126988
# 51     0.184727  0.036945  0.037010  0.000234            1     0.037073
# 60     1.137520  0.227504  0.226772  0.002070            1     0.227156
# 61     0.410598  0.082120  0.082376  0.000724            1     0.082390
# 62     1.227640  0.245529  0.246484  0.001753            1     0.245020
# 63     0.467606  0.093521  0.093570  0.000313            1     0.093631
# 72     2.500050  0.500010  0.500566  0.001044            1     0.501002
# 73     1.223090  0.244618  0.244756  0.001146            1     0.243742
# 74     2.781450  0.556289  0.555878  0.000886            1     0.555807
# 75     1.465100  0.293021  0.293945  0.001767            1     0.291588
# 84     4.216260  0.843253  0.843032  0.002929            1     0.831945
# 85     2.552440  0.510488  0.511706  0.003152            1     0.507765
# 86     4.863780  0.972756  0.973906  0.003530            1     0.969590
# 87     3.112320  0.622463  0.620403  0.005440            1     0.618989
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 48            13370                     0              40          dynamic
# 49             5014                     0              40          dynamic
# 50            16388                     0              40          dynamic
# 51             6671                     0              40          dynamic
# 60            41890                     0              40          dynamic
# 61            20205                     0              40          dynamic
# 62            51669                     0              40          dynamic
# 63            27041                     0              40          dynamic
# 72           134263                     0              40          dynamic
# 73            80809                     0              40          dynamic
# 74           166045                     0              40          dynamic
# 75           108267                     0              40          dynamic
# 84           267895                     0              40          dynamic
# 85           179052                     0              40          dynamic
# 86           331283                     0              40          dynamic
# 87           240046                     0              40          dynamic
#
# [16 rows x 21 columns]
#                    date        octree point_type          encoder   npoints  \
# 48  2025-06-01-10:37:59  LinearOctree      Point  MortonEncoder3D  12219779
# 49  2025-06-01-10:37:59  LinearOctree      Point  MortonEncoder3D  12219779
# 50  2025-06-01-10:37:59  LinearOctree      Point  MortonEncoder3D  12219779
# 51  2025-06-01-10:37:59  LinearOctree      Point  MortonEncoder3D  12219779
# 60  2025-06-01-10:38:00  LinearOctree      Point  MortonEncoder3D  12219779
# 61  2025-06-01-10:38:00  LinearOctree      Point  MortonEncoder3D  12219779
# 62  2025-06-01-10:38:00  LinearOctree      Point  MortonEncoder3D  12219779
# 63  2025-06-01-10:38:00  LinearOctree      Point  MortonEncoder3D  12219779
# 72  2025-06-01-10:38:01  LinearOctree      Point  MortonEncoder3D  12219779
# 73  2025-06-01-10:38:01  LinearOctree      Point  MortonEncoder3D  12219779
# 74  2025-06-01-10:38:01  LinearOctree      Point  MortonEncoder3D  12219779
# 75  2025-06-01-10:38:01  LinearOctree      Point  MortonEncoder3D  12219779
# 84  2025-06-01-10:38:03  LinearOctree      Point  MortonEncoder3D  12219779
# 85  2025-06-01-10:38:03  LinearOctree      Point  MortonEncoder3D  12219779
# 86  2025-06-01-10:38:03  LinearOctree      Point  MortonEncoder3D  12219779
# 87  2025-06-01-10:38:03  LinearOctree      Point  MortonEncoder3D  12219779
#
#          operation  kernel  radius  num_searches sequential_searches  ...  \
# 48  neighborsPrune  Circle     0.5         10000              random  ...
# 49  neighborsPrune  Sphere     0.5         10000              random  ...
# 50  neighborsPrune  Square     0.5         10000              random  ...
# 51  neighborsPrune    Cube     0.5         10000              random  ...
# 60  neighborsPrune  Circle     1.0         10000              random  ...
# 61  neighborsPrune  Sphere     1.0         10000              random  ...
# 62  neighborsPrune  Square     1.0         10000              random  ...
# 63  neighborsPrune    Cube     1.0         10000              random  ...
# 72  neighborsPrune  Circle     2.0         10000              random  ...
# 73  neighborsPrune  Sphere     2.0         10000              random  ...
# 74  neighborsPrune  Square     2.0         10000              random  ...
# 75  neighborsPrune    Cube     2.0         10000              random  ...
# 84  neighborsPrune  Circle     3.0         10000              random  ...
# 85  neighborsPrune  Sphere     3.0         10000              random  ...
# 86  neighborsPrune  Square     3.0         10000              random  ...
# 87  neighborsPrune    Cube     3.0         10000              random  ...
#
#     accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 48     0.069511  0.013902  0.013839  0.000149            1     0.013904
# 49     0.016865  0.003373  0.003361  0.000031            1     0.003436
# 50     0.074320  0.014864  0.014752  0.000184            1     0.014950
# 51     0.018273  0.003655  0.003667  0.000018            1     0.003765
# 60     0.098142  0.019628  0.019565  0.000191            1     0.019726
# 61     0.031402  0.006280  0.006258  0.000049            1     0.006258
# 62     0.106765  0.021353  0.021399  0.000267            1     0.021217
# 63     0.035920  0.007184  0.007175  0.000052            1     0.007203
# 72     0.134402  0.026880  0.026908  0.000233            1     0.026694
# 73     0.056744  0.011349  0.011321  0.000054            1     0.011392
# 74     0.144357  0.028871  0.028881  0.000368            1     0.028625
# 75     0.065799  0.013160  0.013153  0.000034            1     0.013071
# 84     0.189261  0.037852  0.037870  0.000399            1     0.037400
# 85     0.092919  0.018584  0.018613  0.000133            1     0.018417
# 86     0.204204  0.040841  0.040922  0.000344            1     0.040199
# 87     0.110777  0.022155  0.022255  0.000158            1     0.021917
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 48               49                     0              40          dynamic
# 49               20                     0              40          dynamic
# 50               61                     0              40          dynamic
# 51               28                     0              40          dynamic
# ...
# 13              905                     0              40          dynamic
# 14             2121                     0              40          dynamic
# 15             1337                     0              40          dynamic
#
# [16 rows x 21 columns]
#                    date  octree point_type     encoder   npoints  \
# 0   2025-06-01-10:55:56  Octree      Point  NoEncoding  29697591
# 1   2025-06-01-10:55:56  Octree      Point  NoEncoding  29697591
# 2   2025-06-01-10:55:56  Octree      Point  NoEncoding  29697591
# 3   2025-06-01-10:55:56  Octree      Point  NoEncoding  29697591
# 4   2025-06-01-10:55:58  Octree      Point  NoEncoding  29697591
# 5   2025-06-01-10:55:58  Octree      Point  NoEncoding  29697591
# 6   2025-06-01-10:56:00  Octree      Point  NoEncoding  29697591
# 7   2025-06-01-10:56:00  Octree      Point  NoEncoding  29697591
# 8   2025-06-01-10:56:03  Octree      Point  NoEncoding  29697591
# 9   2025-06-01-10:56:04  Octree      Point  NoEncoding  29697591
# 10  2025-06-01-10:56:07  Octree      Point  NoEncoding  29697591
# 11  2025-06-01-10:56:08  Octree      Point  NoEncoding  29697591
# 12  2025-06-01-10:56:15  Octree      Point  NoEncoding  29697591
# 13  2025-06-01-10:56:19  Octree      Point  NoEncoding  29697591
# 14  2025-06-01-10:56:26  Octree      Point  NoEncoding  29697591
# 15  2025-06-01-10:56:30  Octree      Point  NoEncoding  29697591
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 0   neighborsPtr  Circle    0.01         10000              random  ...
# 1   neighborsPtr  Sphere    0.01         10000              random  ...
# 2   neighborsPtr  Square    0.01         10000              random  ...
# 3   neighborsPtr    Cube    0.01         10000              random  ...
# 4   neighborsPtr  Circle    0.05         10000              random  ...
# 5   neighborsPtr  Sphere    0.05         10000              random  ...
# 6   neighborsPtr  Square    0.05         10000              random  ...
# 7   neighborsPtr    Cube    0.05         10000              random  ...
# 8   neighborsPtr  Circle    0.10         10000              random  ...
# 9   neighborsPtr  Sphere    0.10         10000              random  ...
# 10  neighborsPtr  Square    0.10         10000              random  ...
# 11  neighborsPtr    Cube    0.10         10000              random  ...
# 12  neighborsPtr  Circle    0.20         10000              random  ...
# 13  neighborsPtr  Sphere    0.20         10000              random  ...
# 14  neighborsPtr  Square    0.20         10000              random  ...
# 15  neighborsPtr    Cube    0.20         10000              random  ...
#
#     accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 0      0.322159  0.064432  0.063721  0.001499            1     0.079042
# 1      0.058936  0.011787  0.011789  0.000123            1     0.011940
# 2      0.330408  0.066082  0.065863  0.000764            1     0.066491
# 3      0.057640  0.011528  0.011543  0.000043            1     0.011474
# 4      1.187370  0.237474  0.238123  0.001168            1     0.246093
# 5      0.412833  0.082567  0.082494  0.001043            1     0.083282
# 6      1.128060  0.225612  0.231401  0.012577            1     0.235114
# 7      0.359006  0.071801  0.071564  0.001069            1     0.073494
# 8      2.414670  0.482935  0.481782  0.005390            1     0.491773
# 9      1.057280  0.211455  0.210261  0.004333            1     0.221478
# 10     2.265150  0.453029  0.452394  0.002632            1     0.454851
# 11     1.039370  0.207873  0.208733  0.002022            1     0.211493
# 12     6.006550  1.201310  1.206830  0.018934            1     1.232560
# 13     3.286590  0.657317  0.658957  0.004626            1     0.667612
# 14     5.768030  1.153610  1.160830  0.022369            1     1.178510
# 15     3.068610  0.613722  0.613291  0.003397            1     0.632583
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0               447                     0              40          dynamic
# 1                69                     0              40          dynamic
# 2               510                     0              40          dynamic
# 3                76                     0              40          dynamic
# 4              6351                     0              40          dynamic
# 5              2019                     0              40          dynamic
# 6              7888                     0              40          dynamic
# 7              3223                     0              40          dynamic
# 8             20291                     0              40          dynamic
# 9              8606                     0              40          dynamic
# 10            24870                     0              40          dynamic
# 11            12886                     0              40          dynamic
# 12            63978                     0              40          dynamic
# 13            33560                     0              40          dynamic
# 14            78281                     0              40          dynamic
# 15            47506                     0              40          dynamic
#
# [16 rows x 21 columns]
#                    date  octree point_type     encoder    npoints  \
# 0   2025-06-01-11:05:41  Octree      Point  NoEncoding  429615314
# 1   2025-06-01-11:05:41  Octree      Point  NoEncoding  429615314
# 2   2025-06-01-11:05:48  Octree      Point  NoEncoding  429615314
# 3   2025-06-01-11:05:49  Octree      Point  NoEncoding  429615314
# 4   2025-06-01-11:06:29  Octree      Point  NoEncoding  429615314
# 5   2025-06-01-11:06:32  Octree      Point  NoEncoding  429615314
# 6   2025-06-01-11:07:13  Octree      Point  NoEncoding  429615314
# 7   2025-06-01-11:07:16  Octree      Point  NoEncoding  429615314
# 8   2025-06-01-11:08:49  Octree      Point  NoEncoding  429615314
# 9   2025-06-01-11:08:57  Octree      Point  NoEncoding  429615314
# 10  2025-06-01-11:10:28  Octree      Point  NoEncoding  429615314
# 11  2025-06-01-11:10:37  Octree      Point  NoEncoding  429615314
# 12  2025-06-01-11:14:21  Octree      Point  NoEncoding  429615314
# 13  2025-06-01-11:14:52  Octree      Point  NoEncoding  429615314
# 14  2025-06-01-11:18:39  Octree      Point  NoEncoding  429615314
# 15  2025-06-01-11:19:11  Octree      Point  NoEncoding  429615314
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 0   neighborsPtr  Circle    0.01         10000              random  ...
# 1   neighborsPtr  Sphere    0.01         10000              random  ...
# 2   neighborsPtr  Square    0.01         10000              random  ...
# 3   neighborsPtr    Cube    0.01         10000              random  ...
# 4   neighborsPtr  Circle    0.05         10000              random  ...
# 5   neighborsPtr  Sphere    0.05         10000              random  ...
# 6   neighborsPtr  Square    0.05         10000              random  ...
# 7   neighborsPtr    Cube    0.05         10000              random  ...
# 8   neighborsPtr  Circle    0.10         10000              random  ...
# 9   neighborsPtr  Sphere    0.10         10000              random  ...
# 10  neighborsPtr  Square    0.10         10000              random  ...
# 11  neighborsPtr    Cube    0.10         10000              random  ...
# 12  neighborsPtr  Circle    0.20         10000              random  ...
# 13  neighborsPtr  Sphere    0.20         10000              random  ...
# 14  neighborsPtr  Square    0.20         10000              random  ...
# 15  neighborsPtr    Cube    0.20         10000              random  ...
#
#     accumulated       mean     median     stdev  used_warmup  warmup_time  \
# 0      6.096210   1.219240   1.210480  0.024225            1     2.617670
# 1      0.156607   0.031322   0.031125  0.000403            1     0.031415
# 2      5.925380   1.185080   1.177170  0.013451            1     1.203280
# 3      0.181623   0.036325   0.033834  0.005797            1     0.030341
# 4     34.020800   6.804160   6.838490  0.114968            1     6.862700
# 5      1.980980   0.396197   0.396418  0.007344            1     0.392885
# 6     34.386900   6.877370   6.914140  0.127406            1     6.971010
# 7      1.958030   0.391606   0.387722  0.005596            1     0.393771
# 8     77.303200  15.460600  15.329200  0.264669            1    15.911900
# 9      6.875790   1.375160   1.374140  0.012700            1     1.384830
# 10    75.906600  15.181300  15.174300  0.208877            1    15.356600
# 11     6.943270   1.388650   1.386270  0.010194            1     1.384090
# 12   186.951000  37.390200  37.352300  0.296101            1    37.111100
# 13    26.482500   5.296500   5.299210  0.047367            1     5.299510
# 14   189.031000  37.806100  37.697200  0.358073            1    37.811200
# 15    26.444800   5.288970   5.289040  0.041860            1     5.306540
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0             25352                     0              40          dynamic
# 1               455                     0              40          dynamic
# 2             28127                     0              40          dynamic
# 3               501                     0              40          dynamic
# 4            288751                     0              40          dynamic
# 5             14484                     0              40          dynamic
# 6            328625                     0              40          dynamic
# 7             21388                     0              40          dynamic
# 8            750632                     0              40          dynamic
# 9             58634                     0              40          dynamic
# 10           844892                     0              40          dynamic
# 11            83089                     0              40          dynamic
# 12          1918159                     0              40          dynamic
# 13           232692                     0              40          dynamic
# 14          2155799                     0              40          dynamic
# 15           322205                     0              40          dynamic
#
# [16 rows x 21 columns]
#                    date  octree point_type     encoder    npoints  \
# 0   2025-06-01-12:49:44  Octree      Point  NoEncoding  721810646
# 1   2025-06-01-12:49:44  Octree      Point  NoEncoding  721810646
# 2   2025-06-01-12:49:44  Octree      Point  NoEncoding  721810646
# 3   2025-06-01-12:49:44  Octree      Point  NoEncoding  721810646
# 4   2025-06-01-12:49:46  Octree      Point  NoEncoding  721810646
# 5   2025-06-01-12:49:46  Octree      Point  NoEncoding  721810646
# 6   2025-06-01-12:49:48  Octree      Point  NoEncoding  721810646
# 7   2025-06-01-12:49:48  Octree      Point  NoEncoding  721810646
# 8   2025-06-01-12:49:50  Octree      Point  NoEncoding  721810646
# 9   2025-06-01-12:49:50  Octree      Point  NoEncoding  721810646
# 10  2025-06-01-12:49:53  Octree      Point  NoEncoding  721810646
# 11  2025-06-01-12:49:53  Octree      Point  NoEncoding  721810646
# 12  2025-06-01-12:49:58  Octree      Point  NoEncoding  721810646
# 13  2025-06-01-12:49:58  Octree      Point  NoEncoding  721810646
# 14  2025-06-01-12:50:03  Octree      Point  NoEncoding  721810646
# 15  2025-06-01-12:50:04  Octree      Point  NoEncoding  721810646
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 0   neighborsPtr  Circle    0.01         10000              random  ...
# 1   neighborsPtr  Sphere    0.01         10000              random  ...
# 2   neighborsPtr  Square    0.01         10000              random  ...
# 3   neighborsPtr    Cube    0.01         10000              random  ...
# 4   neighborsPtr  Circle    0.05         10000              random  ...
# 5   neighborsPtr  Sphere    0.05         10000              random  ...
# 6   neighborsPtr  Square    0.05         10000              random  ...
# 7   neighborsPtr    Cube    0.05         10000              random  ...
# 8   neighborsPtr  Circle    0.10         10000              random  ...
# 9   neighborsPtr  Sphere    0.10         10000              random  ...
# 10  neighborsPtr  Square    0.10         10000              random  ...
# 11  neighborsPtr    Cube    0.10         10000              random  ...
# 12  neighborsPtr  Circle    0.20         10000              random  ...
# 13  neighborsPtr  Sphere    0.20         10000              random  ...
# 14  neighborsPtr  Square    0.20         10000              random  ...
# 15  neighborsPtr    Cube    0.20         10000              random  ...
#
#     accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 0      1.361500  0.272299  0.248235  0.105481            1     0.867923
# 1      0.024478  0.004896  0.004918  0.000105            1     0.004929
# 2      0.677478  0.135496  0.135063  0.001343            1     0.135504
# 3      0.022736  0.004547  0.004555  0.000031            1     0.004606
# 4      1.289180  0.257836  0.255977  0.008842            1     0.276926
# 5      0.070945  0.014189  0.014214  0.000376            1     0.013763
# 6      1.232410  0.246482  0.244457  0.002732            1     0.247266
# 7      0.069720  0.013944  0.014089  0.000321            1     0.013468
# 8      2.077870  0.415573  0.413554  0.007701            1     0.420312
# 9      0.169874  0.033975  0.033319  0.002581            1     0.039040
# 10     2.058110  0.411623  0.414622  0.003985            1     0.409238
# 11     0.165781  0.033156  0.033294  0.001273            1     0.031021
# 12     3.930810  0.786161  0.780055  0.009886            1     0.796723
# 13     0.446149  0.089230  0.089902  0.002461            1     0.086728
# 14     3.961680  0.792335  0.793808  0.006532            1     0.788498
# 15     0.447254  0.089451  0.090015  0.002572            1     0.086741
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0               202                     0              40          dynamic
# 1                 7                     0              40          dynamic
# 2               247                     0              40          dynamic
# 3                11                     0              40          dynamic
# 4              3212                     0              40          dynamic
# 5               189                     0              40          dynamic
# 6              3886                     0              40          dynamic
# 7               272                     0              40          dynamic
# 8              9375                     0              40          dynamic
# 9               749                     0              40          dynamic
# 10            11228                     0              40          dynamic
# 11             1053                     0              40          dynamic
# 12            26474                     0              40          dynamic
# 13             2904                     0              40          dynamic
# 14            31445                     0              40          dynamic
# 15             3984                     0              40          dynamic
#
# [16 rows x 21 columns]
# Average Morton runtime:  0.8677
# Average Hilbert runtime: 0.9341
# /tmp/ipykernel_2472/974442997.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /tmp/ipykernel_2472/974442997.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
# log-log SUBSETS
fig = plot_avg_result_sizes_log(ALL_CLOUDS, "all", [NEIGHBORS_PTR, NEIGHBORS_PRUNE], DATA_FULL, legend_pos= (1.03,1), fsz=(8,8))
output_fig(fig, "loglog_full")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/full/Lille_0/Lille_0-2025-05-28-22:42:26.csv
# Loading latest file: out_tfg_v3/full/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-05-29-01:03:58.csv
# Skipping file with invalid timestamp format: extra_r15.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/full/5080_54400/5080_54400-2025-05-28-22:12:56.csv
# Loading latest file: out_tfg_v3/full/bildstein_station1_xyz_intensity_rgb/bildstein_station1_xyz_intensity_rgb-2025-05-28-20:49:36.csv
# Loading latest file: out_tfg_v3/full/sg27_station8_intensity_rgb/sg27_station8_intensity_rgb-2025-05-29-02:38:08.csv
# Skipping file with invalid timestamp format: extra_r025.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/full/Speulderbos_2017_TLS/Speulderbos_2017_TLS-2025-05-29-06:57:10.csv
#                    date        octree point_type           encoder   npoints  \
# 11  2025-05-29-00:24:16  LinearOctree      Point  HilbertEncoder3D  10000000
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 11  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#     accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 11      100.394  100.394  100.394      0            0  4.940656e-323
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 11            71483                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date        octree point_type           encoder   npoints  \
# 7  2025-05-29-02:37:14  LinearOctree      Point  HilbertEncoder3D  10000000
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 7  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 7      352.612  352.612  352.612      0            0  4.940656e-323
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 7           179181                     0              40          dynamic
#
# [1 rows x 21 columns]
#                    date        octree point_type           encoder   npoints  \
# 11  2025-05-28-22:34:33  LinearOctree      Point  HilbertEncoder3D  12219779
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 11  neighborsPtr  Sphere      10      12219779          sequential  ...
#
#     accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 11      36.4821  36.4821  36.4821      0            0  4.940656e-323
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 11            12587                     0              40          dynamic
#
# [1 rows x 21 columns]
#                    date        octree point_type           encoder   npoints  \
# 56  2025-05-28-21:47:18  LinearOctree      Point  HilbertEncoder3D  29697591
# 57  2025-05-28-21:47:24  LinearOctree      Point  HilbertEncoder3D  29697591
# 62  2025-05-28-21:48:38  LinearOctree      Point  HilbertEncoder3D  29697591
# 63  2025-05-28-21:49:00  LinearOctree      Point  HilbertEncoder3D  29697591
# 68  2025-05-28-21:52:36  LinearOctree      Point  HilbertEncoder3D  29697591
# 69  2025-05-28-21:53:39  LinearOctree      Point  HilbertEncoder3D  29697591
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 56  neighborsPtr  Sphere    0.01      29697591          sequential  ...
# 57  neighborsPtr    Cube    0.01      29697591          sequential  ...
# 62  neighborsPtr  Sphere    0.05      29697591          sequential  ...
# 63  neighborsPtr    Cube    0.05      29697591          sequential  ...
# 68  neighborsPtr  Sphere    0.10      29697591          sequential  ...
# 69  neighborsPtr    Cube    0.10      29697591          sequential  ...
#
#     accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 56      6.15482   6.15482   6.15482      0            0  4.940656e-323
# 57      6.51559   6.51559   6.51559      0            0  5.928788e-323
# 62     17.87300  17.87300  17.87300      0            0  4.940656e-323
# 63     22.42800  22.42800  22.42800      0            0  5.928788e-323
# 68     48.29830  48.29830  48.29830      0            0  4.940656e-323
# 69     63.38440  63.38440  63.38440      0            0  5.928788e-323
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 56               69                     0              40          dynamic
# 57               76                     0              40          dynamic
# 62             2048                     0              40          dynamic
# 63             3249                     0              40          dynamic
# 68             8617                     0              40          dynamic
# 69            12822                     0              40          dynamic
#
# [6 rows x 21 columns]
#                    date        octree point_type           encoder    npoints  \
# 19  2025-05-29-05:55:12  LinearOctree      Point  HilbertEncoder3D  429615314
# 22  2025-05-29-06:08:30  LinearOctree      Point  HilbertEncoder3D  429615314
# 25  2025-05-29-06:50:09  LinearOctree      Point  HilbertEncoder3D  429615314
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 19  neighborsPtr  Sphere   0.010     429615314          sequential  ...
# 22  neighborsPtr  Sphere   0.025     429615314          sequential  ...
# 25  neighborsPtr  Sphere   0.050     429615314          sequential  ...
#
#     accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 19      99.7746   99.7746   99.7746      0            0  4.940656e-323
# 22     330.7700  330.7700  330.7700      0            0  4.940656e-323
# 25     976.0240  976.0240  976.0240      0            0  4.940656e-323
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 19              456                     0              40          dynamic
# 22             3711                     0              40          dynamic
# 25            14526                     0              40          dynamic
#
# [3 rows x 21 columns]
#                   date        octree point_type           encoder    npoints  \
# 7  2025-05-29-07:42:42  LinearOctree      Point  HilbertEncoder3D  721810646
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 7  neighborsPtr  Sphere    0.05     721810646          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 7      160.323  160.323  160.323      0            0  4.940656e-323
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 7              198                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date        octree point_type          encoder   npoints  \
# 5  2025-05-28-23:35:49  LinearOctree      Point  MortonEncoder3D  10000000
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 5  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 5      101.583  101.583  101.583      0            0  4.940656e-323
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 5            71483                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date        octree point_type          encoder   npoints  \
# 3  2025-05-29-02:01:13  LinearOctree      Point  MortonEncoder3D  10000000
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 3  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 3      354.347  354.347  354.347      0            0  4.940656e-323
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 3           179181                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date        octree point_type          encoder   npoints  \
# 5  2025-05-28-22:24:27  LinearOctree      Point  MortonEncoder3D  12219779
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 5  neighborsPtr  Sphere      10      12219779          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 5      37.7335  37.7335  37.7335      0            0  4.940656e-323
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 5            12587                     0              40          dynamic
#
# [1 rows x 21 columns]
#                    date        octree point_type          encoder   npoints  \
# 23  2025-05-28-21:17:25  LinearOctree      Point  MortonEncoder3D  29697591
# 24  2025-05-28-21:17:31  LinearOctree      Point  MortonEncoder3D  29697591
# 29  2025-05-28-21:18:42  LinearOctree      Point  MortonEncoder3D  29697591
# 30  2025-05-28-21:19:05  LinearOctree      Point  MortonEncoder3D  29697591
# 35  2025-05-28-21:22:42  LinearOctree      Point  MortonEncoder3D  29697591
# 36  2025-05-28-21:23:46  LinearOctree      Point  MortonEncoder3D  29697591
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 23  neighborsPtr  Sphere    0.01      29697591          sequential  ...
# 24  neighborsPtr    Cube    0.01      29697591          sequential  ...
# 29  neighborsPtr  Sphere    0.05      29697591          sequential  ...
# 30  neighborsPtr    Cube    0.05      29697591          sequential  ...
# 35  neighborsPtr  Sphere    0.10      29697591          sequential  ...
# 36  neighborsPtr    Cube    0.10      29697591          sequential  ...
#
#     accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 23      5.44109   5.44109   5.44109      0            0  4.940656e-323
# 24      5.79811   5.79811   5.79811      0            0  5.928788e-323
# 29     17.74820  17.74820  17.74820      0            0  4.940656e-323
# 30     22.07170  22.07170  22.07170      0            0  5.928788e-323
# 35     48.86620  48.86620  48.86620      0            0  4.940656e-323
# 36     63.72820  63.72820  63.72820      0            0  5.928788e-323
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 23               69                     0              40          dynamic
# 24               76                     0              40          dynamic
# 29             2048                     0              40          dynamic
# 30             3249                     0              40          dynamic
# 35             8617                     0              40          dynamic
# 36            12822                     0              40          dynamic
#
# [6 rows x 21 columns]
#                    date        octree point_type          encoder    npoints  \
# 7   2025-05-29-04:10:01  LinearOctree      Point  MortonEncoder3D  429615314
# 10  2025-05-29-04:23:11  LinearOctree      Point  MortonEncoder3D  429615314
# 13  2025-05-29-05:04:15  LinearOctree      Point  MortonEncoder3D  429615314
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 7   neighborsPtr  Sphere   0.010     429615314          sequential  ...
# 10  neighborsPtr  Sphere   0.025     429615314          sequential  ...
# 13  neighborsPtr  Sphere   0.050     429615314          sequential  ...
#
#     accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 7       97.8966   97.8966   97.8966      0            0  4.940656e-323
# 10     330.3280  330.3280  330.3280      0            0  4.940656e-323
# 13     965.0540  965.0540  965.0540      0            0  4.940656e-323
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 7               456                     0              40          dynamic
# 10             3711                     0              40          dynamic
# 13            14526                     0              40          dynamic
#
# [3 rows x 21 columns]
#                   date        octree point_type          encoder    npoints  \
# 3  2025-05-29-07:24:58  LinearOctree      Point  MortonEncoder3D  721810646
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 3  neighborsPtr  Sphere    0.05     721810646          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 3      158.503  158.503  158.503      0            0  4.940656e-323
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 3              198                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type           encoder   npoints  \
# 9  2025-05-29-00:19:57  Octree      Point  HilbertEncoder3D  10000000
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 9  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 9      265.625  265.625  265.625      0            0  6.926240e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 9            71483                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type           encoder   npoints  \
# 5  2025-05-29-02:19:44  Octree      Point  HilbertEncoder3D  10000000
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 5  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 5      1051.45  1051.45  1051.45      0            0  2.245620e-315
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 5           179181                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type           encoder   npoints  \
# 9  2025-05-28-22:33:13  Octree      Point  HilbertEncoder3D  12219779
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 9  neighborsPtr  Sphere      10      12219779          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 9      46.8434  46.8434  46.8434      0            0  6.899260e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 9            12587                     0              40          dynamic
#
# [1 rows x 21 columns]
#                    date  octree point_type           encoder   npoints  \
# 48  2025-05-28-21:43:15  Octree      Point  HilbertEncoder3D  29697591
# 49  2025-05-28-21:43:21  Octree      Point  HilbertEncoder3D  29697591
# 50  2025-05-28-21:43:43  Octree      Point  HilbertEncoder3D  29697591
# 51  2025-05-28-21:44:07  Octree      Point  HilbertEncoder3D  29697591
# 52  2025-05-28-21:45:23  Octree      Point  HilbertEncoder3D  29697591
# 53  2025-05-28-21:46:58  Octree      Point  HilbertEncoder3D  29697591
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 48  neighborsPtr  Sphere    0.01      29697591          sequential  ...
# 49  neighborsPtr    Cube    0.01      29697591          sequential  ...
# 50  neighborsPtr  Sphere    0.05      29697591          sequential  ...
# 51  neighborsPtr    Cube    0.05      29697591          sequential  ...
# 52  neighborsPtr  Sphere    0.10      29697591          sequential  ...
# 53  neighborsPtr    Cube    0.10      29697591          sequential  ...
#
#     accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 48      5.70532   5.70532   5.70532      0            0  1.834900e-314
# 49      5.91943   5.91943   5.91943      0            0  1.834900e-314
# 50     21.48540  21.48540  21.48540      0            0  1.831890e-314
# 51     24.22710  24.22710  24.22710      0            0  1.831890e-314
# 52     75.87590  75.87590  75.87590      0            0  1.831890e-314
# 53     95.23890  95.23890  95.23890      0            0  1.831890e-314
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 48               69                     0              40          dynamic
# 49               76                     0              40          dynamic
# 50             2048                     0              40          dynamic
# 51             3249                     0              40          dynamic
# 52             8617                     0              40          dynamic
# 53            12822                     0              40          dynamic
#
# [6 rows x 21 columns]
#                    date  octree point_type           encoder    npoints  \
# 15  2025-05-29-05:16:43  Octree      Point  HilbertEncoder3D  429615314
# 16  2025-05-29-05:23:45  Octree      Point  HilbertEncoder3D  429615314
# 17  2025-05-29-05:51:05  Octree      Point  HilbertEncoder3D  429615314
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 15  neighborsPtr  Sphere   0.010     429615314          sequential  ...
# 16  neighborsPtr  Sphere   0.025     429615314          sequential  ...
# 17  neighborsPtr  Sphere   0.050     429615314          sequential  ...
#
#     accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 15      134.952   134.952   134.952      0            0  5.059232e-321
# 16      421.880   421.880   421.880      0            0  1.178791e-319
# 17     1639.950  1639.950  1639.950      0            0  1.178890e-319
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 15              456                     0              40          dynamic
# 16             3711                     0              40          dynamic
# 17            14526                     0              40          dynamic
#
# [3 rows x 21 columns]
#                   date  octree point_type           encoder    npoints  \
# 5  2025-05-29-07:36:54  Octree      Point  HilbertEncoder3D  721810646
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 5  neighborsPtr  Sphere    0.05     721810646          sequential  ...
#
#    accumulated    mean  median  stdev  used_warmup    warmup_time  \
# 5       162.59  162.59  162.59      0            0  5.059232e-321
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 5              198                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type          encoder   npoints  \
# 3  2025-05-28-23:31:27  Octree      Point  MortonEncoder3D  10000000
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 3  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#    accumulated    mean  median  stdev  used_warmup    warmup_time  \
# 3       273.66  273.66  273.66      0            0  6.926240e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 3            71483                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type          encoder   npoints  \
# 1  2025-05-29-01:43:47  Octree      Point  MortonEncoder3D  10000000
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 1  neighborsPtr  Sphere       3      10000000          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 1      1037.23  1037.23  1037.23      0            0  6.903090e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 1           179181                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type          encoder   npoints  \
# 3  2025-05-28-22:23:05  Octree      Point  MortonEncoder3D  12219779
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 3  neighborsPtr  Sphere      10      12219779          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 3      49.1982  49.1982  49.1982      0            0  6.899260e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 3            12587                     0              40          dynamic
#
# [1 rows x 21 columns]
#                    date  octree point_type          encoder   npoints  \
# 15  2025-05-28-21:13:11  Octree      Point  MortonEncoder3D  29697591
# 16  2025-05-28-21:13:17  Octree      Point  MortonEncoder3D  29697591
# 17  2025-05-28-21:13:40  Octree      Point  MortonEncoder3D  29697591
# 18  2025-05-28-21:14:05  Octree      Point  MortonEncoder3D  29697591
# 19  2025-05-28-21:15:25  Octree      Point  MortonEncoder3D  29697591
# 20  2025-05-28-21:17:07  Octree      Point  MortonEncoder3D  29697591
#
#        operation  kernel  radius  num_searches sequential_searches  ...  \
# 15  neighborsPtr  Sphere    0.01      29697591          sequential  ...
# 16  neighborsPtr    Cube    0.01      29697591          sequential  ...
# 17  neighborsPtr  Sphere    0.05      29697591          sequential  ...
# 18  neighborsPtr    Cube    0.05      29697591          sequential  ...
# 19  neighborsPtr  Sphere    0.10      29697591          sequential  ...
# 20  neighborsPtr    Cube    0.10      29697591          sequential  ...
#
#     accumulated       mean     median  stdev  used_warmup    warmup_time  \
# 15      5.66571    5.66571    5.66571      0            0  6.923310e-310
# 16      5.87971    5.87971    5.87971      0            0  6.923310e-310
# 17     23.29630   23.29630   23.29630      0            0  6.923310e-310
# 18     25.06120   25.06120   25.06120      0            0  6.923310e-310
# 19     79.93530   79.93530   79.93530      0            0  6.923310e-310
# 20    101.92400  101.92400  101.92400      0            0  6.923310e-310
#
#     avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 15               69                     0              40          dynamic
# 16               76                     0              40          dynamic
# 17             2048                     0              40          dynamic
# 18             3249                     0              40          dynamic
# 19             8617                     0              40          dynamic
# 20            12822                     0              40          dynamic
#
# [6 rows x 21 columns]
#                   date  octree point_type          encoder    npoints  \
# 3  2025-05-29-03:31:04  Octree      Point  MortonEncoder3D  429615314
# 4  2025-05-29-03:38:15  Octree      Point  MortonEncoder3D  429615314
# 5  2025-05-29-04:05:59  Octree      Point  MortonEncoder3D  429615314
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 3  neighborsPtr  Sphere   0.010     429615314          sequential  ...
# 4  neighborsPtr  Sphere   0.025     429615314          sequential  ...
# 5  neighborsPtr  Sphere   0.050     429615314          sequential  ...
#
#    accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 3      142.757   142.757   142.757      0            0  6.951090e-310
# 4      431.047   431.047   431.047      0            0  6.951090e-310
# 5     1663.720  1663.720  1663.720      0            0  6.951090e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 3              456                     0              40          dynamic
# 4             3711                     0              40          dynamic
# 5            14526                     0              40          dynamic
#
# [3 rows x 21 columns]
#                   date  octree point_type          encoder    npoints  \
# 1  2025-05-29-07:19:15  Octree      Point  MortonEncoder3D  721810646
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 1  neighborsPtr  Sphere    0.05     721810646          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 1      166.168  166.168  166.168      0            0  6.942820e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 1              198                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type     encoder   npoints     operation  \
# 0  2025-05-28-22:48:00  Octree      Point  NoEncoding  10000000  neighborsPtr
#
#    kernel  radius  num_searches sequential_searches  ...  accumulated  \
# 0  Sphere       3      10000000          sequential  ...      329.062
#
#       mean   median  stdev  used_warmup    warmup_time  avg_result_size  \
# 0  329.062  329.062      0            0  6.926240e-310            71483
#
#    tolerance_percentage  openmp_threads  openmp_schedule
# 0                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type     encoder   npoints     operation  \
# 0  2025-05-29-01:26:27  Octree      Point  NoEncoding  10000000  neighborsPtr
#
#    kernel  radius  num_searches sequential_searches  ...  accumulated    mean  \
# 0  Sphere       3      10000000          sequential  ...       1344.2  1344.2
#
#    median  stdev  used_warmup    warmup_time  avg_result_size  \
# 0  1344.2      0            0  6.903090e-310           179181
#
#    tolerance_percentage  openmp_threads  openmp_schedule
# 0                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type     encoder   npoints     operation  \
# 0  2025-05-28-22:14:16  Octree      Point  NoEncoding  12219779  neighborsPtr
#
#    kernel  radius  num_searches sequential_searches  ...  accumulated  \
# 0  Sphere      10      12219779          sequential  ...      72.8218
#
#       mean   median  stdev  used_warmup    warmup_time  avg_result_size  \
# 0  72.8218  72.8218      0            0  6.899260e-310            12587
#
#    tolerance_percentage  openmp_threads  openmp_schedule
# 0                     0              40          dynamic
#
# [1 rows x 21 columns]
#                   date  octree point_type     encoder   npoints     operation  \
# 0  2025-05-28-20:49:54  Octree      Point  NoEncoding  29697591  neighborsPtr
# 1  2025-05-28-20:50:00  Octree      Point  NoEncoding  29697591  neighborsPtr
# 2  2025-05-28-20:50:25  Octree      Point  NoEncoding  29697591  neighborsPtr
# 3  2025-05-28-20:50:54  Octree      Point  NoEncoding  29697591  neighborsPtr
# 4  2025-05-28-20:52:22  Octree      Point  NoEncoding  29697591  neighborsPtr
# 5  2025-05-28-20:54:11  Octree      Point  NoEncoding  29697591  neighborsPtr
#
#    kernel  radius  num_searches sequential_searches  ...  accumulated  \
# 0  Sphere    0.01      29697591          sequential  ...      6.60645
# 1    Cube    0.01      29697591          sequential  ...      5.99843
# 2  Sphere    0.05      29697591          sequential  ...     24.97620
# 3    Cube    0.05      29697591          sequential  ...     28.08550
# 4  Sphere    0.10      29697591          sequential  ...     88.22680
# 5    Cube    0.10      29697591          sequential  ...    109.47400
#
#         mean     median  stdev  used_warmup    warmup_time  avg_result_size  \
# 0    6.60645    6.60645      0            0  6.923260e-310               69
# 1    5.99843    5.99843      0            0  6.923260e-310               76
# 2   24.97620   24.97620      0            0  6.923260e-310             2048
# 3   28.08550   28.08550      0            0  6.923260e-310             3249
# 4   88.22680   88.22680      0            0  6.923260e-310             8617
# 5  109.47400  109.47400      0            0  6.923260e-310            12822
#
#    tolerance_percentage  openmp_threads  openmp_schedule
# 0                     0              40          dynamic
# 1                     0              40          dynamic
# 2                     0              40          dynamic
# 3                     0              40          dynamic
# 4                     0              40          dynamic
# 5                     0              40          dynamic
#
# [6 rows x 21 columns]
#                   date  octree point_type     encoder    npoints  \
# 0  2025-05-29-02:44:45  Octree      Point  NoEncoding  429615314
# 1  2025-05-29-02:53:12  Octree      Point  NoEncoding  429615314
# 2  2025-05-29-03:24:29  Octree      Point  NoEncoding  429615314
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 0  neighborsPtr  Sphere   0.010     429615314          sequential  ...
# 1  neighborsPtr  Sphere   0.025     429615314          sequential  ...
# 2  neighborsPtr  Sphere   0.050     429615314          sequential  ...
#
#    accumulated      mean    median  stdev  used_warmup    warmup_time  \
# 0      178.560   178.560   178.560      0            0  6.951090e-310
# 1      506.645   506.645   506.645      0            0  6.951090e-310
# 2     1877.240  1877.240  1877.240      0            0  6.951090e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0              456                     0              40          dynamic
# 1             3711                     0              40          dynamic
# 2            14526                     0              40          dynamic
#
# [3 rows x 21 columns]
#                   date  octree point_type     encoder    npoints  \
# 0  2025-05-29-07:08:18  Octree      Point  NoEncoding  721810646
#
#       operation  kernel  radius  num_searches sequential_searches  ...  \
# 0  neighborsPtr  Sphere    0.05     721810646          sequential  ...
#
#    accumulated     mean   median  stdev  used_warmup    warmup_time  \
# 0      182.111  182.111  182.111      0            0  6.942820e-310
#
#    avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0              198                     0              40          dynamic
#
# [1 rows x 21 columns]
# Average Morton runtime:  336.1198
# Average Hilbert runtime: 333.6733
# /tmp/ipykernel_2472/974442997.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /tmp/ipykernel_2472/974442997.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
# log-log SUBSETS
fig = plot_avg_result_sizes_log(ALL_CLOUDS, "all", [NEIGHBORS_PTR, NEIGHBORS, NEIGHBORS_PRUNE, NEIGHBORS_STRUCT], DATA_SUBSET, types_info=TYPES_INFO_OPERATIONS, legend_pos= (0.91,1),legend_title=r"Algoritmo de búsqueda")
output_fig(fig, "loglog_subsets_algos")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/subset/Lille_0/Lille_0-2025-06-01-10:30:28.csv
# Loading latest file: out_tfg_v3/subset/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-06-01-10:38:28.csv
# Loading latest file: out_tfg_v3/subset/5080_54400/5080_54400-2025-06-01-10:37:30.csv
# Loading latest file: out_tfg_v3/subset/bildstein_station1_xyz_intensity_rgb/bildstein_station1_xyz_intensity_rgb-2025-06-01-10:55:38.csv
# Loading latest file: out_tfg_v3/subset/sg27_station8_intensity_rgb/sg27_station8_intensity_rgb-2025-06-01-11:00:41.csv
# Skipping file with invalid timestamp format: extra.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/subset/Speulderbos_2017_TLS/Speulderbos_2017_TLS-2025-06-01-12:43:03.csv
#                     date  octree point_type           encoder   npoints  \
# 0    2025-06-01-10:30:33  Octree      Point        NoEncoding  10000000
# 1    2025-06-01-10:30:34  Octree      Point        NoEncoding  10000000
# 2    2025-06-01-10:30:35  Octree      Point        NoEncoding  10000000
# 3    2025-06-01-10:30:35  Octree      Point        NoEncoding  10000000
# 4    2025-06-01-10:30:37  Octree      Point        NoEncoding  10000000
# 5    2025-06-01-10:30:39  Octree      Point        NoEncoding  10000000
# 6    2025-06-01-10:30:41  Octree      Point        NoEncoding  10000000
# 7    2025-06-01-10:30:42  Octree      Point        NoEncoding  10000000
# 8    2025-06-01-10:30:48  Octree      Point        NoEncoding  10000000
# 9    2025-06-01-10:30:52  Octree      Point        NoEncoding  10000000
# 10   2025-06-01-10:30:58  Octree      Point        NoEncoding  10000000
# 11   2025-06-01-10:31:03  Octree      Point        NoEncoding  10000000
# 12   2025-06-01-10:31:13  Octree      Point        NoEncoding  10000000
# 13   2025-06-01-10:31:22  Octree      Point        NoEncoding  10000000
# 14   2025-06-01-10:31:33  Octree      Point        NoEncoding  10000000
# 15   2025-06-01-10:31:43  Octree      Point        NoEncoding  10000000
# 28   2025-06-01-10:32:23  Octree      Point   MortonEncoder3D  10000000
# 29   2025-06-01-10:32:23  Octree      Point   MortonEncoder3D  10000000
# 30   2025-06-01-10:32:24  Octree      Point   MortonEncoder3D  10000000
# 31   2025-06-01-10:32:25  Octree      Point   MortonEncoder3D  10000000
# 32   2025-06-01-10:32:27  Octree      Point   MortonEncoder3D  10000000
# 33   2025-06-01-10:32:28  Octree      Point   MortonEncoder3D  10000000
# 34   2025-06-01-10:32:30  Octree      Point   MortonEncoder3D  10000000
# 35   2025-06-01-10:32:31  Octree      Point   MortonEncoder3D  10000000
# 36   2025-06-01-10:32:37  Octree      Point   MortonEncoder3D  10000000
# 37   2025-06-01-10:32:40  Octree      Point   MortonEncoder3D  10000000
# 38   2025-06-01-10:32:46  Octree      Point   MortonEncoder3D  10000000
# 39   2025-06-01-10:32:50  Octree      Point   MortonEncoder3D  10000000
# 40   2025-06-01-10:33:00  Octree      Point   MortonEncoder3D  10000000
# 41   2025-06-01-10:33:09  Octree      Point   MortonEncoder3D  10000000
# 42   2025-06-01-10:33:19  Octree      Point   MortonEncoder3D  10000000
# 43   2025-06-01-10:33:28  Octree      Point   MortonEncoder3D  10000000
# 104  2025-06-01-10:35:14  Octree      Point  HilbertEncoder3D  10000000
# 105  2025-06-01-10:35:15  Octree      Point  HilbertEncoder3D  10000000
# 106  2025-06-01-10:35:15  Octree      Point  HilbertEncoder3D  10000000
# 107  2025-06-01-10:35:16  Octree      Point  HilbertEncoder3D  10000000
# 108  2025-06-01-10:35:18  Octree      Point  HilbertEncoder3D  10000000
# 109  2025-06-01-10:35:19  Octree      Point  HilbertEncoder3D  10000000
# 110  2025-06-01-10:35:21  Octree      Point  HilbertEncoder3D  10000000
# 111  2025-06-01-10:35:22  Octree      Point  HilbertEncoder3D  10000000
# 112  2025-06-01-10:35:26  Octree      Point  HilbertEncoder3D  10000000
# 113  2025-06-01-10:35:30  Octree      Point  HilbertEncoder3D  10000000
# 114  2025-06-01-10:35:34  Octree      Point  HilbertEncoder3D  10000000
# 115  2025-06-01-10:35:37  Octree      Point  HilbertEncoder3D  10000000
# 116  2025-06-01-10:35:46  Octree      Point  HilbertEncoder3D  10000000
# 117  2025-06-01-10:35:53  Octree      Point  HilbertEncoder3D  10000000
# 118  2025-06-01-10:36:01  Octree      Point  HilbertEncoder3D  10000000
# 119  2025-06-01-10:36:08  Octree      Point  HilbertEncoder3D  10000000
#
#         operation  kernel  radius  num_searches sequential_searches  ...  \
# 0    neighborsPtr  Circle     0.5         10000              random  ...
# 1    neighborsPtr  Sphere     0.5         10000              random  ...
# 2    neighborsPtr  Square     0.5         10000              random  ...
# 3    neighborsPtr    Cube     0.5         10000              random  ...
# 4    neighborsPtr  Circle     1.0         10000              random  ...
# 5    neighborsPtr  Sphere     1.0         10000              random  ...
# 6    neighborsPtr  Square     1.0         10000              random  ...
# 7    neighborsPtr    Cube     1.0         10000              random  ...
# 8    neighborsPtr  Circle     2.0         10000              random  ...
# 9    neighborsPtr  Sphere     2.0         10000              random  ...
# 10   neighborsPtr  Square     2.0         10000              random  ...
# 11   neighborsPtr    Cube     2.0         10000              random  ...
# 12   neighborsPtr  Circle     3.0         10000              random  ...
# 13   neighborsPtr  Sphere     3.0         10000              random  ...
# 14   neighborsPtr  Square     3.0         10000              random  ...
# 15   neighborsPtr    Cube     3.0         10000              random  ...
# 28   neighborsPtr  Circle     0.5         10000              random  ...
# 29   neighborsPtr  Sphere     0.5         10000              random  ...
# 30   neighborsPtr  Square     0.5         10000              random  ...
# 31   neighborsPtr    Cube     0.5         10000              random  ...
# 32   neighborsPtr  Circle     1.0         10000              random  ...
# 33   neighborsPtr  Sphere     1.0         10000              random  ...
# 34   neighborsPtr  Square     1.0         10000              random  ...
# 35   neighborsPtr    Cube     1.0         10000              random  ...
# 36   neighborsPtr  Circle     2.0         10000              random  ...
# 37   neighborsPtr  Sphere     2.0         10000              random  ...
# 38   neighborsPtr  Square     2.0         10000              random  ...
# 39   neighborsPtr    Cube     2.0         10000              random  ...
# 40   neighborsPtr  Circle     3.0         10000              random  ...
# 41   neighborsPtr  Sphere     3.0         10000              random  ...
# 42   neighborsPtr  Square     3.0         10000              random  ...
# 43   neighborsPtr    Cube     3.0         10000              random  ...
# 104  neighborsPtr  Circle     0.5         10000              random  ...
# 105  neighborsPtr  Sphere     0.5         10000              random  ...
# 106  neighborsPtr  Square     0.5         10000              random  ...
# 107  neighborsPtr    Cube     0.5         10000              random  ...
# 108  neighborsPtr  Circle     1.0         10000              random  ...
# 109  neighborsPtr  Sphere     1.0         10000              random  ...
# 110  neighborsPtr  Square     1.0         10000              random  ...
# 111  neighborsPtr    Cube     1.0         10000              random  ...
# 112  neighborsPtr  Circle     2.0         10000              random  ...
# 113  neighborsPtr  Sphere     2.0         10000              random  ...
# 114  neighborsPtr  Square     2.0         10000              random  ...
# 115  neighborsPtr    Cube     2.0         10000              random  ...
# 116  neighborsPtr  Circle     3.0         10000              random  ...
# 117  neighborsPtr  Sphere     3.0         10000              random  ...
# 118  neighborsPtr  Square     3.0         10000              random  ...
# 119  neighborsPtr    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 0       1.025790  0.205159  0.200737  0.010707            1     0.250646
# 1       0.438506  0.087701  0.087894  0.002265            1     0.088889
# 2       0.914081  0.182816  0.183242  0.002526            1     0.185088
# 3       0.398195  0.079639  0.079593  0.000747            1     0.080556
# 4       1.882190  0.376437  0.377338  0.002988            1     0.381734
# 5       1.129330  0.225866  0.226189  0.003142            1     0.227260
# 6       1.877670  0.375534  0.375579  0.002510            1     0.375041
# 7       1.155240  0.231048  0.231322  0.002078            1     0.230449
# 8       4.764630  0.952927  0.949767  0.010262            1     0.955219
# 9       3.683620  0.736725  0.740616  0.008378            1     0.732900
# 10      4.692120  0.938424  0.939608  0.004316            1     0.952964
# 11      3.814690  0.762937  0.757835  0.012602            1     0.753638
# 12      8.693210  1.738640  1.741780  0.011196            1     1.738890
# 13      7.521360  1.504270  1.510550  0.016080            1     1.504980
# 14      9.012820  1.802560  1.803880  0.009490            1     1.816360
# 15      7.987870  1.597570  1.601890  0.018200            1     1.610510
# 28      0.863563  0.172713  0.171412  0.003110            1     0.179833
# 29      0.334813  0.066963  0.067115  0.000780            1     0.068681
# 30      0.821025  0.164205  0.163962  0.000867            1     0.164603
# 31      0.319542  0.063908  0.063817  0.000625            1     0.064808
# 32      1.756000  0.351200  0.349754  0.002686            1     0.356414
# 33      0.969216  0.193843  0.193844  0.002487            1     0.198386
# 34      1.702470  0.340495  0.340873  0.000923            1     0.341513
# 35      0.933992  0.186798  0.186531  0.001297            1     0.188650
# 36      4.552940  0.910589  0.911886  0.004474            1     0.918286
# 37      3.258630  0.651726  0.649345  0.005432            1     0.660812
# 38      4.596330  0.919265  0.919121  0.001523            1     0.921559
# 39      3.307120  0.661424  0.661004  0.004316            1     0.666574
# 40      8.540190  1.708040  1.706880  0.006044            1     1.719960
# 41      6.907880  1.381580  1.379370  0.010952            1     1.393100
# 42      8.860120  1.772020  1.775410  0.008184            1     1.775650
# 43      7.144380  1.428880  1.422620  0.014103            1     1.443560
# 104     0.742275  0.148455  0.148511  0.002512            1     0.153193
# 105     0.298519  0.059704  0.059626  0.000340            1     0.060290
# 106     0.723495  0.144699  0.145174  0.001699            1     0.143745
# 107     0.292132  0.058426  0.058449  0.000134            1     0.058867
# 108     1.580390  0.316077  0.318002  0.003617            1     0.316372
# 109     0.890576  0.178115  0.177867  0.001060            1     0.180609
# 110     1.545850  0.309170  0.309902  0.002293            1     0.306213
# 111     0.855518  0.171104  0.175011  0.006254            1     0.176769
# 112     3.760510  0.752102  0.755242  0.006525            1     0.761777
# 113     2.781150  0.556229  0.555427  0.003408            1     0.564051
# 114     3.740990  0.748198  0.749633  0.004651            1     0.747108
# 115     2.809290  0.561857  0.563295  0.003675            1     0.566817
# 116     6.912500  1.382500  1.384690  0.005564            1     1.387960
# 117     5.748650  1.149730  1.152080  0.005692            1     1.158130
# 118     7.073210  1.414640  1.415480  0.005203            1     1.409910
# 119     5.918630  1.183730  1.185060  0.004349            1     1.188640
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0               5205                     0              40          dynamic
# 1               2052                     0              40          dynamic
# 2               6303                     0              40          dynamic
# 3               2747                     0              40          dynamic
# 4              14872                     0              40          dynamic
# 5               8241                     0              40          dynamic
# 6              18212                     0              40          dynamic
# 7              11133                     0              40          dynamic
# 8              45063                     0              40          dynamic
# 9              32557                     0              40          dynamic
# 10             55558                     0              40          dynamic
# 11             43331                     0              40          dynamic
# 12             88869                     0              40          dynamic
# 13             71234                     0              40          dynamic
# 14            110508                     0              40          dynamic
# 15             94396                     0              40          dynamic
# 28              5221                     0              40          dynamic
# 29              2057                     0              40          dynamic
# 30              6323                     0              40          dynamic
# 31              2756                     0              40          dynamic
# 32             14950                     0              40          dynamic
# 33              8276                     0              40          dynamic
# 34             18309                     0              40          dynamic
# 35             11184                     0              40          dynamic
# 36             45407                     0              40          dynamic
# 37             32768                     0              40          dynamic
# 38             56005                     0              40          dynamic
# 39             43668                     0              40          dynamic
# 40             89734                     0              40          dynamic
# 41             71896                     0              40          dynamic
# 42            111599                     0              40          dynamic
# 43             95360                     0              40          dynamic
# 104             5148                     0              40          dynamic
# 105             2063                     0              40          dynamic
# 106             6241                     0              40          dynamic
# 107             2761                     0              40          dynamic
# 108            14817                     0              40          dynamic
# 109             8296                     0              40          dynamic
# 110            18151                     0              40          dynamic
# 111            11199                     0              40          dynamic
# 112            45183                     0              40          dynamic
# 113            32827                     0              40          dynamic
# 114            55765                     0              40          dynamic
# 115            43695                     0              40          dynamic
# 116            89398                     0              40          dynamic
# 117            71947                     0              40          dynamic
# 118           111210                     0              40          dynamic
# 119            95296                     0              40          dynamic
#
# [48 rows x 21 columns]
#                     date  octree point_type           encoder   npoints  \
# 0    2025-06-01-10:38:34  Octree      Point        NoEncoding  10000000
# 1    2025-06-01-10:38:35  Octree      Point        NoEncoding  10000000
# 2    2025-06-01-10:38:38  Octree      Point        NoEncoding  10000000
# 3    2025-06-01-10:38:39  Octree      Point        NoEncoding  10000000
# 4    2025-06-01-10:38:45  Octree      Point        NoEncoding  10000000
# 5    2025-06-01-10:38:48  Octree      Point        NoEncoding  10000000
# 6    2025-06-01-10:38:54  Octree      Point        NoEncoding  10000000
# 7    2025-06-01-10:38:57  Octree      Point        NoEncoding  10000000
# 8    2025-06-01-10:39:13  Octree      Point        NoEncoding  10000000
# 9    2025-06-01-10:39:23  Octree      Point        NoEncoding  10000000
# 10   2025-06-01-10:39:40  Octree      Point        NoEncoding  10000000
# 11   2025-06-01-10:39:51  Octree      Point        NoEncoding  10000000
# 12   2025-06-01-10:40:21  Octree      Point        NoEncoding  10000000
# 13   2025-06-01-10:40:43  Octree      Point        NoEncoding  10000000
# 14   2025-06-01-10:41:15  Octree      Point        NoEncoding  10000000
# 15   2025-06-01-10:41:39  Octree      Point        NoEncoding  10000000
# 28   2025-06-01-10:43:13  Octree      Point   MortonEncoder3D  10000000
# 29   2025-06-01-10:43:14  Octree      Point   MortonEncoder3D  10000000
# 30   2025-06-01-10:43:16  Octree      Point   MortonEncoder3D  10000000
# 31   2025-06-01-10:43:17  Octree      Point   MortonEncoder3D  10000000
# 32   2025-06-01-10:43:22  Octree      Point   MortonEncoder3D  10000000
# 33   2025-06-01-10:43:25  Octree      Point   MortonEncoder3D  10000000
# 34   2025-06-01-10:43:30  Octree      Point   MortonEncoder3D  10000000
# 35   2025-06-01-10:43:33  Octree      Point   MortonEncoder3D  10000000
# 36   2025-06-01-10:43:48  Octree      Point   MortonEncoder3D  10000000
# 37   2025-06-01-10:43:58  Octree      Point   MortonEncoder3D  10000000
# 38   2025-06-01-10:44:13  Octree      Point   MortonEncoder3D  10000000
# 39   2025-06-01-10:44:21  Octree      Point   MortonEncoder3D  10000000
# 40   2025-06-01-10:44:47  Octree      Point   MortonEncoder3D  10000000
# 41   2025-06-01-10:45:05  Octree      Point   MortonEncoder3D  10000000
# 42   2025-06-01-10:45:31  Octree      Point   MortonEncoder3D  10000000
# 43   2025-06-01-10:45:49  Octree      Point   MortonEncoder3D  10000000
# 104  2025-06-01-10:49:35  Octree      Point  HilbertEncoder3D  10000000
# 105  2025-06-01-10:49:36  Octree      Point  HilbertEncoder3D  10000000
# 106  2025-06-01-10:49:38  Octree      Point  HilbertEncoder3D  10000000
# 107  2025-06-01-10:49:39  Octree      Point  HilbertEncoder3D  10000000
# 108  2025-06-01-10:49:44  Octree      Point  HilbertEncoder3D  10000000
# 109  2025-06-01-10:49:47  Octree      Point  HilbertEncoder3D  10000000
# 110  2025-06-01-10:49:52  Octree      Point  HilbertEncoder3D  10000000
# 111  2025-06-01-10:49:54  Octree      Point  HilbertEncoder3D  10000000
# 112  2025-06-01-10:50:09  Octree      Point  HilbertEncoder3D  10000000
# 113  2025-06-01-10:50:18  Octree      Point  HilbertEncoder3D  10000000
# 114  2025-06-01-10:50:34  Octree      Point  HilbertEncoder3D  10000000
# 115  2025-06-01-10:50:44  Octree      Point  HilbertEncoder3D  10000000
# 116  2025-06-01-10:51:11  Octree      Point  HilbertEncoder3D  10000000
# 117  2025-06-01-10:51:29  Octree      Point  HilbertEncoder3D  10000000
# 118  2025-06-01-10:51:56  Octree      Point  HilbertEncoder3D  10000000
# 119  2025-06-01-10:52:14  Octree      Point  HilbertEncoder3D  10000000
#
#         operation  kernel  radius  num_searches sequential_searches  ...  \
# 0    neighborsPtr  Circle     0.5         10000              random  ...
# 1    neighborsPtr  Sphere     0.5         10000              random  ...
# 2    neighborsPtr  Square     0.5         10000              random  ...
# 3    neighborsPtr    Cube     0.5         10000              random  ...
# 4    neighborsPtr  Circle     1.0         10000              random  ...
# 5    neighborsPtr  Sphere     1.0         10000              random  ...
# 6    neighborsPtr  Square     1.0         10000              random  ...
# 7    neighborsPtr    Cube     1.0         10000              random  ...
# 8    neighborsPtr  Circle     2.0         10000              random  ...
# 9    neighborsPtr  Sphere     2.0         10000              random  ...
# 10   neighborsPtr  Square     2.0         10000              random  ...
# 11   neighborsPtr    Cube     2.0         10000              random  ...
# 12   neighborsPtr  Circle     3.0         10000              random  ...
# 13   neighborsPtr  Sphere     3.0         10000              random  ...
# 14   neighborsPtr  Square     3.0         10000              random  ...
# 15   neighborsPtr    Cube     3.0         10000              random  ...
# 28   neighborsPtr  Circle     0.5         10000              random  ...
# 29   neighborsPtr  Sphere     0.5         10000              random  ...
# 30   neighborsPtr  Square     0.5         10000              random  ...
# 31   neighborsPtr    Cube     0.5         10000              random  ...
# 32   neighborsPtr  Circle     1.0         10000              random  ...
# 33   neighborsPtr  Sphere     1.0         10000              random  ...
# 34   neighborsPtr  Square     1.0         10000              random  ...
# 35   neighborsPtr    Cube     1.0         10000              random  ...
# 36   neighborsPtr  Circle     2.0         10000              random  ...
# 37   neighborsPtr  Sphere     2.0         10000              random  ...
# 38   neighborsPtr  Square     2.0         10000              random  ...
# 39   neighborsPtr    Cube     2.0         10000              random  ...
# 40   neighborsPtr  Circle     3.0         10000              random  ...
# 41   neighborsPtr  Sphere     3.0         10000              random  ...
# 42   neighborsPtr  Square     3.0         10000              random  ...
# 43   neighborsPtr    Cube     3.0         10000              random  ...
# 104  neighborsPtr  Circle     0.5         10000              random  ...
# 105  neighborsPtr  Sphere     0.5         10000              random  ...
# 106  neighborsPtr  Square     0.5         10000              random  ...
# 107  neighborsPtr    Cube     0.5         10000              random  ...
# 108  neighborsPtr  Circle     1.0         10000              random  ...
# 109  neighborsPtr  Sphere     1.0         10000              random  ...
# 110  neighborsPtr  Square     1.0         10000              random  ...
# 111  neighborsPtr    Cube     1.0         10000              random  ...
# 112  neighborsPtr  Circle     2.0         10000              random  ...
# 113  neighborsPtr  Sphere     2.0         10000              random  ...
# 114  neighborsPtr  Square     2.0         10000              random  ...
# 115  neighborsPtr    Cube     2.0         10000              random  ...
# 116  neighborsPtr  Circle     3.0         10000              random  ...
# 117  neighborsPtr  Sphere     3.0         10000              random  ...
# 118  neighborsPtr  Square     3.0         10000              random  ...
# 119  neighborsPtr    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 0       2.274560  0.454912  0.447764  0.020720            1     0.531981
# 1       0.816164  0.163233  0.163578  0.003404            1     0.170857
# 2       2.102960  0.420591  0.422880  0.004190            1     0.429605
# 3       0.795293  0.159059  0.157683  0.003831            1     0.159071
# 4       5.091840  1.018370  1.022930  0.020297            1     1.058390
# 5       2.465530  0.493106  0.494797  0.009779            1     0.498947
# 6       4.874460  0.974891  0.977288  0.008111            1     0.994980
# 7       2.476830  0.495367  0.495745  0.004123            1     0.495975
# 8      13.382600  2.676520  2.682320  0.018312            1     2.697600
# 9       8.693500  1.738700  1.750770  0.017894            1     1.753690
# 10     13.664800  2.732960  2.741990  0.016291            1     2.752660
# 11      9.183390  1.836680  1.832490  0.011809            1     1.839890
# 12     24.992100  4.998410  5.012840  0.024706            1     5.027340
# 13     18.700500  3.740100  3.731580  0.020731            1     3.723150
# 14     26.279500  5.255910  5.254610  0.024477            1     5.256530
# 15     20.014200  4.002850  3.998100  0.016428            1     4.010460
# 28      1.902920  0.380584  0.380676  0.007046            1     0.405077
# 29      0.631633  0.126327  0.126852  0.001904            1     0.129619
# 30      1.812760  0.362553  0.362147  0.001221            1     0.363337
# 31      0.606037  0.121207  0.121504  0.001131            1     0.122368
# 32      4.589480  0.917896  0.918878  0.006558            1     0.923228
# 33      2.092720  0.418543  0.418630  0.003055            1     0.422973
# 34      4.577660  0.915532  0.913156  0.006587            1     0.916118
# 35      2.086730  0.417345  0.417027  0.003530            1     0.416546
# 36     13.049700  2.609930  2.611600  0.017282            1     2.613570
# 37      7.850470  1.570090  1.568730  0.010665            1     1.568770
# 38     12.568800  2.513760  2.578170  0.141624            1     2.637530
# 39      7.041980  1.408400  1.411930  0.010036            1     1.401150
# 40     21.219500  4.243900  4.247100  0.023007            1     4.237690
# 41     14.825700  2.965130  2.964220  0.020714            1     2.955520
# 42     21.664600  4.332930  4.332160  0.015871            1     4.320060
# 43     15.055200  3.011030  3.024010  0.026368            1     3.012030
# 104     1.868760  0.373753  0.374289  0.010503            1     0.403264
# 105     0.644801  0.128960  0.129057  0.001416            1     0.132935
# 106     1.721450  0.344290  0.344179  0.002890            1     0.353762
# 107     0.601318  0.120264  0.120072  0.000512            1     0.122294
# 108     4.393910  0.878783  0.880378  0.004247            1     0.890074
# 109     2.086550  0.417309  0.416619  0.002241            1     0.422888
# 110     4.304310  0.860862  0.858534  0.004318            1     0.887592
# 111     2.078690  0.415738  0.415624  0.000663            1     0.419250
# 112    12.597800  2.519560  2.517580  0.008725            1     2.544480
# 113     7.410200  1.482040  1.485610  0.010564            1     1.524870
# 114    12.898900  2.579770  2.563770  0.040725            1     2.583590
# 115     8.099310  1.619860  1.619440  0.005332            1     1.630750
# 116    22.535000  4.507000  4.508970  0.013538            1     4.538410
# 117    15.615900  3.123190  3.127560  0.014190            1     3.139970
# 118    22.175700  4.435140  4.467220  0.122270            1     4.653420
# 119    14.470900  2.894180  2.893490  0.006341            1     2.924560
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0              13555                     0              40          dynamic
# 1               4998                     0              40          dynamic
# 2              16598                     0              40          dynamic
# 3               6656                     0              40          dynamic
# 4              42141                     0              40          dynamic
# 5              20152                     0              40          dynamic
# 6              51975                     0              40          dynamic
# 7              26986                     0              40          dynamic
# 8             134883                     0              40          dynamic
# 9              80850                     0              40          dynamic
# 10            166846                     0              40          dynamic
# 11            108549                     0              40          dynamic
# 12            269184                     0              40          dynamic
# 13            179478                     0              40          dynamic
# 14            333114                     0              40          dynamic
# 15            241578                     0              40          dynamic
# 28             13370                     0              40          dynamic
# 29              5014                     0              40          dynamic
# 30             16388                     0              40          dynamic
# 31              6671                     0              40          dynamic
# 32             41890                     0              40          dynamic
# 33             20205                     0              40          dynamic
# 34             51669                     0              40          dynamic
# 35             27041                     0              40          dynamic
# 36            134263                     0              40          dynamic
# 37             80809                     0              40          dynamic
# 38            166045                     0              40          dynamic
# 39            108267                     0              40          dynamic
# 40            267895                     0              40          dynamic
# 41            179052                     0              40          dynamic
# 42            331283                     0              40          dynamic
# 43            240046                     0              40          dynamic
# 104            13532                     0              40          dynamic
# 105             4999                     0              40          dynamic
# 106            16556                     0              40          dynamic
# 107             6660                     0              40          dynamic
# 108            42070                     0              40          dynamic
# 109            20202                     0              40          dynamic
# 110            51917                     0              40          dynamic
# 111            27092                     0              40          dynamic
# 112           134518                     0              40          dynamic
# 113            81042                     0              40          dynamic
# 114           166349                     0              40          dynamic
# 115           108831                     0              40          dynamic
# 116           268205                     0              40          dynamic
# 117           179797                     0              40          dynamic
# 118           331967                     0              40          dynamic
# 119           241699                     0              40          dynamic
#
# [48 rows x 21 columns]
#                     date  octree point_type           encoder   npoints  \
# 0    2025-06-01-10:37:39  Octree      Point        NoEncoding  12219779
# 1    2025-06-01-10:37:39  Octree      Point        NoEncoding  12219779
# 2    2025-06-01-10:37:39  Octree      Point        NoEncoding  12219779
# 3    2025-06-01-10:37:39  Octree      Point        NoEncoding  12219779
# 4    2025-06-01-10:37:40  Octree      Point        NoEncoding  12219779
# 5    2025-06-01-10:37:40  Octree      Point        NoEncoding  12219779
# 6    2025-06-01-10:37:40  Octree      Point        NoEncoding  12219779
# 7    2025-06-01-10:37:40  Octree      Point        NoEncoding  12219779
# 8    2025-06-01-10:37:40  Octree      Point        NoEncoding  12219779
# 9    2025-06-01-10:37:40  Octree      Point        NoEncoding  12219779
# 10   2025-06-01-10:37:41  Octree      Point        NoEncoding  12219779
# 11   2025-06-01-10:37:41  Octree      Point        NoEncoding  12219779
# 12   2025-06-01-10:37:41  Octree      Point        NoEncoding  12219779
# 13   2025-06-01-10:37:41  Octree      Point        NoEncoding  12219779
# 14   2025-06-01-10:37:42  Octree      Point        NoEncoding  12219779
# 15   2025-06-01-10:37:42  Octree      Point        NoEncoding  12219779
# 28   2025-06-01-10:37:54  Octree      Point   MortonEncoder3D  12219779
# 29   2025-06-01-10:37:54  Octree      Point   MortonEncoder3D  12219779
# 30   2025-06-01-10:37:55  Octree      Point   MortonEncoder3D  12219779
# 31   2025-06-01-10:37:55  Octree      Point   MortonEncoder3D  12219779
# 32   2025-06-01-10:37:55  Octree      Point   MortonEncoder3D  12219779
# 33   2025-06-01-10:37:55  Octree      Point   MortonEncoder3D  12219779
# 34   2025-06-01-10:37:55  Octree      Point   MortonEncoder3D  12219779
# 35   2025-06-01-10:37:55  Octree      Point   MortonEncoder3D  12219779
# 36   2025-06-01-10:37:56  Octree      Point   MortonEncoder3D  12219779
# 37   2025-06-01-10:37:56  Octree      Point   MortonEncoder3D  12219779
# 38   2025-06-01-10:37:56  Octree      Point   MortonEncoder3D  12219779
# 39   2025-06-01-10:37:56  Octree      Point   MortonEncoder3D  12219779
# 40   2025-06-01-10:37:57  Octree      Point   MortonEncoder3D  12219779
# 41   2025-06-01-10:37:57  Octree      Point   MortonEncoder3D  12219779
# 42   2025-06-01-10:37:58  Octree      Point   MortonEncoder3D  12219779
# 43   2025-06-01-10:37:58  Octree      Point   MortonEncoder3D  12219779
# 104  2025-06-01-10:38:13  Octree      Point  HilbertEncoder3D  12219779
# 105  2025-06-01-10:38:13  Octree      Point  HilbertEncoder3D  12219779
# 106  2025-06-01-10:38:13  Octree      Point  HilbertEncoder3D  12219779
# 107  2025-06-01-10:38:13  Octree      Point  HilbertEncoder3D  12219779
# 108  2025-06-01-10:38:14  Octree      Point  HilbertEncoder3D  12219779
# 109  2025-06-01-10:38:14  Octree      Point  HilbertEncoder3D  12219779
# 110  2025-06-01-10:38:14  Octree      Point  HilbertEncoder3D  12219779
# 111  2025-06-01-10:38:14  Octree      Point  HilbertEncoder3D  12219779
# 112  2025-06-01-10:38:14  Octree      Point  HilbertEncoder3D  12219779
# 113  2025-06-01-10:38:15  Octree      Point  HilbertEncoder3D  12219779
# 114  2025-06-01-10:38:15  Octree      Point  HilbertEncoder3D  12219779
# 115  2025-06-01-10:38:15  Octree      Point  HilbertEncoder3D  12219779
# 116  2025-06-01-10:38:16  Octree      Point  HilbertEncoder3D  12219779
# 117  2025-06-01-10:38:16  Octree      Point  HilbertEncoder3D  12219779
# 118  2025-06-01-10:38:17  Octree      Point  HilbertEncoder3D  12219779
# 119  2025-06-01-10:38:17  Octree      Point  HilbertEncoder3D  12219779
#
#         operation  kernel  radius  num_searches sequential_searches  ...  \
# 0    neighborsPtr  Circle     0.5         10000              random  ...
# 1    neighborsPtr  Sphere     0.5         10000              random  ...
# 2    neighborsPtr  Square     0.5         10000              random  ...
# 3    neighborsPtr    Cube     0.5         10000              random  ...
# 4    neighborsPtr  Circle     1.0         10000              random  ...
# 5    neighborsPtr  Sphere     1.0         10000              random  ...
# 6    neighborsPtr  Square     1.0         10000              random  ...
# 7    neighborsPtr    Cube     1.0         10000              random  ...
# 8    neighborsPtr  Circle     2.0         10000              random  ...
# 9    neighborsPtr  Sphere     2.0         10000              random  ...
# 10   neighborsPtr  Square     2.0         10000              random  ...
# 11   neighborsPtr    Cube     2.0         10000              random  ...
# 12   neighborsPtr  Circle     3.0         10000              random  ...
# 13   neighborsPtr  Sphere     3.0         10000              random  ...
# 14   neighborsPtr  Square     3.0         10000              random  ...
# 15   neighborsPtr    Cube     3.0         10000              random  ...
# 28   neighborsPtr  Circle     0.5         10000              random  ...
# 29   neighborsPtr  Sphere     0.5         10000              random  ...
# 30   neighborsPtr  Square     0.5         10000              random  ...
# 31   neighborsPtr    Cube     0.5         10000              random  ...
# 32   neighborsPtr  Circle     1.0         10000              random  ...
# 33   neighborsPtr  Sphere     1.0         10000              random  ...
# 34   neighborsPtr  Square     1.0         10000              random  ...
# 35   neighborsPtr    Cube     1.0         10000              random  ...
# 36   neighborsPtr  Circle     2.0         10000              random  ...
# 37   neighborsPtr  Sphere     2.0         10000              random  ...
# 38   neighborsPtr  Square     2.0         10000              random  ...
# 39   neighborsPtr    Cube     2.0         10000              random  ...
# 40   neighborsPtr  Circle     3.0         10000              random  ...
# 41   neighborsPtr  Sphere     3.0         10000              random  ...
# 42   neighborsPtr  Square     3.0         10000              random  ...
# 43   neighborsPtr    Cube     3.0         10000              random  ...
# 104  neighborsPtr  Circle     0.5         10000              random  ...
# 105  neighborsPtr  Sphere     0.5         10000              random  ...
# 106  neighborsPtr  Square     0.5         10000              random  ...
# 107  neighborsPtr    Cube     0.5         10000              random  ...
# 108  neighborsPtr  Circle     1.0         10000              random  ...
# 109  neighborsPtr  Sphere     1.0         10000              random  ...
# 110  neighborsPtr  Square     1.0         10000              random  ...
# 111  neighborsPtr    Cube     1.0         10000              random  ...
# 112  neighborsPtr  Circle     2.0         10000              random  ...
# 113  neighborsPtr  Sphere     2.0         10000              random  ...
# 114  neighborsPtr  Square     2.0         10000              random  ...
# 115  neighborsPtr    Cube     2.0         10000              random  ...
# 116  neighborsPtr  Circle     3.0         10000              random  ...
# 117  neighborsPtr  Sphere     3.0         10000              random  ...
# 118  neighborsPtr  Square     3.0         10000              random  ...
# 119  neighborsPtr    Cube     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 0       0.119156  0.023831  0.023740  0.001110            1     0.029466
# 1       0.039028  0.007806  0.007820  0.000059            1     0.007815
# 2       0.111788  0.022358  0.022374  0.000349            1     0.022651
# 3       0.033270  0.006654  0.006667  0.000040            1     0.006679
# 4       0.147779  0.029556  0.029499  0.000467            1     0.029667
# 5       0.066727  0.013345  0.013407  0.000113            1     0.013288
# 6       0.148624  0.029725  0.029799  0.000237            1     0.029611
# 7       0.059950  0.011990  0.012031  0.000101            1     0.011991
# 8       0.241645  0.048329  0.048376  0.000427            1     0.048693
# 9       0.140620  0.028124  0.028139  0.000156            1     0.028292
# 10      0.252371  0.050474  0.048835  0.003652            1     0.048676
# 11      0.135519  0.027104  0.026406  0.001364            1     0.026401
# 12      0.352720  0.070544  0.070549  0.000075            1     0.074068
# 13      0.236874  0.047375  0.047362  0.000110            1     0.047475
# 14      0.356205  0.071241  0.071053  0.000898            1     0.077521
# 15      0.258251  0.051650  0.049399  0.004890            1     0.045861
# 28      0.171451  0.034290  0.034272  0.000443            1     0.033157
# 29      0.037006  0.007401  0.007411  0.000034            1     0.009518
# 30      0.146925  0.029385  0.029188  0.000350            1     0.029604
# 31      0.037035  0.007407  0.007410  0.000013            1     0.007505
# 32      0.199182  0.039836  0.039701  0.000384            1     0.040010
# 33      0.067813  0.013563  0.013550  0.000084            1     0.013791
# 34      0.199819  0.039964  0.039992  0.000356            1     0.039893
# 35      0.067507  0.013501  0.013477  0.000074            1     0.013626
# 36      0.327124  0.065425  0.065320  0.000449            1     0.065234
# 37      0.149595  0.029919  0.029933  0.000033            1     0.030008
# 38      0.327396  0.065479  0.065530  0.000385            1     0.065007
# 39      0.148442  0.029688  0.029687  0.000072            1     0.029776
# 40      0.481095  0.096219  0.096309  0.000757            1     0.096433
# 41      0.268533  0.053707  0.053299  0.000902            1     0.053136
# 42      0.474087  0.094817  0.094862  0.000676            1     0.093453
# 43      0.262907  0.052581  0.052489  0.000283            1     0.052720
# 104     0.145318  0.029064  0.028986  0.000149            1     0.030398
# 105     0.036759  0.007352  0.007335  0.000060            1     0.007371
# 106     0.143069  0.028614  0.028559  0.000106            1     0.029062
# 107     0.036545  0.007309  0.007315  0.000049            1     0.007426
# 108     0.200000  0.040000  0.038863  0.003229            1     0.039173
# 109     0.064743  0.012949  0.012965  0.000247            1     0.013308
# 110     0.191168  0.038234  0.038224  0.000117            1     0.038532
# 111     0.065757  0.013151  0.013173  0.000044            1     0.013169
# 112     0.315176  0.063035  0.062958  0.000233            1     0.063617
# 113     0.145072  0.029014  0.029010  0.000115            1     0.029098
# 114     0.313956  0.062791  0.062649  0.000397            1     0.063180
# 115     0.144024  0.028805  0.028811  0.000080            1     0.029011
# 116     0.462256  0.092451  0.092440  0.000530            1     0.093801
# 117     0.260027  0.052005  0.051635  0.000703            1     0.051979
# 118     0.460350  0.092070  0.091982  0.000308            1     0.092502
# 119     0.256363  0.051273  0.051239  0.000239            1     0.051515
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 0                 49                     0              40          dynamic
# 1                 20                     0              40          dynamic
# 2                 61                     0              40          dynamic
# 3                 27                     0              40          dynamic
# 4                199                     0              40          dynamic
# 5                 87                     0              40          dynamic
# 6                249                     0              40          dynamic
# 7                119                     0              40          dynamic
# 8                771                     0              40          dynamic
# 9                375                     0              40          dynamic
# 10               970                     0              40          dynamic
# 11               539                     0              40          dynamic
# 12              1691                     0              40          dynamic
# 13               905                     0              40          dynamic
# 14              2121                     0              40          dynamic
# 15              1337                     0              40          dynamic
# 28                49                     0              40          dynamic
# 29                20                     0              40          dynamic
# 30                61                     0              40          dynamic
# 31                28                     0              40          dynamic
# 32               197                     0              40          dynamic
# 33                87                     0              40          dynamic
# 34               248                     0              40          dynamic
# 35               120                     0              40          dynamic
# 36               767                     0              40          dynamic
# 37               377                     0              40          dynamic
# 38               965                     0              40          dynamic
# 39               541                     0              40          dynamic
# 40              1683                     0              40          dynamic
# 41               908                     0              40          dynamic
# 42              2114                     0              40          dynamic
# 43              1336                     0              40          dynamic
# 104               50                     0              40          dynamic
# 105               20                     0              40          dynamic
# 106               62                     0              40          dynamic
# 107               27                     0              40          dynamic
# 108              200                     0              40          dynamic
# 109               87                     0              40          dynamic
# 110              251                     0              40          dynamic
# 111              119                     0              40          dynamic
# 112              777                     0              40          dynamic
# 113              375                     0              40          dynamic
# 114              978                     0              40          dynamic
# 115              539                     0              40          dynamic
# 116             1706                     0              40          dynamic
# 117              907                     0              40          dynamic
# 118             2140                     0              40          dynamic
# 119             1339                     0              40          dynamic
#
# [48 rows x 21 columns]
#                     date  octree point_type           encoder   npoints  \
# 0    2025-06-01-10:55:56  Octree      Point        NoEncoding  29697591
# 1    2025-06-01-10:55:56  Octree      Point        NoEncoding  29697591
# 2    2025-06-01-10:55:56  Octree      Point        NoEncoding  29697591
# 3    2025-06-01-10:55:56  Octree      Point        NoEncoding  29697591
# 4    2025-06-01-10:55:58  Octree      Point        NoEncoding  29697591
# 5    2025-06-01-10:55:58  Octree      Point        NoEncoding  29697591
# 6    2025-06-01-10:56:00  Octree      Point        NoEncoding  29697591
# 7    2025-06-01-10:56:00  Octree      Point        NoEncoding  29697591
# 8    2025-06-01-10:56:03  Octree      Point        NoEncoding  29697591
# 9    2025-06-01-10:56:04  Octree      Point        NoEncoding  29697591
# 10   2025-06-01-10:56:07  Octree      Point        NoEncoding  29697591
# 11   2025-06-01-10:56:08  Octree      Point        NoEncoding  29697591
# 12   2025-06-01-10:56:15  Octree      Point        NoEncoding  29697591
# 13   2025-06-01-10:56:19  Octree      Point        NoEncoding  29697591
# 14   2025-06-01-10:56:26  Octree      Point        NoEncoding  29697591
# 15   2025-06-01-10:56:30  Octree      Point        NoEncoding  29697591
# 28   2025-06-01-10:57:10  Octree      Point   MortonEncoder3D  29697591
# 29   2025-06-01-10:57:10  Octree      Point   MortonEncoder3D  29697591
# 30   2025-06-01-10:57:10  Octree      Point   MortonEncoder3D  29697591
# 31   2025-06-01-10:57:10  Octree      Point   MortonEncoder3D  29697591
# 32   2025-06-01-10:57:11  Octree      Point   MortonEncoder3D  29697591
# 33   2025-06-01-10:57:12  Octree      Point   MortonEncoder3D  29697591
# 34   2025-06-01-10:57:13  Octree      Point   MortonEncoder3D  29697591
# 35   2025-06-01-10:57:13  Octree      Point   MortonEncoder3D  29697591
# 36   2025-06-01-10:57:16  Octree      Point   MortonEncoder3D  29697591
# 37   2025-06-01-10:57:17  Octree      Point   MortonEncoder3D  29697591
# 38   2025-06-01-10:57:20  Octree      Point   MortonEncoder3D  29697591
# 39   2025-06-01-10:57:21  Octree      Point   MortonEncoder3D  29697591
# 40   2025-06-01-10:57:28  Octree      Point   MortonEncoder3D  29697591
# 41   2025-06-01-10:57:32  Octree      Point   MortonEncoder3D  29697591
# ...
# 129              random  ...     0.051836  0.010367  0.010432  0.000127
# 130              random  ...     2.589540  0.517907  0.515690  0.006068
# 131              random  ...     0.076223  0.015244  0.015314  0.000213
# 140              random  ...     5.726080  1.145220  1.140930  0.009500
# 141              random  ...     0.287798  0.057560  0.057566  0.000326
# 142              random  ...     5.491590  1.098320  1.095690  0.009363
# 143              random  ...     0.394952  0.078990  0.078643  0.001463
# 152              random  ...     7.593970  1.518790  1.513110  0.010858
# 153              random  ...     0.587322  0.117464  0.116926  0.000871
# 154              random  ...     7.112250  1.422450  1.422090  0.012496
# 155              random  ...     0.776313  0.155263  0.154958  0.001686
# 164              random  ...     9.853020  1.970600  1.972320  0.013258
# 165              random  ...     1.153530  0.230706  0.230589  0.001941
# 166              random  ...     9.424020  1.884800  1.891730  0.019997
# 167              random  ...     1.526260  0.305252  0.304121  0.002963
#
#      used_warmup  warmup_time  avg_result_size  tolerance_percentage  \
# 52             1     0.458649            25239                     0
# 53             1     0.009032              453                     0
# 54             1     0.453103            28010                     0
# 55             1     0.013209              500                     0
# 64             1     1.012390           285771                     0
# 65             1     0.050828            14461                     0
# 66             1     0.972841           323961                     0
# 67             1     0.068858            21326                     0
# 76             1     1.330890           733150                     0
# 77             1     0.104392            58403                     0
# 78             1     1.256140           822445                     0
# 79             1     0.137947            82382                     0
# 88             1     1.730370          1873001                     0
# 89             1     0.205819           230987                     0
# 90             1     1.668440          2106487                     0
# 91             1     0.273783           319446                     0
# 128            1     0.508354            25843                     0
# 129            1     0.010430              460                     0
# 130            1     0.514964            28669                     0
# 131            1     0.015240              506                     0
# 140            1     1.151510           296234                     0
# 141            1     0.057846            14663                     0
# 142            1     1.101980           336392                     0
# 143            1     0.078817            21670                     0
# 152            1     1.532610           765061                     0
# 153            1     0.118000            59321                     0
# 154            1     1.432930           860040                     0
# 155            1     0.155654            83693                     0
# 164            1     1.985340          1949215                     0
# 165            1     0.230353           234024                     0
# 166            1     1.889060          2189463                     0
# 167            1     0.305809           323295                     0
#
#      openmp_threads  openmp_schedule
# 52               40          dynamic
# 53               40          dynamic
# 54               40          dynamic
# 55               40          dynamic
# 64               40          dynamic
# 65               40          dynamic
# 66               40          dynamic
# 67               40          dynamic
# 76               40          dynamic
# 77               40          dynamic
# 78               40          dynamic
# 79               40          dynamic
# 88               40          dynamic
# 89               40          dynamic
# 90               40          dynamic
# 91               40          dynamic
# 128              40          dynamic
# 129              40          dynamic
# 130              40          dynamic
# 131              40          dynamic
# 140              40          dynamic
# 141              40          dynamic
# 142              40          dynamic
# 143              40          dynamic
# 152              40          dynamic
# 153              40          dynamic
# 154              40          dynamic
# 155              40          dynamic
# 164              40          dynamic
# 165              40          dynamic
# 166              40          dynamic
# 167              40          dynamic
#
# [32 rows x 21 columns]
#                     date        octree point_type           encoder  \
# 52   2025-06-01-13:03:24  LinearOctree      Point   MortonEncoder3D
# 53   2025-06-01-13:03:24  LinearOctree      Point   MortonEncoder3D
# 54   2025-06-01-13:03:24  LinearOctree      Point   MortonEncoder3D
# 55   2025-06-01-13:03:24  LinearOctree      Point   MortonEncoder3D
# 64   2025-06-01-13:03:29  LinearOctree      Point   MortonEncoder3D
# 65   2025-06-01-13:03:29  LinearOctree      Point   MortonEncoder3D
# 66   2025-06-01-13:03:30  LinearOctree      Point   MortonEncoder3D
# 67   2025-06-01-13:03:30  LinearOctree      Point   MortonEncoder3D
# 76   2025-06-01-13:03:38  LinearOctree      Point   MortonEncoder3D
# 77   2025-06-01-13:03:38  LinearOctree      Point   MortonEncoder3D
# 78   2025-06-01-13:03:40  LinearOctree      Point   MortonEncoder3D
# 79   2025-06-01-13:03:40  LinearOctree      Point   MortonEncoder3D
# 88   2025-06-01-13:03:55  LinearOctree      Point   MortonEncoder3D
# 89   2025-06-01-13:03:55  LinearOctree      Point   MortonEncoder3D
# 90   2025-06-01-13:03:57  LinearOctree      Point   MortonEncoder3D
# 91   2025-06-01-13:03:57  LinearOctree      Point   MortonEncoder3D
# 128  2025-06-01-13:16:34  LinearOctree      Point  HilbertEncoder3D
# 129  2025-06-01-13:16:34  LinearOctree      Point  HilbertEncoder3D
# 130  2025-06-01-13:16:34  LinearOctree      Point  HilbertEncoder3D
# 131  2025-06-01-13:16:35  LinearOctree      Point  HilbertEncoder3D
# 140  2025-06-01-13:16:40  LinearOctree      Point  HilbertEncoder3D
# 141  2025-06-01-13:16:40  LinearOctree      Point  HilbertEncoder3D
# 142  2025-06-01-13:16:40  LinearOctree      Point  HilbertEncoder3D
# 143  2025-06-01-13:16:41  LinearOctree      Point  HilbertEncoder3D
# 152  2025-06-01-13:16:49  LinearOctree      Point  HilbertEncoder3D
# 153  2025-06-01-13:16:49  LinearOctree      Point  HilbertEncoder3D
# 154  2025-06-01-13:16:50  LinearOctree      Point  HilbertEncoder3D
# 155  2025-06-01-13:16:50  LinearOctree      Point  HilbertEncoder3D
# 164  2025-06-01-13:17:05  LinearOctree      Point  HilbertEncoder3D
# 165  2025-06-01-13:17:05  LinearOctree      Point  HilbertEncoder3D
# 166  2025-06-01-13:17:08  LinearOctree      Point  HilbertEncoder3D
# 167  2025-06-01-13:17:08  LinearOctree      Point  HilbertEncoder3D
#
#        npoints        operation  kernel  radius  num_searches  \
# 52   721810646  neighborsStruct  Circle    0.01         10000
# 53   721810646  neighborsStruct  Sphere    0.01         10000
# 54   721810646  neighborsStruct  Square    0.01         10000
# 55   721810646  neighborsStruct    Cube    0.01         10000
# 64   721810646  neighborsStruct  Circle    0.05         10000
# 65   721810646  neighborsStruct  Sphere    0.05         10000
# 66   721810646  neighborsStruct  Square    0.05         10000
# 67   721810646  neighborsStruct    Cube    0.05         10000
# 76   721810646  neighborsStruct  Circle    0.10         10000
# 77   721810646  neighborsStruct  Sphere    0.10         10000
# 78   721810646  neighborsStruct  Square    0.10         10000
# 79   721810646  neighborsStruct    Cube    0.10         10000
# 88   721810646  neighborsStruct  Circle    0.20         10000
# 89   721810646  neighborsStruct  Sphere    0.20         10000
# 90   721810646  neighborsStruct  Square    0.20         10000
# 91   721810646  neighborsStruct    Cube    0.20         10000
# 128  721810646  neighborsStruct  Circle    0.01         10000
# 129  721810646  neighborsStruct  Sphere    0.01         10000
# 130  721810646  neighborsStruct  Square    0.01         10000
# 131  721810646  neighborsStruct    Cube    0.01         10000
# 140  721810646  neighborsStruct  Circle    0.05         10000
# 141  721810646  neighborsStruct  Sphere    0.05         10000
# 142  721810646  neighborsStruct  Square    0.05         10000
# 143  721810646  neighborsStruct    Cube    0.05         10000
# 152  721810646  neighborsStruct  Circle    0.10         10000
# 153  721810646  neighborsStruct  Sphere    0.10         10000
# 154  721810646  neighborsStruct  Square    0.10         10000
# 155  721810646  neighborsStruct    Cube    0.10         10000
# 164  721810646  neighborsStruct  Circle    0.20         10000
# 165  721810646  neighborsStruct  Sphere    0.20         10000
# 166  721810646  neighborsStruct  Square    0.20         10000
# 167  721810646  neighborsStruct    Cube    0.20         10000
#
#     sequential_searches  ...  accumulated      mean    median     stdev  \
# 52               random  ...     0.412065  0.082413  0.082437  0.000364
# 53               random  ...     0.011182  0.002236  0.002229  0.000013
# 54               random  ...     0.415597  0.083119  0.083199  0.000404
# 55               random  ...     0.011474  0.002295  0.002296  0.000023
# 64               random  ...     0.736649  0.147330  0.147014  0.001484
# 65               random  ...     0.032970  0.006594  0.006583  0.000054
# 66               random  ...     0.747314  0.149463  0.149600  0.000804
# 67               random  ...     0.035433  0.007087  0.007076  0.000093
# 76               random  ...     1.116870  0.223374  0.222648  0.001258
# 77               random  ...     0.067803  0.013560  0.013541  0.000132
# 78               random  ...     1.134740  0.226947  0.226841  0.000532
# 79               random  ...     0.072349  0.014470  0.014468  0.000078
# 88               random  ...     1.785240  0.357047  0.356980  0.001641
# 89               random  ...     0.144729  0.028946  0.028988  0.000159
# 90               random  ...     1.799280  0.359856  0.359482  0.001246
# 91               random  ...     0.153423  0.030685  0.030745  0.000192
# 128              random  ...     0.420545  0.084109  0.083902  0.000814
# 129              random  ...     0.012311  0.002462  0.002430  0.000074
# 130              random  ...     0.433303  0.086661  0.086450  0.000733
# 131              random  ...     0.012778  0.002556  0.002553  0.000006
# 140              random  ...     0.732027  0.146405  0.146875  0.001847
# 141              random  ...     0.034115  0.006823  0.006826  0.000036
# 142              random  ...     0.752782  0.150556  0.150815  0.002075
# 143              random  ...     0.036871  0.007374  0.007361  0.000035
# 152              random  ...     1.094410  0.218882  0.217294  0.002797
# 153              random  ...     0.068104  0.013621  0.013633  0.000052
# 154              random  ...     1.116940  0.223389  0.223826  0.002643
# 155              random  ...     0.072447  0.014489  0.014487  0.000031
# 164              random  ...     1.752710  0.350542  0.350846  0.003949
# 165              random  ...     0.142632  0.028526  0.028506  0.000127
# 166              random  ...     1.763900  0.352779  0.352822  0.003348
# 167              random  ...     0.149510  0.029902  0.029932  0.000126
#
#      used_warmup  warmup_time  avg_result_size  tolerance_percentage  \
# 52             1     0.082535              212                     0
# 53             1     0.002320                7                     0
# 54             1     0.082789              257                     0
# 55             1     0.002377               11                     0
# 64             1     0.146698             3184                     0
# 65             1     0.006606              193                     0
# 66             1     0.149780             3840                     0
# 67             1     0.007140              276                     0
# 76             1     0.221116             9307                     0
# 77             1     0.013448              768                     0
# 78             1     0.225990            11141                     0
# 79             1     0.014470             1079                     0
# 88             1     0.357569            26055                     0
# 89             1     0.028661             2963                     0
# 90             1     0.358369            30956                     0
# 91             1     0.030607             4052                     0
# 128            1     0.084751              204                     0
# 129            1     0.002537                7                     0
# 130            1     0.086700              248                     0
# 131            1     0.002634               11                     0
# 140            1     0.147379             3174                     0
# 141            1     0.006866              190                     0
# 142            1     0.151576             3847                     0
# 143            1     0.007459              274                     0
# 152            1     0.221256             9389                     0
# 153            1     0.013611              757                     0
# 154            1     0.226315            11238                     0
# 155            1     0.014411             1066                     0
# 164            1     0.356587            26521                     0
# 165            1     0.028360             2933                     0
# 166            1     0.356817            31490                     0
# 167            1     0.029776             4010                     0
#
#      openmp_threads  openmp_schedule
# 52               40          dynamic
# 53               40          dynamic
# 54               40          dynamic
# 55               40          dynamic
# 64               40          dynamic
# 65               40          dynamic
# 66               40          dynamic
# 67               40          dynamic
# 76               40          dynamic
# 77               40          dynamic
# 78               40          dynamic
# 79               40          dynamic
# 88               40          dynamic
# 89               40          dynamic
# 90               40          dynamic
# 91               40          dynamic
# 128              40          dynamic
# 129              40          dynamic
# 130              40          dynamic
# 131              40          dynamic
# 140              40          dynamic
# 141              40          dynamic
# 142              40          dynamic
# 143              40          dynamic
# 152              40          dynamic
# 153              40          dynamic
# 154              40          dynamic
# 155              40          dynamic
# 164              40          dynamic
# 165              40          dynamic
# 166              40          dynamic
# 167              40          dynamic
#
# [32 rows x 21 columns]
# Average Morton runtime:  0.8677
# Average Hilbert runtime: 0.9341
# /tmp/ipykernel_2472/974442997.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /tmp/ipykernel_2472/974442997.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
fig = plot_avg_result_sizes_log(ALL_CLOUDS, "Sphere", 
                                [NEIGHBORS_PCLKD, NEIGHBORS_UNIBN, NEIGHBORS_STRUCT, NEIGHBORS_PCLOCT], 
                                DATA_SUBSET, encoder=HILBERT_ENCODER, types_info=TYPES_INFO_STRUCTURES, legend_pos=(0.91, 1.03), legend_title=r"Estructura usada")
output_fig(fig, "loglog_subsets_structures_sphere")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/subset/Lille_0/Lille_0-2025-06-01-10:30:28.csv
# Loading latest file: out_tfg_v3/subset/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-06-01-10:38:28.csv
# Loading latest file: out_tfg_v3/subset/5080_54400/5080_54400-2025-06-01-10:37:30.csv
# Loading latest file: out_tfg_v3/subset/bildstein_station1_xyz_intensity_rgb/bildstein_station1_xyz_intensity_rgb-2025-06-01-10:55:38.csv
# Loading latest file: out_tfg_v3/subset/sg27_station8_intensity_rgb/sg27_station8_intensity_rgb-2025-06-01-11:00:41.csv
# Skipping file with invalid timestamp format: extra.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/subset/Speulderbos_2017_TLS/Speulderbos_2017_TLS-2025-06-01-12:43:03.csv
#                     date        octree point_type           encoder   npoints  \
# 129  2025-06-01-10:36:11  LinearOctree      Point  HilbertEncoder3D  10000000
# 141  2025-06-01-10:36:16  LinearOctree      Point  HilbertEncoder3D  10000000
# 153  2025-06-01-10:36:30  LinearOctree      Point  HilbertEncoder3D  10000000
# 165  2025-06-01-10:36:59  LinearOctree      Point  HilbertEncoder3D  10000000
#
#            operation  kernel  radius  num_searches sequential_searches  ...  \
# 129  neighborsStruct  Sphere     0.5         10000              random  ...
# 141  neighborsStruct  Sphere     1.0         10000              random  ...
# 153  neighborsStruct  Sphere     2.0         10000              random  ...
# 165  neighborsStruct  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 129     0.088872  0.017774  0.017780  0.000058            1     0.017818
# 141     0.189922  0.037984  0.037820  0.000233            1     0.038089
# 153     0.393224  0.078645  0.078614  0.000271            1     0.078922
# 165     0.593131  0.118626  0.118825  0.000313            1     0.118541
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 129             2063                     0              40          dynamic
# 141             8296                     0              40          dynamic
# 153            32827                     0              40          dynamic
# 165            71947                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date        octree point_type           encoder   npoints  \
# 129  2025-06-01-10:52:19  LinearOctree      Point  HilbertEncoder3D  10000000
# 141  2025-06-01-10:52:32  LinearOctree      Point  HilbertEncoder3D  10000000
# 153  2025-06-01-10:53:10  LinearOctree      Point  HilbertEncoder3D  10000000
# 165  2025-06-01-10:54:20  LinearOctree      Point  HilbertEncoder3D  10000000
#
#            operation  kernel  radius  num_searches sequential_searches  ...  \
# 129  neighborsStruct  Sphere     0.5         10000              random  ...
# 141  neighborsStruct  Sphere     1.0         10000              random  ...
# 153  neighborsStruct  Sphere     2.0         10000              random  ...
# 165  neighborsStruct  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 129     0.130182  0.026037  0.026052  0.000096            1     0.026157
# 141     0.281004  0.056201  0.056197  0.000220            1     0.056727
# 153     0.626971  0.125394  0.125624  0.000398            1     0.126762
# 165     0.912213  0.182443  0.182312  0.000180            1     0.182330
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 129             4999                     0              40          dynamic
# 141            20202                     0              40          dynamic
# 153            81042                     0              40          dynamic
# 165           179797                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date        octree point_type           encoder   npoints  \
# 129  2025-06-01-10:38:18  LinearOctree      Point  HilbertEncoder3D  12219779
# 141  2025-06-01-10:38:19  LinearOctree      Point  HilbertEncoder3D  12219779
# 153  2025-06-01-10:38:20  LinearOctree      Point  HilbertEncoder3D  12219779
# 165  2025-06-01-10:38:22  LinearOctree      Point  HilbertEncoder3D  12219779
#
#            operation  kernel  radius  num_searches sequential_searches  ...  \
# 129  neighborsStruct  Sphere     0.5         10000              random  ...
# 141  neighborsStruct  Sphere     1.0         10000              random  ...
# 153  neighborsStruct  Sphere     2.0         10000              random  ...
# 165  neighborsStruct  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 129     0.016652  0.003330  0.003327  0.000015            1     0.003316
# 141     0.027962  0.005592  0.005564  0.000043            1     0.005564
# 153     0.055468  0.011094  0.011075  0.000073            1     0.010987
# 165     0.090623  0.018125  0.018101  0.000104            1     0.017983
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 129               20                     0              40          dynamic
# 141               87                     0              40          dynamic
# 153              375                     0              40          dynamic
# 165              907                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date        octree point_type           encoder   npoints  \
# 129  2025-06-01-10:59:39  LinearOctree      Point  HilbertEncoder3D  29697591
# 141  2025-06-01-10:59:43  LinearOctree      Point  HilbertEncoder3D  29697591
# 153  2025-06-01-10:59:52  LinearOctree      Point  HilbertEncoder3D  29697591
# 165  2025-06-01-11:00:14  LinearOctree      Point  HilbertEncoder3D  29697591
#
#            operation  kernel  radius  num_searches sequential_searches  ...  \
# 129  neighborsStruct  Sphere    0.01         10000              random  ...
# 141  neighborsStruct  Sphere    0.05         10000              random  ...
# 153  neighborsStruct  Sphere    0.10         10000              random  ...
# 165  neighborsStruct  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 129     0.019464  0.003893  0.003897  0.000027            1     0.003973
# 141     0.104993  0.020999  0.021003  0.000098            1     0.021177
# 153     0.209659  0.041932  0.041975  0.000252            1     0.042049
# 165     0.409080  0.081816  0.081774  0.000567            1     0.081934
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 129               66                     0              40          dynamic
# 141             2029                     0              40          dynamic
# 153             8553                     0              40          dynamic
# 165            33036                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date        octree point_type           encoder  \
# 129  2025-06-01-12:22:51  LinearOctree      Point  HilbertEncoder3D
# 141  2025-06-01-12:24:26  LinearOctree      Point  HilbertEncoder3D
# 153  2025-06-01-12:28:02  LinearOctree      Point  HilbertEncoder3D
# 165  2025-06-01-12:36:53  LinearOctree      Point  HilbertEncoder3D
#
#        npoints        operation  kernel  radius  num_searches  \
# 129  429615314  neighborsStruct  Sphere    0.01         10000
# 141  429615314  neighborsStruct  Sphere    0.05         10000
# 153  429615314  neighborsStruct  Sphere    0.10         10000
# 165  429615314  neighborsStruct  Sphere    0.20         10000
#
#     sequential_searches  ...  accumulated      mean    median     stdev  \
# 129              random  ...     0.051836  0.010367  0.010432  0.000127
# 141              random  ...     0.287798  0.057560  0.057566  0.000326
# 153              random  ...     0.587322  0.117464  0.116926  0.000871
# 165              random  ...     1.153530  0.230706  0.230589  0.001941
#
#      used_warmup  warmup_time  avg_result_size  tolerance_percentage  \
# 129            1     0.010430              460                     0
# 141            1     0.057846            14663                     0
# 153            1     0.118000            59321                     0
# 165            1     0.230353           234024                     0
#
#      openmp_threads  openmp_schedule
# 129              40          dynamic
# 141              40          dynamic
# 153              40          dynamic
# 165              40          dynamic
#
# [4 rows x 21 columns]
#                     date        octree point_type           encoder  \
# 129  2025-06-01-13:16:34  LinearOctree      Point  HilbertEncoder3D
# 141  2025-06-01-13:16:40  LinearOctree      Point  HilbertEncoder3D
# 153  2025-06-01-13:16:49  LinearOctree      Point  HilbertEncoder3D
# 165  2025-06-01-13:17:05  LinearOctree      Point  HilbertEncoder3D
#
#        npoints        operation  kernel  radius  num_searches  \
# 129  721810646  neighborsStruct  Sphere    0.01         10000
# 141  721810646  neighborsStruct  Sphere    0.05         10000
# 153  721810646  neighborsStruct  Sphere    0.10         10000
# 165  721810646  neighborsStruct  Sphere    0.20         10000
#
#     sequential_searches  ...  accumulated      mean    median     stdev  \
# 129              random  ...     0.012311  0.002462  0.002430  0.000074
# 141              random  ...     0.034115  0.006823  0.006826  0.000036
# 153              random  ...     0.068104  0.013621  0.013633  0.000052
# 165              random  ...     0.142632  0.028526  0.028506  0.000127
#
#      used_warmup  warmup_time  avg_result_size  tolerance_percentage  \
# 129            1     0.002537                7                     0
# 141            1     0.006866              190                     0
# 153            1     0.013611              757                     0
# 165            1     0.028360             2933                     0
#
#      openmp_threads  openmp_schedule
# 129              40          dynamic
# 141              40          dynamic
# 153              40          dynamic
# 165              40          dynamic
#
# [4 rows x 21 columns]
# ('LinearOctree', 'neighborsStruct')
#                     date       octree point_type           encoder   npoints  \
# 168  2025-06-01-10:37:01  unibnOctree      Point  HilbertEncoder3D  10000000
# 170  2025-06-01-10:37:02  unibnOctree      Point  HilbertEncoder3D  10000000
# 172  2025-06-01-10:37:03  unibnOctree      Point  HilbertEncoder3D  10000000
# 174  2025-06-01-10:37:05  unibnOctree      Point  HilbertEncoder3D  10000000
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 168  neighborsUnibn  Sphere     0.5         10000              random  ...
# 170  neighborsUnibn  Sphere     1.0         10000              random  ...
# 172  neighborsUnibn  Sphere     2.0         10000              random  ...
# 174  neighborsUnibn  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 168     0.112117  0.022423  0.022474  0.000177            1     0.023048
# 170     0.247627  0.049526  0.049565  0.000150            1     0.049857
# 172     0.570539  0.114108  0.114113  0.000362            1     0.114996
# 174     0.980175  0.196035  0.196187  0.000614            1     0.196290
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 168             2063                     0              40          dynamic
# 170             8296                     0              40          dynamic
# 172            32827                     0              40          dynamic
# 174            71947                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date       octree point_type           encoder   npoints  \
# 168  2025-06-01-10:54:24  unibnOctree      Point  HilbertEncoder3D  10000000
# 170  2025-06-01-10:54:24  unibnOctree      Point  HilbertEncoder3D  10000000
# 172  2025-06-01-10:54:27  unibnOctree      Point  HilbertEncoder3D  10000000
# 174  2025-06-01-10:54:31  unibnOctree      Point  HilbertEncoder3D  10000000
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 168  neighborsUnibn  Sphere     0.5         10000              random  ...
# 170  neighborsUnibn  Sphere     1.0         10000              random  ...
# 172  neighborsUnibn  Sphere     2.0         10000              random  ...
# 174  neighborsUnibn  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 168     0.189711  0.037942  0.037773  0.000448            1     0.040040
# 170     0.453002  0.090600  0.090716  0.000513            1     0.091215
# 172     1.284750  0.256950  0.257628  0.001382            1     0.257033
# 174     2.523840  0.504768  0.504650  0.001127            1     0.504828
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 168             4999                     0              40          dynamic
# 170            20202                     0              40          dynamic
# 172            81042                     0              40          dynamic
# 174           179797                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date       octree point_type           encoder   npoints  \
# 168  2025-06-01-10:38:23  unibnOctree      Point  HilbertEncoder3D  12219779
# 170  2025-06-01-10:38:23  unibnOctree      Point  HilbertEncoder3D  12219779
# 172  2025-06-01-10:38:23  unibnOctree      Point  HilbertEncoder3D  12219779
# 174  2025-06-01-10:38:24  unibnOctree      Point  HilbertEncoder3D  12219779
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 168  neighborsUnibn  Sphere     0.5         10000              random  ...
# 170  neighborsUnibn  Sphere     1.0         10000              random  ...
# 172  neighborsUnibn  Sphere     2.0         10000              random  ...
# 174  neighborsUnibn  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 168     0.015894  0.003179  0.003169  0.000022            1     0.003428
# 170     0.028951  0.005790  0.005803  0.000046            1     0.005667
# 172     0.062934  0.012587  0.012599  0.000115            1     0.012535
# 174     0.101395  0.020279  0.020336  0.000134            1     0.020128
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 168               20                     0              40          dynamic
# 170               87                     0              40          dynamic
# 172              375                     0              40          dynamic
# 174              907                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date       octree point_type           encoder   npoints  \
# 168  2025-06-01-11:00:19  unibnOctree      Point  HilbertEncoder3D  29697591
# 170  2025-06-01-11:00:19  unibnOctree      Point  HilbertEncoder3D  29697591
# 172  2025-06-01-11:00:19  unibnOctree      Point  HilbertEncoder3D  29697591
# 174  2025-06-01-11:00:21  unibnOctree      Point  HilbertEncoder3D  29697591
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 168  neighborsUnibn  Sphere    0.01         10000              random  ...
# 170  neighborsUnibn  Sphere    0.05         10000              random  ...
# 172  neighborsUnibn  Sphere    0.10         10000              random  ...
# 174  neighborsUnibn  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 168     0.026856  0.005371  0.005364  0.000060            1     0.005554
# 170     0.138817  0.027763  0.027794  0.000189            1     0.027970
# 172     0.314816  0.062963  0.063044  0.000517            1     0.063411
# 174     0.724373  0.144875  0.144431  0.001303            1     0.146433
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 168               66                     0              40          dynamic
# 170             2029                     0              40          dynamic
# 172             8553                     0              40          dynamic
# 174            33036                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date       octree point_type           encoder    npoints  \
# 168  2025-06-01-12:38:08  unibnOctree      Point  HilbertEncoder3D  429615314
# 170  2025-06-01-12:38:08  unibnOctree      Point  HilbertEncoder3D  429615314
# 172  2025-06-01-12:38:10  unibnOctree      Point  HilbertEncoder3D  429615314
# 174  2025-06-01-12:38:16  unibnOctree      Point  HilbertEncoder3D  429615314
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 168  neighborsUnibn  Sphere    0.01         10000              random  ...
# 170  neighborsUnibn  Sphere    0.05         10000              random  ...
# 172  neighborsUnibn  Sphere    0.10         10000              random  ...
# 174  neighborsUnibn  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 168     0.062959  0.012592  0.012580  0.000118            1     0.015049
# 170     0.397189  0.079438  0.079892  0.001038            1     0.078410
# 172     1.075920  0.215183  0.215857  0.002319            1     0.217206
# 174     3.618140  0.723628  0.724964  0.008690            1     0.727404
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 168              460                     0              40          dynamic
# 170            14663                     0              40          dynamic
# 172            59321                     0              40          dynamic
# 174           234024                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date       octree point_type           encoder    npoints  \
# 168  2025-06-01-13:18:24  unibnOctree      Point  HilbertEncoder3D  721810646
# 170  2025-06-01-13:18:24  unibnOctree      Point  HilbertEncoder3D  721810646
# 172  2025-06-01-13:18:24  unibnOctree      Point  HilbertEncoder3D  721810646
# 174  2025-06-01-13:18:25  unibnOctree      Point  HilbertEncoder3D  721810646
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 168  neighborsUnibn  Sphere    0.01         10000              random  ...
# 170  neighborsUnibn  Sphere    0.05         10000              random  ...
# 172  neighborsUnibn  Sphere    0.10         10000              random  ...
# 174  neighborsUnibn  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 168     0.016273  0.003255  0.003234  0.000044            1     0.003517
# 170     0.043483  0.008697  0.008656  0.000088            1     0.008579
# 172     0.087424  0.017485  0.017555  0.000196            1     0.017334
# 174     0.190490  0.038098  0.037663  0.000724            1     0.037579
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 168                7                     0              40          dynamic
# 170              190                     0              40          dynamic
# 172              757                     0              40          dynamic
# 174             2933                     0              40          dynamic
#
# [4 rows x 21 columns]
# ('unibnOctree', 'neighborsUnibn')
#                     date     octree   point_type           encoder   npoints  \
# 188  2025-06-02-18:03:23  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
# 189  2025-06-02-18:03:23  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
# 190  2025-06-02-18:03:25  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
# 191  2025-06-02-18:03:30  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
#
#      operation  kernel  radius  num_searches sequential_searches  ...  \
# 188  PCLOctree  Sphere     0.5         10000              random  ...
# 189  PCLOctree  Sphere     1.0         10000              random  ...
# 190  PCLOctree  Sphere     2.0         10000              random  ...
# 191  PCLOctree  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 188     0.166394  0.033279  0.031662  0.002307            1     0.035255
# 189     0.471569  0.094314  0.094166  0.000902            1     0.096633
# 190     1.591590  0.318317  0.317857  0.002932            1     0.324198
# 191     3.543580  0.708716  0.709729  0.004619            1     0.717835
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 188             2063                     0              40          dynamic
# 189             8296                     0              40          dynamic
# 190            32827                     0              40          dynamic
# 191            71947                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder   npoints  \
# 188  2025-06-02-18:05:05  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
# 189  2025-06-02-18:05:06  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
# 190  2025-06-02-18:05:10  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
# 191  2025-06-02-18:05:20  PCLOctree  PCLPointXYZ  HilbertEncoder3D  10000000
#
#      operation  kernel  radius  num_searches sequential_searches  ...  \
# 188  PCLOctree  Sphere     0.5         10000              random  ...
# 189  PCLOctree  Sphere     1.0         10000              random  ...
# 190  PCLOctree  Sphere     2.0         10000              random  ...
# 191  PCLOctree  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 188     0.263177  0.052635  0.052542  0.000483            1     0.053879
# 189     0.864281  0.172856  0.172358  0.000844            1     0.175801
# 190     3.426950  0.685390  0.679534  0.010457            1     0.688435
# 191     8.202670  1.640530  1.640600  0.008235            1     1.666970
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 188             4999                     0              40          dynamic
# 189            20202                     0              40          dynamic
# 190            81042                     0              40          dynamic
# 191           179797                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder   npoints  \
# 188  2025-06-02-18:04:07  PCLOctree  PCLPointXYZ  HilbertEncoder3D  12219779
# 189  2025-06-02-18:04:07  PCLOctree  PCLPointXYZ  HilbertEncoder3D  12219779
# 190  2025-06-02-18:04:07  PCLOctree  PCLPointXYZ  HilbertEncoder3D  12219779
# 191  2025-06-02-18:04:08  PCLOctree  PCLPointXYZ  HilbertEncoder3D  12219779
#
#      operation  kernel  radius  num_searches sequential_searches  ...  \
# 188  PCLOctree  Sphere     0.5         10000              random  ...
# 189  PCLOctree  Sphere     1.0         10000              random  ...
# 190  PCLOctree  Sphere     2.0         10000              random  ...
# 191  PCLOctree  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 188     0.045592  0.009118  0.008689  0.001186            1     0.011508
# 189     0.060920  0.012184  0.011734  0.000827            1     0.014502
# 190     0.202832  0.040566  0.040609  0.000223            1     0.040223
# 191     0.435403  0.087081  0.087229  0.000410            1     0.087189
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 188               13                     0              40          dynamic
# 189               77                     0              40          dynamic
# 190              363                     0              40          dynamic
# 191              892                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder   npoints  \
# 188  2025-06-02-18:05:56  PCLOctree  PCLPointXYZ  HilbertEncoder3D  29697591
# 189  2025-06-02-18:05:57  PCLOctree  PCLPointXYZ  HilbertEncoder3D  29697591
# 190  2025-06-02-18:05:57  PCLOctree  PCLPointXYZ  HilbertEncoder3D  29697591
# 191  2025-06-02-18:05:59  PCLOctree  PCLPointXYZ  HilbertEncoder3D  29697591
#
#      operation  kernel  radius  num_searches sequential_searches  ...  \
# 188  PCLOctree  Sphere    0.01         10000              random  ...
# 189  PCLOctree  Sphere    0.05         10000              random  ...
# 190  PCLOctree  Sphere    0.10         10000              random  ...
# 191  PCLOctree  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 188     0.107508  0.021501  0.021516  0.000241            1     0.025092
# 189     0.279289  0.055858  0.056106  0.000679            1     0.057276
# 190     0.584681  0.116936  0.116869  0.001636            1     0.118995
# 191     1.581360  0.316271  0.315476  0.002337            1     0.320370
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 188               67                     0              40          dynamic
# 189             2028                     0              40          dynamic
# 190             8553                     0              40          dynamic
# 191            33036                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder    npoints  \
# 188  2025-06-02-18:13:36  PCLOctree  PCLPointXYZ  HilbertEncoder3D  429615314
# 189  2025-06-02-18:13:39  PCLOctree  PCLPointXYZ  HilbertEncoder3D  429615314
# 190  2025-06-02-18:13:44  PCLOctree  PCLPointXYZ  HilbertEncoder3D  429615314
# 191  2025-06-02-18:13:59  PCLOctree  PCLPointXYZ  HilbertEncoder3D  429615314
#
#      operation  kernel  radius  num_searches sequential_searches  ...  \
# 188  PCLOctree  Sphere    0.01         10000              random  ...
# 189  PCLOctree  Sphere    0.05         10000              random  ...
# 190  PCLOctree  Sphere    0.10         10000              random  ...
# 191  PCLOctree  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 188     0.739312  0.147862  0.148765  0.004484            1     0.186524
# 189     1.979710  0.395942  0.398169  0.008291            1     0.407443
# 190     4.372960  0.874592  0.878109  0.011866            1     0.893818
# 191    12.112200  2.422430  2.425720  0.040701            1     2.500130
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 188              474                     0              40          dynamic
# 189            14655                     0              40          dynamic
# 190            59316                     0              40          dynamic
# 191           234021                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder    npoints  \
# 188  2025-06-02-18:28:50  PCLOctree  PCLPointXYZ  HilbertEncoder3D  721810646
# 189  2025-06-02-18:28:51  PCLOctree  PCLPointXYZ  HilbertEncoder3D  721810646
# 190  2025-06-02-18:28:51  PCLOctree  PCLPointXYZ  HilbertEncoder3D  721810646
# 191  2025-06-02-18:28:51  PCLOctree  PCLPointXYZ  HilbertEncoder3D  721810646
#
#      operation  kernel  radius  num_searches sequential_searches  ...  \
# 188  PCLOctree  Sphere    0.01         10000              random  ...
# 189  PCLOctree  Sphere    0.05         10000              random  ...
# 190  PCLOctree  Sphere    0.10         10000              random  ...
# 191  PCLOctree  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 188     0.049727  0.009945  0.009917  0.000080            1     0.010259
# 189     0.067170  0.013434  0.013475  0.000247            1     0.012869
# 190     0.119189  0.023838  0.023833  0.000170            1     0.023151
# 191     0.228541  0.045708  0.045571  0.000924            1     0.045518
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 188              160                     0              40          dynamic
# 189              472                     0              40          dynamic
# 190             1651                     0              40          dynamic
# 191             4233                     0              40          dynamic
#
# [4 rows x 21 columns]
# ('PCLOctree', 'PCLOctree')
#                     date     octree   point_type           encoder   npoints  \
# 176  2025-06-01-10:37:09  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
# 177  2025-06-01-10:37:10  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
# 178  2025-06-01-10:37:16  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
# 179  2025-06-01-10:37:30  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 176  neighborsPCLKD  Sphere     0.5         10000              random  ...
# 177  neighborsPCLKD  Sphere     1.0         10000              random  ...
# 178  neighborsPCLKD  Sphere     2.0         10000              random  ...
# 179  neighborsPCLKD  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 176     0.299667  0.059933  0.059419  0.001001            1     0.059277
# 177     1.180070  0.236014  0.236356  0.001566            1     0.238898
# 178     4.906000  0.981199  0.981303  0.006117            1     0.989691
# 179    11.288400  2.257680  2.258280  0.014230            1     2.279560
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 176             2063                     0              40          dynamic
# 177             8296                     0              40          dynamic
# 178            32827                     0              40          dynamic
# 179            71947                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder   npoints  \
# 176  2025-06-01-10:54:39  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
# 177  2025-06-01-10:54:42  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
# 178  2025-06-01-10:54:59  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
# 179  2025-06-01-10:55:37  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  10000000
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 176  neighborsPCLKD  Sphere     0.5         10000              random  ...
# 177  neighborsPCLKD  Sphere     1.0         10000              random  ...
# 178  neighborsPCLKD  Sphere     2.0         10000              random  ...
# 179  neighborsPCLKD  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 176     0.766384  0.153277  0.153084  0.001050            1     0.159248
# 177     3.104460  0.620892  0.619940  0.001993            1     0.628898
# 178    13.626300  2.725250  2.719580  0.010510            1     2.734410
# 179    32.261700  6.452340  6.447420  0.023857            1     6.469680
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 176             4999                     0              40          dynamic
# 177            20202                     0              40          dynamic
# 178            81042                     0              40          dynamic
# 179           179797                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder   npoints  \
# 176  2025-06-01-10:38:27  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  12219779
# 177  2025-06-01-10:38:27  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  12219779
# 178  2025-06-01-10:38:27  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  12219779
# 179  2025-06-01-10:38:27  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  12219779
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 176  neighborsPCLKD  Sphere     0.5         10000              random  ...
# 177  neighborsPCLKD  Sphere     1.0         10000              random  ...
# 178  neighborsPCLKD  Sphere     2.0         10000              random  ...
# 179  neighborsPCLKD  Sphere     3.0         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 176     0.035250  0.007050  0.006964  0.000142            1     0.006460
# 177     0.046072  0.009214  0.009193  0.000055            1     0.008979
# 178     0.088906  0.017781  0.017778  0.000036            1     0.017757
# 179     0.164419  0.032884  0.032881  0.000091            1     0.032844
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 176               13                     0              40          dynamic
# 177               77                     0              40          dynamic
# 178              363                     0              40          dynamic
# 179              892                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder   npoints  \
# 176  2025-06-01-11:00:31  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  29697591
# 177  2025-06-01-11:00:32  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  29697591
# 178  2025-06-01-11:00:34  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  29697591
# 179  2025-06-01-11:00:41  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  29697591
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 176  neighborsPCLKD  Sphere    0.01         10000              random  ...
# 177  neighborsPCLKD  Sphere    0.05         10000              random  ...
# 178  neighborsPCLKD  Sphere    0.10         10000              random  ...
# 179  neighborsPCLKD  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 176     0.040432  0.008086  0.008442  0.000853            1     0.006599
# 177     0.343389  0.068678  0.067929  0.001651            1     0.071226
# 178     1.415720  0.283143  0.284032  0.003585            1     0.285209
# 179     5.830160  1.166030  1.166680  0.012372            1     1.172760
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 176               67                     0              40          dynamic
# 177             2028                     0              40          dynamic
# 178             8553                     0              40          dynamic
# 179            33036                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder    npoints  \
# 176  2025-06-01-12:41:52  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  429615314
# 177  2025-06-01-12:41:54  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  429615314
# 178  2025-06-01-12:42:06  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  429615314
# 179  2025-06-01-12:42:56  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  429615314
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 176  neighborsPCLKD  Sphere    0.01         10000              random  ...
# 177  neighborsPCLKD  Sphere    0.05         10000              random  ...
# 178  neighborsPCLKD  Sphere    0.10         10000              random  ...
# 179  neighborsPCLKD  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 176     0.166853  0.033371  0.035047  0.006006            1     0.045931
# 177     2.263170  0.452634  0.452148  0.004063            1     0.519044
# 178     9.631470  1.926290  1.936230  0.028130            1     1.929830
# 179    42.052500  8.410510  8.401350  0.118866            1     8.482720
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 176              474                     0              40          dynamic
# 177            14655                     0              40          dynamic
# 178            59315                     0              40          dynamic
# 179           234021                     0              40          dynamic
#
# [4 rows x 21 columns]
#                     date     octree   point_type           encoder    npoints  \
# 176  2025-06-01-13:22:47  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  721810646
# 177  2025-06-01-13:22:48  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  721810646
# 178  2025-06-01-13:22:48  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  721810646
# 179  2025-06-01-13:22:49  PCLKdTree  PCLPointXYZ  HilbertEncoder3D  721810646
#
#           operation  kernel  radius  num_searches sequential_searches  ...  \
# 176  neighborsPCLKD  Sphere    0.01         10000              random  ...
# 177  neighborsPCLKD  Sphere    0.05         10000              random  ...
# 178  neighborsPCLKD  Sphere    0.10         10000              random  ...
# 179  neighborsPCLKD  Sphere    0.20         10000              random  ...
#
#      accumulated      mean    median     stdev  used_warmup  warmup_time  \
# 176     0.077414  0.015483  0.015895  0.001546            1     0.020675
# 177     0.096171  0.019234  0.019763  0.002051            1     0.021733
# 178     0.276051  0.055210  0.055321  0.001254            1     0.054846
# 179     0.693103  0.138621  0.137997  0.004401            1     0.137180
#
#      avg_result_size  tolerance_percentage  openmp_threads  openmp_schedule
# 176              160                     0              40          dynamic
# 177              472                     0              40          dynamic
# 178             1651                     0              40          dynamic
# 179             4233                     0              40          dynamic
#
# [4 rows x 21 columns]
# ('PCLKdTree', 'neighborsPCLKD')
# Average Morton runtime:  0.8677
# Average Hilbert runtime: 0.9341
# /tmp/ipykernel_2472/974442997.py:65: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /tmp/ipykernel_2472/974442997.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
def octree_parallelization(cloud, encoder, kernel, octree, data_path, annotated=False):
    df = get_dataset_file(cloud, "latest", data_path)
    df = df[(df["octree"] == octree) & (df["encoder"] == encoder) & (df['kernel'] == kernel)][["num_searches", "repeats", "npoints", "radius", "mean", "openmp_threads"]]
    # Extract ntreads=1 baseline
    baseline = df[df["openmp_threads"] == 1].set_index("radius")["mean"]
    # Merge it on the df
    df = df.merge(baseline.rename("T1"), on="radius")
    # Compute the efficiency as (time 1 thread) / (time n threads * n)
    df["efficiency"] = df["T1"] / (df["openmp_threads"] * df["mean"])
    # Pivot and get the efficiency matrix
    efficiency_matrix = df.pivot(index="radius", columns="openmp_threads", values="efficiency")
    figsize = (7, 2.5)
    fig, ax = plt.subplots(figsize=figsize, gridspec_kw={'top': 0.75})
    heatmap = sns.heatmap(efficiency_matrix, cmap="viridis", annot=annotated, fmt=".2f", linewidths=0, 
                vmin=0, vmax=1, 
                cbar_kws={'label': 'Eficiencia'}, # Add the shrink parameter
                annot_kws={"size": 11},
                ax=ax)    
    cbar = heatmap.collections[0].colorbar
    cbar.ax.set_ylabel('Eficiencia', fontsize=15)
    plt.subplots_adjust(bottom=0.05)
    # Labels and title
    ax.set_xlabel("Número de hilos", fontsize=15)
    ax.set_ylabel("Radio de búsqueda", fontsize=15)
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=15)
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=15)
    ax.xaxis.set_minor_locator(plt.NullLocator())
    ax.tick_params(axis="both", which="both", length=0)
    cbar.ax.tick_params(axis="y", which="both", length=0)
    return fig

# %%
# parallel SUBSETS
fig = octree_parallelization("Lille_0", "NoEncoding", "Sphere", "Octree", DATA_PARALLEL_SUBSET, True)
output_fig(fig, "lille_0_parallel_subset_poct_unsorted")
display(fig)

fig = octree_parallelization("Lille_0", "HilbertEncoder3D", "Sphere", "Octree", DATA_PARALLEL_SUBSET, True)
output_fig(fig, "lille_0_parallel_subset_poct_hilb")
display(fig)

fig = octree_parallelization("Lille_0", "HilbertEncoder3D", "Sphere", "LinearOctree", DATA_PARALLEL_SUBSET, True)
output_fig(fig, "lille_0_parallel_subset_loct_hilb")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/parallel_subset/Lille_0/Lille_0-2025-06-03-06:25:09.csv
# Loading latest file: out_tfg_v3/parallel_subset/Lille_0/Lille_0-2025-06-03-06:25:09.csv
# Loading latest file: out_tfg_v3/parallel_subset/Lille_0/Lille_0-2025-06-03-06:25:09.csv

# %%
# parallel FULL
fig = octree_parallelization("Lille_0", "NoEncoding", "Sphere", "Octree", DATA_PARALLEL_FULL, True)
output_fig(fig, "lille_0_parallel_full_poct_unsorted")
display(fig)

fig = octree_parallelization("Lille_0", "HilbertEncoder3D", "Sphere", "Octree", DATA_PARALLEL_FULL, True)
output_fig(fig, "lille_0_parallel_full_poct_hilb")
display(fig)

fig = octree_parallelization("Lille_0", "HilbertEncoder3D", "Sphere", "LinearOctree", DATA_PARALLEL_FULL, True)
output_fig(fig, "lille_0_parallel_full_loct_hilb")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/parallel_full/Lille_0/Lille_0-2025-06-15-17:51:24.csv
# Loading latest file: out_tfg_v3/parallel_full/Lille_0/Lille_0-2025-06-15-17:51:24.csv
# Loading latest file: out_tfg_v3/parallel_full/Lille_0/Lille_0-2025-06-15-17:51:24.csv

# %% [markdown]
# ### PLOTS QUE NO ESTÁN EN EL PAPER PERO SI EN EL TFG

# %%
from matplotlib.ticker import FuncFormatter
def approximate_search_comparison(cloud, dataset, kernel, data_path, encoder = HILBERT_ENCODER, legendpos=(0.85, 1.07)):
    df = get_dataset_file(cloud, "latest", data_path)

    operations = [NEIGHBORS_APPROX_LOWER, NEIGHBORS_STRUCT, NEIGHBORS_APPROX_UPPER]
    operations_palette = {
        NEIGHBORS_STRUCT: "#3ca370",
        NEIGHBORS_APPROX_UPPER: '#1984c5',
        NEIGHBORS_APPROX_LOWER: '#e14b31'
    }
    operations_display_name = {
        NEIGHBORS_STRUCT: 'Exacta',
        NEIGHBORS_APPROX_UPPER: 'Aproximada (Cota Superior)',
        NEIGHBORS_APPROX_LOWER: 'Aproximada (Cota Inferior)'
    }
    df = df[df['operation'].isin(operations)]
    df = df[df['kernel'] == kernel]
    df = df[df['encoder'] == encoder] 
    radii = sorted(df['radius'].unique())
    fig, axes = plt.subplots(len(radii), 1, figsize=(10, 6), gridspec_kw={'hspace': 0.5})
    if len(radii) == 1:
        axes = [axes]

    legend_handles, legend_labels = [], []

    for radius_idx, radius in enumerate(radii):
        ax = axes[radius_idx]
        radius_data = df[df['radius'] == radius].copy()
        baseline_row = radius_data[
            (radius_data['operation'] == NEIGHBORS_STRUCT) &
            (radius_data['tolerance_percentage'] == 0)
        ]
        if baseline_row.empty:
            ax.text(0.5, 0.5, f'No exact search data for r = {radius}',
                    transform=ax.transAxes, ha='center', va='center', fontsize=10)
            continue

        baseline = baseline_row['avg_result_size'].iloc[0]
        radius_data['relative_points'] = (radius_data['avg_result_size'] / baseline) * 100

        for op in operations:
            op_data = radius_data[radius_data['operation'] == op].sort_values('relative_points')
            min_x = 1e9
            max_x = -1e9
            if not op_data.empty:
                ax.plot(op_data['relative_points'], op_data['mean'],
                        color='gray', alpha=0.4, linestyle='-')
                scatter = ax.scatter(op_data['relative_points'], op_data['mean'],
                                     color=operations_palette[op], s=70)

                for _, row in op_data.iterrows():
                    xy_test = (10,0) if op == NEIGHBORS_APPROX_UPPER else (-55, 0) if op == NEIGHBORS_APPROX_LOWER else (-20, -15)
                    if row["tolerance_percentage"] == 75:
                        xy_test = (xy_test[0], xy_test[1] - 12)
                    ax.annotate(f"$tol = {row['tolerance_percentage']}\%$",
                                (row['relative_points'], row['mean']),
                                textcoords="offset points", xytext=xy_test,
                                fontsize=12, color='black')

                if radius_idx == 0 and operations_display_name[op] not in legend_labels:
                    legend_handles.append(scatter)
                    legend_labels.append(operations_display_name[op])
        ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x)}\%'))
        print(min_x, max_x)
        ax.set_title(f"$r = {radius}$", loc='left')
        ax.set_xlabel("Porcentaje de puntos encontrados")
        ax.set_ylabel(f"Tiempo {'(ms)' if TIMES_IN_MS else '(s)'}")
        ax.grid(True, linestyle='--', alpha=0.3)
        ax.tick_params(axis='x')
        ax.tick_params(axis='y')

    add_octree_types_legend(legend_handles, legend_labels, "Método de búsqueda", fig, pos = legendpos)
    return fig

# %%
fig = approximate_search_comparison("Lille_0", "Paris_Lille", "Sphere", DATA_APPROX_FULL, legendpos = (0.92, 1.02))
output_fig(fig, "lille_0_approx_subset_sphere_hilbert")
display(fig)
# Out:
# Loading latest file: out_tfg_v3/approx_full/Lille_0/Lille_0-2025-05-29-07:57:47.csv
# 1000000000.0 -1000000000.0

# %%
# time to check the build times
PATH_BUILD_128 = os.path.join(BASE_DATA_PATH, "build_128")
dfs = {}
clouds = ["5080_54400", "bildstein_station1_xyz_intensity_rgb", "Lille_0", "Paris_Luxembourg_6", "sg27_station8_intensity_rgb", "Speulderbos_2017_TLS"]
# Load and tag each DataFrame
dfs = []
for cloud in clouds:
    filepath = os.path.join(PATH_BUILD_128, cloud, "enc_octree_times.csv")
    df = pd.read_csv(filepath)
    df["cloud"] = cloud
    dfs.append(df)

df_merged = pd.concat(dfs, ignore_index=True)

# %%
# Create a new column for the ratio
df_merged["mu"] =  (df_merged["number_of_nodes"] / df_merged["cloud_size"])
# Group by octree type and compute the average ratio
avg_ratios = df_merged.groupby("oct_type")["mu"].mean()
print(avg_ratios)
# Out:
# oct_type
# LinearOctree    0.045420
# Octree          0.045417
# unibnOctree     0.029800
# Name: mu, dtype: float64

# %%
def table_speedup_vs_kdtree(clouds_datasets, kernel, operations, data_path, types_info=TYPES_INFO_STRUCTURES, encoder="all"):
    import math
    dfs = read_multiple_datasets(clouds_datasets, data_path)
    all_results = []

    # Identify structure keys
    pcloct_key = (PCL_OCTREE, NEIGHBORS_PCLOCT)

    # Define result size bins: [(min, max), ...]
    bins = [(10**i, 10**(i+2)) for i in range(0, 8, 2)]

    for bin_min, bin_max in bins:
        bin_results = []
        for j, (_, params) in enumerate(types_info["available_types"].iterrows()):
            key = tuple(params[col] for col in types_info["type_parameters"])
            runtimes = []

            for df_name, df in dfs.items():
                if df.empty:
                    continue
                if kernel == "all":
                    df = df[df['operation'].isin(operations)]
                else:
                    df = df[(df['kernel'] == kernel) & (df['operation'].isin(operations))]
                if encoder != "all":
                    df = df[df["encoder"] == encoder]

                struct_data = df[
                    (df[types_info["type_parameters"]] == pd.Series(key, index=types_info["type_parameters"])).all(axis=1)
                ]

                if struct_data.empty:
                    continue

                # Filter by result size bin
                struct_data = struct_data[
                    (struct_data["avg_result_size"] >= bin_min) & 
                    (struct_data["avg_result_size"] < bin_max)
                ]
                if struct_data.empty:
                    continue

                runtimes.extend(struct_data["mean"].tolist())

            avg_runtime = np.mean(runtimes) if runtimes else np.nan
            bin_results.append((key, avg_runtime))

        # Find KDTree runtime in this bin
        kdtree_runtime = next((r for (k, r) in bin_results if k == pcloct_key), np.nan)
        print(bin_results)
        print(kdtree_runtime)
        # Collect table data for the bin
        for key, runtime in bin_results:
            if np.isnan(runtime) or np.isnan(kdtree_runtime):
                speedup = np.nan
            else:
                speedup = kdtree_runtime / runtime
            label = types_info["display_name"].get(key, str(key))
            all_results.append({
                "Size Range": f"{bin_min:.0e}–{bin_max:.0e}",
                "Structure": label,
                "Average Runtime (ms)": f"{runtime:.2f}" if not np.isnan(runtime) else "N/A",
                "Speedup vs. KDTree": f"{speedup:.2f}×" if not np.isnan(speedup) else "N/A"
            })

    return pd.DataFrame(all_results).sort_values(
        by=["Size Range", "Speedup vs. KDTree"], ascending=[True, False]
    )

# %%
speedup_fullsearch = table_speedup_vs_kdtree(ALL_CLOUDS, "Sphere", [NEIGHBORS_PCLKD, NEIGHBORS_UNIBN, NEIGHBORS_STRUCT, NEIGHBORS_PCLOCT], DATA_FULL, encoder=HILBERT_ENCODER)
speedup_randomsearch = table_speedup_vs_kdtree(ALL_CLOUDS, "Sphere", [NEIGHBORS_PCLKD, NEIGHBORS_UNIBN, NEIGHBORS_STRUCT, NEIGHBORS_PCLOCT], DATA_SUBSET, encoder=HILBERT_ENCODER)
# Out:
# Loading latest file: out_tfg_v3/full/Lille_0/Lille_0-2025-05-28-22:42:26.csv
# Loading latest file: out_tfg_v3/full/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-05-29-01:03:58.csv
# Skipping file with invalid timestamp format: extra_r15.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/full/5080_54400/5080_54400-2025-05-28-22:12:56.csv
# Loading latest file: out_tfg_v3/full/bildstein_station1_xyz_intensity_rgb/bildstein_station1_xyz_intensity_rgb-2025-05-28-20:49:36.csv
# Loading latest file: out_tfg_v3/full/sg27_station8_intensity_rgb/sg27_station8_intensity_rgb-2025-05-29-02:38:08.csv
# Skipping file with invalid timestamp format: extra_r025.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/full/Speulderbos_2017_TLS/Speulderbos_2017_TLS-2025-05-29-06:57:10.csv
# [(('LinearOctree', 'neighborsStruct'), np.float64(6.17949)), (('unibnOctree', 'neighborsUnibn'), np.float64(5.883125)), (('PCLOctree', 'PCLOctree'), np.float64(17.0319)), (('PCLKdTree', 'neighborsPCLKD'), np.float64(12.7531))]
# 17.0319
# [(('LinearOctree', 'neighborsStruct'), np.float64(101.06148)), (('unibnOctree', 'neighborsUnibn'), np.float64(197.62445714285715)), (('PCLOctree', 'PCLOctree'), np.float64(1046.52394)), (('PCLKdTree', 'neighborsPCLKD'), np.float64(463.50649999999996))]
# 1046.52394
# [(('LinearOctree', 'neighborsStruct'), np.float64(131.609175)), (('unibnOctree', 'neighborsUnibn'), np.float64(231.41116666666667)), (('PCLOctree', 'PCLOctree'), np.float64(1808.9805000000001)), (('PCLKdTree', 'neighborsPCLKD'), np.float64(1336.45))]
# 1808.9805000000001
# [(('LinearOctree', 'neighborsStruct'), nan), (('unibnOctree', 'neighborsUnibn'), nan), (('PCLOctree', 'PCLOctree'), nan), (('PCLKdTree', 'neighborsPCLKD'), nan)]
# nan
# Loading latest file: out_tfg_v3/subset/Lille_0/Lille_0-2025-06-01-10:30:28.csv
# Loading latest file: out_tfg_v3/subset/Paris_Luxembourg_6/Paris_Luxembourg_6-2025-06-01-10:38:28.csv
# Loading latest file: out_tfg_v3/subset/5080_54400/5080_54400-2025-06-01-10:37:30.csv
# Loading latest file: out_tfg_v3/subset/bildstein_station1_xyz_intensity_rgb/bildstein_station1_xyz_intensity_rgb-2025-06-01-10:55:38.csv
# Loading latest file: out_tfg_v3/subset/sg27_station8_intensity_rgb/sg27_station8_intensity_rgb-2025-06-01-11:00:41.csv
# Skipping file with invalid timestamp format: extra.csv (time data '' does not match format '%Y-%m-%d-%H:%M:%S')
# Loading latest file: out_tfg_v3/subset/Speulderbos_2017_TLS/Speulderbos_2017_TLS-2025-06-01-12:43:03.csv
# [(('LinearOctree', 'neighborsStruct'), np.float64(0.0038194725000000006)), (('unibnOctree', 'neighborsUnibn'), np.float64(0.0043986425)), (('PCLOctree', 'PCLOctree'), np.float64(0.014267950000000001)), (('PCLKdTree', 'neighborsPCLKD'), np.float64(0.008116926666666666))]
# 0.014267950000000001
# [(('LinearOctree', 'neighborsStruct'), np.float64(0.021207416363636364)), (('unibnOctree', 'neighborsUnibn'), np.float64(0.028214040909090913)), (('PCLOctree', 'PCLOctree'), np.float64(0.060121360833333325)), (('PCLKdTree', 'neighborsPCLKD'), np.float64(0.09280240833333335))]
# 0.060121360833333325
# [(('LinearOctree', 'neighborsStruct'), np.float64(0.11653934444444444)), (('unibnOctree', 'neighborsUnibn'), np.float64(0.25839835555555557)), (('PCLOctree', 'PCLOctree'), np.float64(0.8372271111111113)), (('PCLKdTree', 'neighborsPCLKD'), np.float64(2.776980555555556))]
# 0.8372271111111113
# [(('LinearOctree', 'neighborsStruct'), nan), (('unibnOctree', 'neighborsUnibn'), nan), (('PCLOctree', 'PCLOctree'), nan), (('PCLKdTree', 'neighborsPCLKD'), nan)]
# nan

# %%
print(speedup_fullsearch)
print(speedup_randomsearch)
# Out:
#      Size Range                 Structure Average Runtime (ms)  \
# 1   1e+00–1e+02      \textit{unibnOctree}                 5.88
# 0   1e+00–1e+02  \textit{neighborsStruct}                 6.18
# 3   1e+00–1e+02      \textit{PCL KD-tree}                12.75
# 2   1e+00–1e+02       \textit{PCL Octree}                17.03
# 5   1e+02–1e+04      \textit{unibnOctree}               197.62
# 7   1e+02–1e+04      \textit{PCL KD-tree}               463.51
# 4   1e+02–1e+04  \textit{neighborsStruct}               101.06
# 6   1e+02–1e+04       \textit{PCL Octree}              1046.52
# 9   1e+04–1e+06      \textit{unibnOctree}               231.41
# 8   1e+04–1e+06  \textit{neighborsStruct}               131.61
# 11  1e+04–1e+06      \textit{PCL KD-tree}              1336.45
# 10  1e+04–1e+06       \textit{PCL Octree}              1808.98
# 12  1e+06–1e+08  \textit{neighborsStruct}                  N/A
# 13  1e+06–1e+08      \textit{unibnOctree}                  N/A
# 14  1e+06–1e+08       \textit{PCL Octree}                  N/A
# 15  1e+06–1e+08      \textit{PCL KD-tree}                  N/A
#
#    Speedup vs. KDTree
# 1               2.90×
# 0               2.76×
# 3               1.34×
# 2               1.00×
# 5               5.30×
# 7               2.26×
# 4              10.36×
# 6               1.00×
# 9               7.82×
# 8              13.75×
# 11              1.35×
# 10              1.00×
# 12                N/A
# 13                N/A
# 14                N/A
# 15                N/A
#      Size Range                 Structure Average Runtime (ms)  \
# 0   1e+00–1e+02  \textit{neighborsStruct}                 0.00
# 1   1e+00–1e+02      \textit{unibnOctree}                 0.00
# 3   1e+00–1e+02      \textit{PCL KD-tree}                 0.01
# 2   1e+00–1e+02       \textit{PCL Octree}                 0.01
# 4   1e+02–1e+04  \textit{neighborsStruct}                 0.02
# 5   1e+02–1e+04      \textit{unibnOctree}                 0.03
# 6   1e+02–1e+04       \textit{PCL Octree}                 0.06
# 7   1e+02–1e+04      \textit{PCL KD-tree}                 0.09
# 8   1e+04–1e+06  \textit{neighborsStruct}                 0.12
# 9   1e+04–1e+06      \textit{unibnOctree}                 0.26
# 10  1e+04–1e+06       \textit{PCL Octree}                 0.84
# 11  1e+04–1e+06      \textit{PCL KD-tree}                 2.78
# 12  1e+06–1e+08  \textit{neighborsStruct}                  N/A
# 13  1e+06–1e+08      \textit{unibnOctree}                  N/A
# 14  1e+06–1e+08       \textit{PCL Octree}                  N/A
# 15  1e+06–1e+08      \textit{PCL KD-tree}                  N/A
#
#    Speedup vs. KDTree
# 0               3.74×
# 1               3.24×
# 3               1.76×
# 2               1.00×
# 4               2.83×
# 5               2.13×
# 6               1.00×
# 7               0.65×
# 8               7.18×
# 9               3.24×
# 10              1.00×
# 11              0.30×
# 12                N/A
# 13                N/A
# 14                N/A
# 15                N/A
